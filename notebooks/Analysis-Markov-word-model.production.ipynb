# %% [markdown]
# # Loanword analysis using Markov language model
# ### with Kneser Ney smoothing
# ### Files from WOLD  - forms, segmented forms, indicator of loan words
# ## Requires NLTK3.5

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))

# Do this once in the kernel.
import sys
sys.path.append('code')

# Set to automatically reload.
# %load_ext autoreload
# %autoreload 2
# Out:
# <style>.container { width:80% !important; }</style>

# %%
# List of study languages:
languages = ['English', 'Hup', 'ImbaburaQuechua', 'Mapudungun', 'Qeqchi', 'Wichi']
# English for development and the Latin American languages for strong regioinal interest.

# %%
# Compile code for MarkovCharLM...
import py_compile
py_compile.compile('code/utility_functions.py')
py_compile.compile('code/markov_char_lm.py')
py_compile.compile('code/markov_model_analysis.py')
# Out:
# 'code/__pycache__/markov_model_analysis.cpython-38.pyc'

# %%
from utility_functions import *
from markov_char_lm import MarkovCharLM
from markov_model_analysis import analyze_language_word_distributions
from markov_model_analysis import analyze_language_word_distributions_native_basis
from markov_model_analysis import language_word_discrimination_dual_basis
from markov_model_analysis import language_word_discrimination_native_basis
from markov_model_analysis import language_word_discrimination_dual_basis
from markov_model_analysis import language_word_discrimination_native_basis
from markov_model_analysis import k_fold_language_word_discrimination_native_basis
from markov_model_analysis import k_fold_language_word_discrimination_dual_basis
from markov_model_analysis import k_fold_entropy_for_language

# %% [markdown]
# # Randomization test for distribution differences
# ## Markov model entropies calculated from undifferentiated (entire) word table
# 1. Fit Markov model to undifferentiated sample or entire table.
# 2. Examine distributiona of native and loan words.
# 3. Randomization test for native versus loan word distributional differences.
#     1. Calculate decision statistic for 'true' vector of native versus loan.
#     2. Perform n randomizations of vector which arbitrarily designates native versus loan.
#         1. calculate statistic for each randomization.
#     3. Determine empirical probability distribution of statistic and probability of original decision statistic.

# %%
# Test for distributional differences - Based on formchars
# Based on undifferentiated table for training 2nd order Markov model, and
# Calcalulation and plotting of entropies for native and loan words separately.
for l in languages:
    analyze_language_word_distributions(l, form='formchars', test='ks', n=5000)
# Out:
# Language=English
# prob (ks stat >= 0.16808) = 0.00010
# Language=Hup
# prob (ks stat >= 0.29571) = 0.00010
# Language=ImbaburaQuechua
# prob (ks stat >= 0.41148) = 0.00010
# Language=Mapudungun
# prob (ks stat >= 0.33744) = 0.00010
# Language=Qeqchi
# prob (ks stat >= 0.32823) = 0.00010
# Language=Wichi
# prob (ks stat >= 0.52453) = 0.00010

# %%
# Test for distributional differences - Based on segmented IPA (segments)
# Based on undifferentiated table for training 2nd order Markov model, and
# Calcalulation and plotting of entropies for native and loan words separately.
for l in languages:
    analyze_language_word_distributions(l, form='segments', test='ks', n=5000)
# Out:
# Language=English
# prob (ks stat >= 0.04214) = 0.49220
# Language=Hup
# prob (ks stat >= 0.33364) = 0.00010
# Language=ImbaburaQuechua
# prob (ks stat >= 0.36392) = 0.00010
# Language=Mapudungun
# prob (ks stat >= 0.29208) = 0.00010
# Language=Qeqchi
# prob (ks stat >= 0.28575) = 0.00010
# Language=Wichi
# prob (ks stat >= 0.47015) = 0.00010

# %%
# Test for distributional differences - Based on segmented IPA (segments)
# Based on undifferentiated table for training 2nd order Markov model, and
# Calcalulation and plotting of entropies for native and loan words separately.
for l in languages:
    analyze_language_word_distributions(l, form='scas', test='ks', n=5000)
# Out:
# Language=English, form=scas
# prob (ks stat >= 0.05185) = 0.26945
# Language=Hup, form=scas
# prob (ks stat >= 0.42114) = 0.00010
# Language=ImbaburaQuechua, form=scas
# prob (ks stat >= 0.28408) = 0.00010
# Language=Mapudungun, form=scas
# prob (ks stat >= 0.31353) = 0.00010
# Language=Qeqchi, form=scas
# prob (ks stat >= 0.31501) = 0.00010
# Language=Wichi, form=scas
# prob (ks stat >= 0.43982) = 0.00010

# %% [markdown]
# # Randomization tests for distribution differences
# ## Constructs native Markov models for each randomization
# - Repeated estimation of model and with random selector - very compute intensive
#     - Correct approach in that it incoporates the learning bias.
#     - Reduced repetitions to 1000 due to compute time.

# %%
# Test for distributional differences - Based on formchars
# Based on native table for training 2nd order Markov model, and
# Calcalulation and plotting of entropies for native and loan words separately.
for l in languages:
    analyze_language_word_distributions_native_basis(l, form='formchars', test='ks', n=1000)

# More than 1000 replicates would be costly in time.
# Out:
# prob (stat >= 0.6870465084378602 ) = 0.0004995004995005381
# prob (stat >= 0.8855676328502415 ) = 0.0004995004995005381
# prob (stat >= 0.7656702265695179 ) = 0.0004995004995005381
# prob (stat >= 0.7151606425702811 ) = 0.0004995004995005381
# prob (stat >= 0.6168676363887641 ) = 0.0004995004995005381
# prob (stat >= 0.8197155033113137 ) = 0.0004995004995005381

# %%
# Test for distributional differences - Based on segmented IPA (segments).
# Based on native table for training 2nd order Markov model, and
# Calcalulation and plotting of entropies for native and loan words separately.
for l in languages:
    analyze_language_word_distributions_native_basis(l, form='segments', test='ks', n=1000)
# Out:
# Language=English, form=segments
# prob (stat >= 0.7809184824143699 ) = 0.0004995004995005381
# Language=Hup, form=segments
# prob (stat >= 0.806280193236715 ) = 0.0004995004995005381
# Language=ImbaburaQuechua, form=segments
# prob (stat >= 0.7866276297257433 ) = 0.0004995004995005381
# Language=Mapudungun, form=segments
# prob (stat >= 0.7396251673360107 ) = 0.0004995004995005381
# Language=Qeqchi, form=segments
# prob (stat >= 0.7226214743921962 ) = 0.0004995004995005381
# Language=Wichi, form=segments
# prob (stat >= 0.8293354766868444 ) = 0.0004995004995005381

# %%
# Test for distributional differences - Based on segmented IPA (segments).
# Based on native table for training 2nd order Markov model, and
# Calcalulation and plotting of entropies for native and loan words separately.
for l in languages:
    analyze_language_word_distributions_native_basis(l, form='scas', test='ks', n=1000)
# Out:
# Language=English, form=scas
# prob (stat >= 0.4050778584776757 ) = 0.0004995004995005381
# Language=Hup, form=scas
# prob (stat >= 0.668659420289855 ) = 0.0004995004995005381
# Language=ImbaburaQuechua, form=scas
# prob (stat >= 0.6270364086014351 ) = 0.0004995004995005381
# Language=Mapudungun, form=scas
# prob (stat >= 0.6231369924141008 ) = 0.0004995004995005381
# Language=Qeqchi, form=scas
# prob (stat >= 0.5182945790001037 ) = 0.0004995004995005381
# Language=Wichi, form=scas
# prob (stat >= 0.7517142641850652 ) = 0.0004995004995005381

# %% [markdown]
# # Word discrimination - based on native versus loan entropy models

# %%
# Illustration of one trial.  Below we do k_fold trials.
language_word_discrimination_dual_basis("Hup", smoothing=0.5)
language_word_discrimination_dual_basis("Hup", form='segments', smoothing=0.5)
language_word_discrimination_dual_basis("Hup", form='scas', smoothing=0.5)
# Out:
# Language=Hup, form=formchars
# num train=  944, num test=  235
#
# * TRAIN RESULTS *
# precision, recall, F1 = (1.0, 0.9867947178871549, 0.9933534743202418)
# n = 944  accuracy = 0.9883474576271186
# confusion matrix: tn, fp, fn, tp [111   0  11 822]
# Predict majority: accuracy= 0.8824152542372882
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9528795811518325, 0.900990099009901, 0.926208651399491)
# n = 235  accuracy = 0.8765957446808511
# confusion matrix: tn, fp, fn, tp [ 24   9  20 182]
# Predict majority: accuracy= 0.8595744680851064
#
# Language=Hup, form=segments
# num train=  944, num test=  235
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9975550122249389, 0.9855072463768116, 0.991494532199271)
# n = 944  accuracy = 0.9851694915254238
# confusion matrix: tn, fp, fn, tp [114   2  12 816]
# Predict majority: accuracy= 0.8771186440677966
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9637305699481865, 0.8985507246376812, 0.93)
# n = 235  accuracy = 0.8808510638297873
# confusion matrix: tn, fp, fn, tp [ 21   7  21 186]
# Predict majority: accuracy= 0.8808510638297873
#
# Language=Hup, form=scas
# num train=  944, num test=  235
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9962073324905183, 0.9516908212560387, 0.9734403953057443)
# n = 944  accuracy = 0.9544491525423728
# confusion matrix: tn, fp, fn, tp [113   3  40 788]
# Predict majority: accuracy= 0.8771186440677966
#
# * TEST RESULTS *
# precision, recall, F1 = (0.96875, 0.8985507246376812, 0.9323308270676692)
# n = 235  accuracy = 0.8851063829787233
# confusion matrix: tn, fp, fn, tp [ 22   6  21 186]
# Predict majority: accuracy= 0.8808510638297873

# %% [markdown]
# # Word discrimination - based on just native known

# %%
# Illustration of one trial.  Below we do k_fold trials.
language_word_discrimination_native_basis("Qeqchi", smoothing=0.5, p=.995)
language_word_discrimination_native_basis("Qeqchi", form='segments', smoothing=0.5, p=.995)
language_word_discrimination_native_basis("Qeqchi", form='scas', smoothing=0.5, p=.995)
# Out:
# Language=Qeqchi, form=formchars
# num train= 1596, num test=  399
# Native avg=2.752, stdev=0.449
# fraction 0.995, idx 1342.25, ref limit=4.453
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9018157363819771, 0.9933333333333333, 0.9453648219950652)
# n = 1596  accuracy = 0.9028822055137845
# confusion matrix: tn, fp, fn, tp [ 100  146    9 1341]
# Predict majority: accuracy= 0.8458646616541353
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8962536023054755, 0.9255952380952381, 0.9106881405563689)
# n = 399  accuracy = 0.8471177944862155
# confusion matrix: tn, fp, fn, tp [ 27  36  25 311]
# Predict majority: accuracy= 0.8421052631578947
#
# Language=Qeqchi, form=segments
# num train= 1596, num test=  399
# Native avg=2.743, stdev=0.496
# fraction 0.995, idx 1333.30, ref limit=4.412
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9295184926727146, 0.9932885906040269, 0.9603460706560923)
# n = 1596  accuracy = 0.931077694235589
# confusion matrix: tn, fp, fn, tp [ 154  101    9 1332]
# Predict majority: accuracy= 0.8402255639097744
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9292604501607717, 0.8376811594202899, 0.8810975609756098)
# n = 399  accuracy = 0.8045112781954887
# confusion matrix: tn, fp, fn, tp [ 32  22  56 289]
# Predict majority: accuracy= 0.8646616541353384
#
# Language=Qeqchi, form=scas
# num train= 1596, num test=  399
# Native avg=2.672, stdev=0.464
# fraction 0.995, idx 1343.25, ref limit=4.481
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8847167325428195, 0.9940784603997039, 0.936214708957825)
# n = 1596  accuracy = 0.8853383458646616
# confusion matrix: tn, fp, fn, tp [  70  175    8 1343]
# Predict majority: accuracy= 0.8464912280701754
#
# * TEST RESULTS *
# precision, recall, F1 = (0.875, 0.9611940298507463, 0.9160739687055477)
# n = 399  accuracy = 0.8521303258145363
# confusion matrix: tn, fp, fn, tp [ 18  46  13 322]
# Predict majority: accuracy= 0.8395989974937343

# %% [markdown]
# # Word discrimination - based on native only entropy model
# ## k-fold fit on known native and loan and validation on unknown

# %%
# Test k-fold native basis word discrimination - Based on formchars.
# No interest in return table of k-fold trials, thus the _ return value.
for l in languages:
    _ = k_fold_language_word_discrimination_native_basis(l, form='formchars', smoothing=0.5, k_fold=10, p=.995)
# Out:
# English
# Native avg=2.622, stdev=0.419
# fraction 0.995, idx 778.09, ref limit=3.986
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.7239776951672863, 0.9948914431673053, 0.8380849919311458)
# n = 1364  accuracy = 0.7793255131964809
# confusion matrix: tn, fp, fn, tp [284 297   4 779]
# Predict majority: accuracy= 0.5740469208211144
#
# * TEST RESULTS *
# precision, recall, F1 = (0.7087378640776699, 0.8111111111111111, 0.756476683937824)
# n = 152  accuracy = 0.6907894736842105
# confusion matrix: tn, fp, fn, tp [32 30 17 73]
# Predict majority: accuracy= 0.5921052631578947
# Native avg=2.642, stdev=0.417
# fraction 0.995, idx 784.06, ref limit=4.086
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.714936247723133, 0.9949302915082383, 0.8320084790673026)
# n = 1364  accuracy = 0.7675953079178885
# confusion matrix: tn, fp, fn, tp [262 313   4 785]
# Predict majority: accuracy= 0.5784457478005866
#
# * TEST RESULTS *
# precision, recall, F1 = (0.6542056074766355, 0.8333333333333334, 0.7329842931937172)
# n = 152  accuracy = 0.6644736842105263
# confusion matrix: tn, fp, fn, tp [31 37 14 70]
# Predict majority: accuracy= 0.5526315789473685
# Native avg=2.622, stdev=0.422
# fraction 0.995, idx 784.06, ref limit=4.056
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.7116953762466002, 0.9949302915082383, 0.8298097251585624)
# n = 1364  accuracy = 0.7639296187683284
# confusion matrix: tn, fp, fn, tp [257 318   4 785]
# Predict majority: accuracy= 0.5784457478005866
#
# * TEST RESULTS *
# precision, recall, F1 = (0.6415094339622641, 0.8095238095238095, 0.7157894736842104)
# n = 152  accuracy = 0.6447368421052632
# confusion matrix: tn, fp, fn, tp [30 38 16 68]
# Predict majority: accuracy= 0.5526315789473685
# Native avg=2.635, stdev=0.418
# fraction 0.995, idx 776.10, ref limit=4.068
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.7108874656907593, 0.9948783610755442, 0.8292422625400214)
# n = 1364  accuracy = 0.7653958944281525
# confusion matrix: tn, fp, fn, tp [267 316   4 777]
# Predict majority: accuracy= 0.5725806451612904
#
# * TEST RESULTS *
# precision, recall, F1 = (0.6612903225806451, 0.8913043478260869, 0.7592592592592593)
# n = 152  accuracy = 0.6578947368421053
# confusion matrix: tn, fp, fn, tp [18 42 10 82]
# Predict majority: accuracy= 0.6052631578947368
# Native avg=2.634, stdev=0.418
# fraction 0.995, idx 782.07, ref limit=4.110
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.7035040431266847, 0.9949174078780177, 0.8242105263157895)
# n = 1364  accuracy = 0.7551319648093842
# confusion matrix: tn, fp, fn, tp [247 330   4 783]
# Predict majority: accuracy= 0.5769794721407625
#
# * TEST RESULTS *
# precision, recall, F1 = (0.6509433962264151, 0.8023255813953488, 0.71875)
# n = 152  accuracy = 0.6447368421052632
# confusion matrix: tn, fp, fn, tp [29 37 17 69]
# Predict majority: accuracy= 0.5657894736842105
# Native avg=2.633, stdev=0.430
# fraction 0.995, idx 777.10, ref limit=4.079
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.7028003613369467, 0.9948849104859335, 0.8237162519851774)
# n = 1364  accuracy = 0.7558651026392962
# confusion matrix: tn, fp, fn, tp [253 329   4 778]
# Predict majority: accuracy= 0.5733137829912024
#
# * TEST RESULTS *
# precision, recall, F1 = (0.7192982456140351, 0.9010989010989011, 0.8000000000000002)
# n = 152  accuracy = 0.7302631578947368
# confusion matrix: tn, fp, fn, tp [29 32  9 82]
# Predict majority: accuracy= 0.5986842105263158
# Native avg=2.632, stdev=0.426
# fraction 0.995, idx 779.09, ref limit=4.111
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.6951871657754011, 0.9948979591836735, 0.8184679958027283)
# n = 1365  accuracy = 0.7465201465201465
# confusion matrix: tn, fp, fn, tp [239 342   4 780]
# Predict majority: accuracy= 0.5743589743589743
#
# * TEST RESULTS *
# precision, recall, F1 = (0.7168141592920354, 0.9101123595505618, 0.8019801980198019)
# n = 151  accuracy = 0.7350993377483444
# confusion matrix: tn, fp, fn, tp [30 32  8 81]
# Predict majority: accuracy= 0.5894039735099338
# Native avg=2.627, stdev=0.427
# fraction 0.995, idx 777.10, ref limit=4.087
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.7098540145985401, 0.9948849104859335, 0.8285410010649626)
# n = 1365  accuracy = 0.764102564102564
# confusion matrix: tn, fp, fn, tp [265 318   4 778]
# Predict majority: accuracy= 0.5728937728937729
#
# * TEST RESULTS *
# precision, recall, F1 = (0.680672268907563, 0.8901098901098901, 0.7714285714285715)
# n = 151  accuracy = 0.6821192052980133
# confusion matrix: tn, fp, fn, tp [22 38 10 81]
# Predict majority: accuracy= 0.6026490066225165
# Native avg=2.631, stdev=0.427
# fraction 0.995, idx 784.06, ref limit=4.084
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.7136363636363636, 0.9949302915082383, 0.8311275807305453)
# n = 1365  accuracy = 0.7663003663003664
# confusion matrix: tn, fp, fn, tp [261 315   4 785]
# Predict majority: accuracy= 0.578021978021978
#
# * TEST RESULTS *
# precision, recall, F1 = (0.6194690265486725, 0.8333333333333334, 0.7106598984771573)
# n = 151  accuracy = 0.6225165562913907
# confusion matrix: tn, fp, fn, tp [24 43 14 70]
# Predict majority: accuracy= 0.5562913907284768
# Native avg=2.630, stdev=0.425
# fraction 0.995, idx 786.05, ref limit=4.099
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.6952296819787986, 0.9949431099873578, 0.8185127405096204)
# n = 1365  accuracy = 0.7443223443223443
# confusion matrix: tn, fp, fn, tp [229 345   4 787]
# Predict majority: accuracy= 0.5794871794871795
#
# * TEST RESULTS *
# precision, recall, F1 = (0.7204301075268817, 0.8170731707317073, 0.7657142857142857)
# n = 151  accuracy = 0.7284768211920529
# confusion matrix: tn, fp, fn, tp [43 26 15 67]
# Predict majority: accuracy= 0.543046357615894
#
#             Acc   Maj_acc      Prec    Recall        F1
# Mean   0.680111  0.575850  0.677337  0.849933  0.753304
# StDev  0.040214  0.024015  0.036961  0.042950  0.033184
#
# Hup
# Native avg=2.439, stdev=0.449
# fraction 0.995, idx 924.36, ref limit=3.874
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9809119830328739, 0.9946236559139785, 0.9877202349172451)
# n = 1061  accuracy = 0.9783223374175306
# confusion matrix: tn, fp, fn, tp [113  18   5 925]
# Predict majority: accuracy= 0.8765315739868049
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9882352941176471, 0.8, 0.8842105263157894)
# n = 118  accuracy = 0.8135593220338984
# confusion matrix: tn, fp, fn, tp [12  1 21 84]
# Predict majority: accuracy= 0.8898305084745762
# Native avg=2.429, stdev=0.461
# fraction 0.995, idx 920.38, ref limit=3.880
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9766702014846236, 0.9946004319654428, 0.9855537720706261)
# n = 1061  accuracy = 0.9745523091423186
# confusion matrix: tn, fp, fn, tp [113  22   5 921]
# Predict majority: accuracy= 0.8727615457115928
#
# * TEST RESULTS *
# precision, recall, F1 = (0.963855421686747, 0.7339449541284404, 0.8333333333333334)
# n = 118  accuracy = 0.7288135593220338
# confusion matrix: tn, fp, fn, tp [ 6  3 29 80]
# Predict majority: accuracy= 0.923728813559322
# Native avg=2.430, stdev=0.454
# fraction 0.995, idx 929.33, ref limit=3.666
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9830866807610994, 0.9946524064171123, 0.988835725677831)
# n = 1061  accuracy = 0.9802073515551367
# confusion matrix: tn, fp, fn, tp [110  16   5 930]
# Predict majority: accuracy= 0.88124410933082
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9722222222222222, 0.7, 0.813953488372093)
# n = 118  accuracy = 0.7288135593220338
# confusion matrix: tn, fp, fn, tp [16  2 30 70]
# Predict majority: accuracy= 0.847457627118644
# Native avg=2.433, stdev=0.453
# fraction 0.995, idx 925.35, ref limit=3.892
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9747368421052631, 0.9946294307196563, 0.9845826687931951)
# n = 1061  accuracy = 0.9726672950047125
# confusion matrix: tn, fp, fn, tp [106  24   5 926]
# Predict majority: accuracy= 0.8774740810556079
#
# * TEST RESULTS *
# precision, recall, F1 = (1.0, 0.6730769230769231, 0.8045977011494253)
# n = 118  accuracy = 0.711864406779661
# confusion matrix: tn, fp, fn, tp [14  0 34 70]
# Predict majority: accuracy= 0.8813559322033898
# Native avg=2.434, stdev=0.472
# fraction 0.995, idx 931.32, ref limit=3.925
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9841605068637803, 0.9946638207043756, 0.989384288747346)
# n = 1061  accuracy = 0.9811498586239397
# confusion matrix: tn, fp, fn, tp [109  15   5 932]
# Predict majority: accuracy= 0.883129123468426
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9493670886075949, 0.7653061224489796, 0.8474576271186441)
# n = 118  accuracy = 0.7711864406779662
# confusion matrix: tn, fp, fn, tp [16  4 23 75]
# Predict majority: accuracy= 0.8305084745762712
# Native avg=2.428, stdev=0.470
# fraction 0.995, idx 929.33, ref limit=3.884
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9789473684210527, 0.9946524064171123, 0.9867374005305041)
# n = 1061  accuracy = 0.9764373232799246
# confusion matrix: tn, fp, fn, tp [106  20   5 930]
# Predict majority: accuracy= 0.88124410933082
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9871794871794872, 0.77, 0.8651685393258428)
# n = 118  accuracy = 0.7966101694915254
# confusion matrix: tn, fp, fn, tp [17  1 23 77]
# Predict majority: accuracy= 0.847457627118644
# Native avg=2.426, stdev=0.457
# fraction 0.995, idx 925.35, ref limit=3.877
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9819724284199364, 0.9946294307196563, 0.9882604055496265)
# n = 1061  accuracy = 0.9792648444863337
# confusion matrix: tn, fp, fn, tp [113  17   5 926]
# Predict majority: accuracy= 0.8774740810556079
#
# * TEST RESULTS *
# precision, recall, F1 = (0.958904109589041, 0.6730769230769231, 0.7909604519774011)
# n = 118  accuracy = 0.6864406779661016
# confusion matrix: tn, fp, fn, tp [11  3 34 70]
# Predict majority: accuracy= 0.8813559322033898
# Native avg=2.429, stdev=0.458
# fraction 0.995, idx 925.35, ref limit=3.879
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9757639620653319, 0.9946294307196563, 0.9851063829787233)
# n = 1061  accuracy = 0.9736098020735156
# confusion matrix: tn, fp, fn, tp [107  23   5 926]
# Predict majority: accuracy= 0.8774740810556079
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9873417721518988, 0.75, 0.8524590163934427)
# n = 118  accuracy = 0.7711864406779662
# confusion matrix: tn, fp, fn, tp [13  1 26 78]
# Predict majority: accuracy= 0.8813559322033898
# Native avg=2.430, stdev=0.462
# fraction 0.995, idx 926.35, ref limit=3.884
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9788806758183738, 0.9946351931330472, 0.9866950505588078)
# n = 1061  accuracy = 0.9764373232799246
# confusion matrix: tn, fp, fn, tp [109  20   5 927]
# Predict majority: accuracy= 0.8784165881244109
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9746835443037974, 0.7475728155339806, 0.8461538461538461)
# n = 118  accuracy = 0.7627118644067796
# confusion matrix: tn, fp, fn, tp [13  2 26 77]
# Predict majority: accuracy= 0.8728813559322034
# Native avg=2.431, stdev=0.454
# fraction 0.995, idx 921.37, ref limit=3.914
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9766949152542372, 0.9946062567421791, 0.985569214323891)
# n = 1062  accuracy = 0.9745762711864406
# confusion matrix: tn, fp, fn, tp [113  22   5 922]
# Predict majority: accuracy= 0.8728813559322034
#
# * TEST RESULTS *
# precision, recall, F1 = (0.975, 0.7222222222222222, 0.8297872340425532)
# n = 117  accuracy = 0.7264957264957265
# confusion matrix: tn, fp, fn, tp [ 7  2 30 78]
# Predict majority: accuracy= 0.9230769230769231
#
#             Acc   Maj_acc      Prec    Recall        F1
# Mean   0.749768  0.877901  0.975679  0.733520  0.836808
# StDev  0.039743  0.030630  0.015436  0.041883  0.028324
#
# ImbaburaQuechua
# Native avg=2.306, stdev=0.467
# fraction 0.995, idx 829.83, ref limit=3.705
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8783068783068783, 0.9940119760479041, 0.9325842696629213)
# n = 1187  accuracy = 0.8989048020219039
# confusion matrix: tn, fp, fn, tp [237 115   5 830]
# Predict majority: accuracy= 0.7034540859309183
#
# * TEST RESULTS *
# precision, recall, F1 = (0.875, 0.9381443298969072, 0.9054726368159204)
# n = 132  accuracy = 0.8560606060606061
# confusion matrix: tn, fp, fn, tp [22 13  6 91]
# Predict majority: accuracy= 0.7348484848484849
# Native avg=2.311, stdev=0.458
# fraction 0.995, idx 835.80, ref limit=3.652
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8884165781083954, 0.9940546967895363, 0.9382716049382716)
# n = 1187  accuracy = 0.9073294018534119
# confusion matrix: tn, fp, fn, tp [241 105   5 836]
# Predict majority: accuracy= 0.7085088458298231
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8627450980392157, 0.967032967032967, 0.9119170984455958)
# n = 132  accuracy = 0.8712121212121212
# confusion matrix: tn, fp, fn, tp [27 14  3 88]
# Predict majority: accuracy= 0.6893939393939394
# Native avg=2.292, stdev=0.456
# fraction 0.995, idx 828.84, ref limit=3.649
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8923573735199138, 0.9940047961630696, 0.9404424276800909)
# n = 1187  accuracy = 0.9115417017691659
# confusion matrix: tn, fp, fn, tp [253 100   5 829]
# Predict majority: accuracy= 0.7026116259477675
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8924731182795699, 0.8469387755102041, 0.8691099476439791)
# n = 132  accuracy = 0.8106060606060606
# confusion matrix: tn, fp, fn, tp [24 10 15 83]
# Predict majority: accuracy= 0.7424242424242424
# Native avg=2.290, stdev=0.459
# fraction 0.995, idx 831.82, ref limit=3.595
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8907922912205567, 0.994026284348865, 0.9395821569734614)
# n = 1187  accuracy = 0.9098567818028643
# confusion matrix: tn, fp, fn, tp [248 102   5 832]
# Predict majority: accuracy= 0.7051390058972199
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8829787234042553, 0.8736842105263158, 0.8783068783068785)
# n = 132  accuracy = 0.8257575757575758
# confusion matrix: tn, fp, fn, tp [26 11 12 83]
# Predict majority: accuracy= 0.7196969696969697
# Native avg=2.293, stdev=0.468
# fraction 0.995, idx 828.84, ref limit=3.694
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8744725738396625, 0.9940047961630696, 0.9304152637485972)
# n = 1187  accuracy = 0.8955349620893007
# confusion matrix: tn, fp, fn, tp [234 119   5 829]
# Predict majority: accuracy= 0.7026116259477675
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9494949494949495, 0.9591836734693877, 0.9543147208121828)
# n = 132  accuracy = 0.9318181818181818
# confusion matrix: tn, fp, fn, tp [29  5  4 94]
# Predict majority: accuracy= 0.7424242424242424
# Native avg=2.304, stdev=0.466
# fraction 0.995, idx 831.82, ref limit=3.702
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8785638859556494, 0.994026284348865, 0.9327354260089686)
# n = 1187  accuracy = 0.8989048020219039
# confusion matrix: tn, fp, fn, tp [235 115   5 832]
# Predict majority: accuracy= 0.7051390058972199
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8952380952380953, 0.9894736842105263, 0.9400000000000001)
# n = 132  accuracy = 0.9090909090909091
# confusion matrix: tn, fp, fn, tp [26 11  1 94]
# Predict majority: accuracy= 0.7196969696969697
# Native avg=2.301, stdev=0.460
# fraction 0.995, idx 831.82, ref limit=3.655
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8869936034115139, 0.994026284348865, 0.9374647887323944)
# n = 1187  accuracy = 0.9064869418702611
# confusion matrix: tn, fp, fn, tp [244 106   5 832]
# Predict majority: accuracy= 0.7051390058972199
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8585858585858586, 0.8947368421052632, 0.8762886597938143)
# n = 132  accuracy = 0.8181818181818182
# confusion matrix: tn, fp, fn, tp [23 14 10 85]
# Predict majority: accuracy= 0.7196969696969697
# Native avg=2.294, stdev=0.460
# fraction 0.995, idx 840.77, ref limit=3.616
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8926673751328374, 0.9929078014184397, 0.940123111359821)
# n = 1187  accuracy = 0.9098567818028643
# confusion matrix: tn, fp, fn, tp [240 101   6 840]
# Predict majority: accuracy= 0.7127211457455771
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8369565217391305, 0.8953488372093024, 0.8651685393258426)
# n = 132  accuracy = 0.8181818181818182
# confusion matrix: tn, fp, fn, tp [31 15  9 77]
# Predict majority: accuracy= 0.6515151515151515
# Native avg=2.309, stdev=0.457
# fraction 0.995, idx 836.79, ref limit=3.580
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.895187165775401, 0.994061757719715, 0.9420371412492966)
# n = 1187  accuracy = 0.9132266217354675
# confusion matrix: tn, fp, fn, tp [247  98   5 837]
# Predict majority: accuracy= 0.7093513058129739
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8571428571428571, 0.9333333333333333, 0.8936170212765957)
# n = 132  accuracy = 0.8484848484848485
# confusion matrix: tn, fp, fn, tp [28 14  6 84]
# Predict majority: accuracy= 0.6818181818181818
# Native avg=2.299, stdev=0.466
# fraction 0.995, idx 839.78, ref limit=3.708
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8832807570977917, 0.9940828402366864, 0.9354120267260577)
# n = 1188  accuracy = 0.9023569023569024
# confusion matrix: tn, fp, fn, tp [232 111   5 840]
# Predict majority: accuracy= 0.7112794612794613
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8695652173913043, 0.9195402298850575, 0.8938547486033519)
# n = 131  accuracy = 0.8549618320610687
# confusion matrix: tn, fp, fn, tp [32 12  7 80]
# Predict majority: accuracy= 0.6641221374045801
#
#             Acc   Maj_acc      Prec    Recall        F1
# Mean   0.854436  0.706564  0.878018  0.921742  0.898805
# StDev  0.040369  0.032708  0.030645  0.044447  0.029789
#
# Mapudungun
# Native avg=2.599, stdev=0.449
# fraction 0.995, idx 969.13, ref limit=4.019
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.885036496350365, 0.9948717948717949, 0.9367455335586673)
# n = 1270  accuracy = 0.8968503937007875
# confusion matrix: tn, fp, fn, tp [169 126   5 970]
# Predict majority: accuracy= 0.7677165354330708
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8378378378378378, 0.8857142857142857, 0.8611111111111112)
# n = 142  accuracy = 0.7887323943661971
# confusion matrix: tn, fp, fn, tp [19 18 12 93]
# Predict majority: accuracy= 0.7394366197183099
# Native avg=2.609, stdev=0.455
# fraction 0.995, idx 959.18, ref limit=3.982
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8799266727772685, 0.9948186528497409, 0.933852140077821)
# n = 1270  accuracy = 0.8929133858267716
# confusion matrix: tn, fp, fn, tp [174 131   5 960]
# Predict majority: accuracy= 0.7598425196850394
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9122807017543859, 0.9043478260869565, 0.9082969432314411)
# n = 142  accuracy = 0.852112676056338
# confusion matrix: tn, fp, fn, tp [ 17  10  11 104]
# Predict majority: accuracy= 0.8098591549295775
# Native avg=2.599, stdev=0.457
# fraction 0.995, idx 967.14, ref limit=4.037
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8784029038112523, 0.9948612538540597, 0.9330120481927712)
# n = 1271  accuracy = 0.8906372934697089
# confusion matrix: tn, fp, fn, tp [164 134   5 968]
# Predict majority: accuracy= 0.7655389457120377
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8490566037735849, 0.8411214953271028, 0.8450704225352114)
# n = 141  accuracy = 0.7659574468085106
# confusion matrix: tn, fp, fn, tp [18 16 17 90]
# Predict majority: accuracy= 0.7588652482269503
# Native avg=2.604, stdev=0.457
# fraction 0.995, idx 963.16, ref limit=4.009
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8827838827838828, 0.9948400412796697, 0.935468219311014)
# n = 1271  accuracy = 0.8953579858379229
# confusion matrix: tn, fp, fn, tp [174 128   5 964]
# Predict majority: accuracy= 0.7623918174665618
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9056603773584906, 0.8648648648648649, 0.8847926267281107)
# n = 141  accuracy = 0.8226950354609929
# confusion matrix: tn, fp, fn, tp [20 10 15 96]
# Predict majority: accuracy= 0.7872340425531915
# Native avg=2.605, stdev=0.442
# fraction 0.995, idx 967.14, ref limit=3.921
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.890524379024839, 0.9948612538540597, 0.9398058252427185)
# n = 1271  accuracy = 0.9024390243902439
# confusion matrix: tn, fp, fn, tp [179 119   5 968]
# Predict majority: accuracy= 0.7655389457120377
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8613861386138614, 0.8130841121495327, 0.8365384615384616)
# n = 141  accuracy = 0.7588652482269503
# confusion matrix: tn, fp, fn, tp [20 14 20 87]
# Predict majority: accuracy= 0.7588652482269503
# Native avg=2.595, stdev=0.462
# fraction 0.995, idx 964.15, ref limit=4.069
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8796718322698268, 0.9948453608247423, 0.9337203676826318)
# n = 1271  accuracy = 0.8922108575924469
# confusion matrix: tn, fp, fn, tp [169 132   5 965]
# Predict majority: accuracy= 0.7631785995279308
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8454545454545455, 0.8454545454545455, 0.8454545454545455)
# n = 141  accuracy = 0.7588652482269503
# confusion matrix: tn, fp, fn, tp [14 17 17 93]
# Predict majority: accuracy= 0.7801418439716312
# Native avg=2.614, stdev=0.464
# fraction 0.995, idx 965.15, ref limit=4.067
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8789808917197452, 0.9948506694129763, 0.9333333333333333)
# n = 1271  accuracy = 0.8914240755310779
# confusion matrix: tn, fp, fn, tp [167 133   5 966]
# Predict majority: accuracy= 0.7639653815892997
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8688524590163934, 0.9724770642201835, 0.9177489177489178)
# n = 141  accuracy = 0.8652482269503546
# confusion matrix: tn, fp, fn, tp [ 16  16   3 106]
# Predict majority: accuracy= 0.7730496453900709
# Native avg=2.602, stdev=0.455
# fraction 0.995, idx 967.14, ref limit=3.998
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8832116788321168, 0.9948612538540597, 0.9357177380376994)
# n = 1271  accuracy = 0.8953579858379229
# confusion matrix: tn, fp, fn, tp [170 128   5 968]
# Predict majority: accuracy= 0.7655389457120377
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9074074074074074, 0.9158878504672897, 0.9116279069767442)
# n = 141  accuracy = 0.8652482269503546
# confusion matrix: tn, fp, fn, tp [24 10  9 98]
# Predict majority: accuracy= 0.7588652482269503
# Native avg=2.599, stdev=0.461
# fraction 0.995, idx 975.10, ref limit=4.038
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8880800727934486, 0.9949031600407747, 0.9384615384615385)
# n = 1271  accuracy = 0.8992918961447679
# confusion matrix: tn, fp, fn, tp [167 123   5 976]
# Predict majority: accuracy= 0.7718332022029898
#
# * TEST RESULTS *
# precision, recall, F1 = (0.7857142857142857, 0.8888888888888888, 0.8341232227488152)
# n = 141  accuracy = 0.75177304964539
# confusion matrix: tn, fp, fn, tp [18 24 11 88]
# Predict majority: accuracy= 0.7021276595744681
# Native avg=2.605, stdev=0.447
# fraction 0.995, idx 964.15, ref limit=3.969
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8861340679522498, 0.9948453608247423, 0.9373482272948034)
# n = 1271  accuracy = 0.898505114083399
# confusion matrix: tn, fp, fn, tp [177 124   5 965]
# Predict majority: accuracy= 0.7631785995279308
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9, 0.9, 0.9)
# n = 141  accuracy = 0.8439716312056738
# confusion matrix: tn, fp, fn, tp [20 11 11 99]
# Predict majority: accuracy= 0.7801418439716312
#
#             Acc   Maj_acc      Prec    Recall        F1
# Mean   0.807347  0.764859  0.867365  0.883184  0.874476
# StDev  0.047299  0.029343  0.040200  0.045037  0.033512
#
# Qeqchi
# Native avg=2.771, stdev=0.472
# fraction 0.995, idx 1503.44, ref limit=4.309
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9043896572459411, 0.9947089947089947, 0.9474015748031496)
# n = 1795  accuracy = 0.9069637883008357
# confusion matrix: tn, fp, fn, tp [ 124  159    8 1504]
# Predict majority: accuracy= 0.8423398328690808
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9428571428571428, 0.9482758620689655, 0.9455587392550143)
# n = 200  accuracy = 0.905
# confusion matrix: tn, fp, fn, tp [ 16  10   9 165]
# Predict majority: accuracy= 0.87
# Native avg=2.771, stdev=0.475
# fraction 0.995, idx 1508.42, ref limit=4.457
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9019725044829647, 0.994726433750824, 0.9460815047021944)
# n = 1795  accuracy = 0.9041782729805014
# confusion matrix: tn, fp, fn, tp [ 114  164    8 1509]
# Predict majority: accuracy= 0.8451253481894151
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8804347826086957, 0.9585798816568047, 0.9178470254957507)
# n = 200  accuracy = 0.855
# confusion matrix: tn, fp, fn, tp [  9  22   7 162]
# Predict majority: accuracy= 0.845
# Native avg=2.774, stdev=0.467
# fraction 0.995, idx 1504.44, ref limit=4.428
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.899581589958159, 0.9947124917382684, 0.9447583176396736)
# n = 1795  accuracy = 0.901949860724234
# confusion matrix: tn, fp, fn, tp [ 114  168    8 1505]
# Predict majority: accuracy= 0.8428969359331476
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9265536723163842, 0.9479768786127167, 0.9371428571428572)
# n = 200  accuracy = 0.89
# confusion matrix: tn, fp, fn, tp [ 14  13   9 164]
# Predict majority: accuracy= 0.865
# Native avg=2.773, stdev=0.459
# fraction 0.995, idx 1510.41, ref limit=4.411
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9020895522388059, 0.9947333772218565, 0.9461490294301815)
# n = 1795  accuracy = 0.9041782729805014
# confusion matrix: tn, fp, fn, tp [ 112  164    8 1511]
# Predict majority: accuracy= 0.8462395543175487
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8908045977011494, 0.9281437125748503, 0.909090909090909)
# n = 200  accuracy = 0.845
# confusion matrix: tn, fp, fn, tp [ 14  19  12 155]
# Predict majority: accuracy= 0.835
# Native avg=2.770, stdev=0.461
# fraction 0.995, idx 1507.42, ref limit=4.538
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8948931116389549, 0.9940633245382586, 0.941875)
# n = 1795  accuracy = 0.8963788300835654
# confusion matrix: tn, fp, fn, tp [ 102  177    9 1507]
# Predict majority: accuracy= 0.8445682451253482
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9075144508670521, 0.9235294117647059, 0.9154518950437318)
# n = 200  accuracy = 0.855
# confusion matrix: tn, fp, fn, tp [ 14  16  13 157]
# Predict majority: accuracy= 0.85
# Native avg=2.763, stdev=0.461
# fraction 0.995, idx 1506.43, ref limit=4.327
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9055923030667469, 0.994059405940594, 0.9477658904971681)
# n = 1796  accuracy = 0.9075723830734966
# confusion matrix: tn, fp, fn, tp [ 124  157    9 1506]
# Predict majority: accuracy= 0.8435412026726058
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9207317073170732, 0.8830409356725146, 0.9014925373134329)
# n = 199  accuracy = 0.8341708542713567
# confusion matrix: tn, fp, fn, tp [ 15  13  20 151]
# Predict majority: accuracy= 0.8592964824120602
# Native avg=2.767, stdev=0.462
# fraction 0.995, idx 1518.37, ref limit=4.446
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9074074074074074, 0.9947609692206941, 0.9490784129959386)
# n = 1796  accuracy = 0.9092427616926503
# confusion matrix: tn, fp, fn, tp [ 114  155    8 1519]
# Predict majority: accuracy= 0.8502227171492205
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8421052631578947, 0.9056603773584906, 0.8727272727272727)
# n = 199  accuracy = 0.7889447236180904
# confusion matrix: tn, fp, fn, tp [ 13  27  15 144]
# Predict majority: accuracy= 0.7989949748743719
# Native avg=2.768, stdev=0.463
# fraction 0.995, idx 1508.42, ref limit=4.536
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8992248062015504, 0.994067237969677, 0.9442705072010019)
# n = 1796  accuracy = 0.9008908685968819
# confusion matrix: tn, fp, fn, tp [ 110  169    9 1508]
# Predict majority: accuracy= 0.8446547884187082
#
# * TEST RESULTS *
# precision, recall, F1 = (0.888268156424581, 0.9408284023668639, 0.9137931034482758)
# n = 199  accuracy = 0.8492462311557789
# confusion matrix: tn, fp, fn, tp [ 10  20  10 159]
# Predict majority: accuracy= 0.8492462311557789
# Native avg=2.765, stdev=0.468
# fraction 0.995, idx 1509.41, ref limit=4.475
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9009546539379475, 0.994729907773386, 0.9455228553537883)
# n = 1796  accuracy = 0.9031180400890868
# confusion matrix: tn, fp, fn, tp [ 112  166    8 1510]
# Predict majority: accuracy= 0.8452115812917594
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9022988505747126, 0.9345238095238095, 0.9181286549707602)
# n = 199  accuracy = 0.8592964824120602
# confusion matrix: tn, fp, fn, tp [ 14  17  11 157]
# Predict majority: accuracy= 0.8442211055276382
# Native avg=2.759, stdev=0.472
# fraction 0.995, idx 1511.40, ref limit=4.528
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9020895522388059, 0.9940789473684211, 0.9458528951486698)
# n = 1796  accuracy = 0.9036748329621381
# confusion matrix: tn, fp, fn, tp [ 112  164    9 1511]
# Predict majority: accuracy= 0.8463251670378619
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8722222222222222, 0.9457831325301205, 0.9075144508670521)
# n = 199  accuracy = 0.8391959798994975
# confusion matrix: tn, fp, fn, tp [ 10  23   9 157]
# Predict majority: accuracy= 0.8341708542713567
#
#             Acc   Maj_acc      Prec    Recall        F1
# Mean   0.852085  0.845093  0.897379  0.931634  0.913875
# StDev  0.031338  0.020019  0.029237  0.022796  0.019696
#
# Wichi
# Native avg=2.556, stdev=0.424
# fraction 0.995, idx 1035.80, ref limit=3.879
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9452554744525548, 0.9942418426103646, 0.9691300280636109)
# n = 1224  accuracy = 0.946078431372549
# confusion matrix: tn, fp, fn, tp [ 122   60    6 1036]
# Predict majority: accuracy= 0.8513071895424836
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9065420560747663, 0.8660714285714286, 0.8858447488584474)
# n = 137  accuracy = 0.8175182481751825
# confusion matrix: tn, fp, fn, tp [15 10 15 97]
# Predict majority: accuracy= 0.8175182481751825
# Native avg=2.570, stdev=0.434
# fraction 0.995, idx 1035.80, ref limit=3.980
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9333333333333333, 0.9942418426103646, 0.9628252788104089)
# n = 1225  accuracy = 0.9346938775510204
# confusion matrix: tn, fp, fn, tp [ 109   74    6 1036]
# Predict majority: accuracy= 0.8506122448979592
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9478260869565217, 0.9732142857142857, 0.960352422907489)
# n = 136  accuracy = 0.9338235294117647
# confusion matrix: tn, fp, fn, tp [ 18   6   3 109]
# Predict majority: accuracy= 0.8235294117647058
# Native avg=2.575, stdev=0.429
# fraction 0.995, idx 1031.82, ref limit=3.992
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9339366515837104, 0.9942196531791907, 0.9631357909472702)
# n = 1225  accuracy = 0.9355102040816327
# confusion matrix: tn, fp, fn, tp [ 114   73    6 1032]
# Predict majority: accuracy= 0.8473469387755102
#
# * TEST RESULTS *
# precision, recall, F1 = (0.940677966101695, 0.9568965517241379, 0.9487179487179486)
# n = 136  accuracy = 0.9117647058823529
# confusion matrix: tn, fp, fn, tp [ 13   7   5 111]
# Predict majority: accuracy= 0.8529411764705882
# Native avg=2.565, stdev=0.428
# fraction 0.995, idx 1031.82, ref limit=3.957
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9390354868061874, 0.9942196531791907, 0.9658399625643425)
# n = 1225  accuracy = 0.9404081632653061
# confusion matrix: tn, fp, fn, tp [ 120   67    6 1032]
# Predict majority: accuracy= 0.8473469387755102
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9375, 0.9051724137931034, 0.9210526315789473)
# n = 136  accuracy = 0.8676470588235294
# confusion matrix: tn, fp, fn, tp [ 13   7  11 105]
# Predict majority: accuracy= 0.8529411764705882
# Native avg=2.565, stdev=0.437
# fraction 0.995, idx 1031.82, ref limit=3.944
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9364791288566243, 0.9942196531791907, 0.9644859813084111)
# n = 1225  accuracy = 0.9379591836734694
# confusion matrix: tn, fp, fn, tp [ 117   70    6 1032]
# Predict majority: accuracy= 0.8473469387755102
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9401709401709402, 0.9482758620689655, 0.944206008583691)
# n = 136  accuracy = 0.9044117647058824
# confusion matrix: tn, fp, fn, tp [ 13   7   6 110]
# Predict majority: accuracy= 0.8529411764705882
# Native avg=2.572, stdev=0.429
# fraction 0.995, idx 1031.82, ref limit=3.946
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9398907103825137, 0.9942196531791907, 0.9662921348314607)
# n = 1225  accuracy = 0.9412244897959183
# confusion matrix: tn, fp, fn, tp [ 121   66    6 1032]
# Predict majority: accuracy= 0.8473469387755102
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9083333333333333, 0.9396551724137931, 0.9237288135593221)
# n = 136  accuracy = 0.8676470588235294
# confusion matrix: tn, fp, fn, tp [  9  11   7 109]
# Predict majority: accuracy= 0.8529411764705882
# Native avg=2.560, stdev=0.429
# fraction 0.995, idx 1022.86, ref limit=3.954
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9333941605839416, 0.9941690962099126, 0.9628235294117646)
# n = 1225  accuracy = 0.9355102040816327
# confusion matrix: tn, fp, fn, tp [ 123   73    6 1023]
# Predict majority: accuracy= 0.84
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9831932773109243, 0.936, 0.959016393442623)
# n = 136  accuracy = 0.9264705882352942
# confusion matrix: tn, fp, fn, tp [  9   2   8 117]
# Predict majority: accuracy= 0.9191176470588235
# Native avg=2.564, stdev=0.432
# fraction 0.995, idx 1032.81, ref limit=3.939
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9373865698729582, 0.9942252165543792, 0.9649696403549743)
# n = 1225  accuracy = 0.9387755102040817
# confusion matrix: tn, fp, fn, tp [ 117   69    6 1033]
# Predict majority: accuracy= 0.8481632653061224
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9316239316239316, 0.9478260869565217, 0.939655172413793)
# n = 136  accuracy = 0.8970588235294118
# confusion matrix: tn, fp, fn, tp [ 13   8   6 109]
# Predict majority: accuracy= 0.8455882352941176
# Native avg=2.567, stdev=0.423
# fraction 0.995, idx 1033.81, ref limit=3.901
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.94, 0.9942307692307693, 0.9663551401869159)
# n = 1225  accuracy = 0.9412244897959183
# confusion matrix: tn, fp, fn, tp [ 119   66    6 1034]
# Predict majority: accuracy= 0.8489795918367347
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9224137931034483, 0.9385964912280702, 0.9304347826086956)
# n = 136  accuracy = 0.8823529411764706
# confusion matrix: tn, fp, fn, tp [ 13   9   7 107]
# Predict majority: accuracy= 0.8382352941176471
# Native avg=2.567, stdev=0.434
# fraction 0.995, idx 1035.80, ref limit=4.027
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9316546762589928, 0.9942418426103646, 0.9619312906220984)
# n = 1225  accuracy = 0.9330612244897959
# confusion matrix: tn, fp, fn, tp [ 107   76    6 1036]
# Predict majority: accuracy= 0.8506122448979592
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9217391304347826, 0.9464285714285714, 0.9339207048458149)
# n = 136  accuracy = 0.8897058823529411
# confusion matrix: tn, fp, fn, tp [ 15   9   6 106]
# Predict majority: accuracy= 0.8235294117647058
#
#             Acc   Maj_acc      Prec    Recall        F1
# Mean   0.889840  0.847928  0.934002  0.935814  0.934693
# StDev  0.033818  0.028642  0.022133  0.029965  0.021789

# %%
# Test k-fold native basis word discrimination - Based on segmented IPA (segments).
# No interest in return table of k-fold trials, thus the _ return value.
for l in languages:
    _ = k_fold_language_word_discrimination_native_basis(l, form='segments', smoothing=0.5, k_fold=10, p=.995)
# Out:
# English
# Native avg=2.683, stdev=0.414
# fraction 0.995, idx 784.06, ref limit=3.949
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8151609553478713, 0.9949302915082383, 0.8961187214611872)
# n = 1364  accuracy = 0.8665689149560117
# confusion matrix: tn, fp, fn, tp [397 178   4 785]
# Predict majority: accuracy= 0.5784457478005866
#
# * TEST RESULTS *
# precision, recall, F1 = (0.6219512195121951, 0.6071428571428571, 0.6144578313253012)
# n = 152  accuracy = 0.5789473684210527
# confusion matrix: tn, fp, fn, tp [37 31 33 51]
# Predict majority: accuracy= 0.5526315789473685
# Native avg=2.680, stdev=0.424
# fraction 0.995, idx 778.09, ref limit=3.990
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.798155737704918, 0.9948914431673053, 0.885730528709494)
# n = 1364  accuracy = 0.8526392961876833
# confusion matrix: tn, fp, fn, tp [384 197   4 779]
# Predict majority: accuracy= 0.5740469208211144
#
# * TEST RESULTS *
# precision, recall, F1 = (0.7532467532467533, 0.6444444444444445, 0.6946107784431139)
# n = 152  accuracy = 0.6644736842105263
# confusion matrix: tn, fp, fn, tp [43 19 32 58]
# Predict majority: accuracy= 0.5921052631578947
# Native avg=2.672, stdev=0.423
# fraction 0.995, idx 776.10, ref limit=3.915
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.821353065539112, 0.9948783610755442, 0.8998262883613202)
# n = 1364  accuracy = 0.8731671554252199
# confusion matrix: tn, fp, fn, tp [414 169   4 777]
# Predict majority: accuracy= 0.5725806451612904
#
# * TEST RESULTS *
# precision, recall, F1 = (0.7536231884057971, 0.5652173913043478, 0.6459627329192545)
# n = 152  accuracy = 0.625
# confusion matrix: tn, fp, fn, tp [43 17 40 52]
# Predict majority: accuracy= 0.6052631578947368
# Native avg=2.674, stdev=0.421
# fraction 0.995, idx 788.04, ref limit=3.827
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8366914103923648, 0.9949558638083228, 0.9089861751152073)
# n = 1364  accuracy = 0.8841642228739003
# confusion matrix: tn, fp, fn, tp [417 154   4 789]
# Predict majority: accuracy= 0.5813782991202346
#
# * TEST RESULTS *
# precision, recall, F1 = (0.7258064516129032, 0.5625, 0.6338028169014084)
# n = 152  accuracy = 0.6578947368421053
# confusion matrix: tn, fp, fn, tp [55 17 35 45]
# Predict majority: accuracy= 0.5263157894736842
# Native avg=2.670, stdev=0.426
# fraction 0.995, idx 781.08, ref limit=3.960
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8078512396694215, 0.9949109414758269, 0.8916761687571265)
# n = 1364  accuracy = 0.8607038123167156
# confusion matrix: tn, fp, fn, tp [392 186   4 782]
# Predict majority: accuracy= 0.5762463343108505
#
# * TEST RESULTS *
# precision, recall, F1 = (0.7142857142857143, 0.5747126436781609, 0.6369426751592356)
# n = 152  accuracy = 0.625
# confusion matrix: tn, fp, fn, tp [45 20 37 50]
# Predict majority: accuracy= 0.5723684210526315
# Native avg=2.677, stdev=0.429
# fraction 0.995, idx 784.06, ref limit=3.993
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.795339412360689, 0.9949302915082383, 0.884009009009009)
# n = 1364  accuracy = 0.8489736070381232
# confusion matrix: tn, fp, fn, tp [373 202   4 785]
# Predict majority: accuracy= 0.5784457478005866
#
# * TEST RESULTS *
# precision, recall, F1 = (0.6666666666666666, 0.5714285714285714, 0.6153846153846153)
# n = 152  accuracy = 0.6052631578947368
# confusion matrix: tn, fp, fn, tp [44 24 36 48]
# Predict majority: accuracy= 0.5526315789473685
# Native avg=2.670, stdev=0.422
# fraction 0.995, idx 783.06, ref limit=3.940
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8243953732912723, 0.9949238578680203, 0.9016676250718804)
# n = 1365  accuracy = 0.8747252747252747
# confusion matrix: tn, fp, fn, tp [410 167   4 784]
# Predict majority: accuracy= 0.5772893772893772
#
# * TEST RESULTS *
# precision, recall, F1 = (0.647887323943662, 0.5411764705882353, 0.5897435897435898)
# n = 151  accuracy = 0.5761589403973509
# confusion matrix: tn, fp, fn, tp [41 25 39 46]
# Predict majority: accuracy= 0.5629139072847682
# Native avg=2.678, stdev=0.419
# fraction 0.995, idx 778.09, ref limit=3.917
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8097713097713097, 0.9948914431673053, 0.8928366762177651)
# n = 1365  accuracy = 0.863003663003663
# confusion matrix: tn, fp, fn, tp [399 183   4 779]
# Predict majority: accuracy= 0.5736263736263736
#
# * TEST RESULTS *
# precision, recall, F1 = (0.803030303030303, 0.5888888888888889, 0.6794871794871795)
# n = 151  accuracy = 0.6688741721854304
# confusion matrix: tn, fp, fn, tp [48 13 37 53]
# Predict majority: accuracy= 0.5960264900662252
# Native avg=2.667, stdev=0.424
# fraction 0.995, idx 765.15, ref limit=3.858
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8114406779661016, 0.9948051948051948, 0.8938156359393232)
# n = 1365  accuracy = 0.8666666666666667
# confusion matrix: tn, fp, fn, tp [417 178   4 766]
# Predict majority: accuracy= 0.5641025641025641
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8852459016393442, 0.5242718446601942, 0.6585365853658537)
# n = 151  accuracy = 0.6291390728476821
# confusion matrix: tn, fp, fn, tp [41  7 49 54]
# Predict majority: accuracy= 0.6821192052980133
# Native avg=2.676, stdev=0.424
# fraction 0.995, idx 790.03, ref limit=3.952
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8163054695562435, 0.9949685534591195, 0.8968253968253969)
# n = 1365  accuracy = 0.8666666666666667
# confusion matrix: tn, fp, fn, tp [392 178   4 791]
# Predict majority: accuracy= 0.5824175824175825
#
# * TEST RESULTS *
# precision, recall, F1 = (0.6282051282051282, 0.6282051282051282, 0.6282051282051282)
# n = 151  accuracy = 0.6158940397350994
# confusion matrix: tn, fp, fn, tp [44 29 29 49]
# Predict majority: accuracy= 0.5165562913907285
#
#             Acc   Maj_acc      Prec    Recall        F1
# Mean   0.624665  0.575893  0.719995  0.580799  0.639713
# StDev  0.032592  0.047207  0.083391  0.037305  0.031430
#
# Hup
# Native avg=2.432, stdev=0.448
# fraction 0.995, idx 925.35, ref limit=3.710
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9645833333333333, 0.9946294307196563, 0.9793759915388682)
# n = 1061  accuracy = 0.9632422243166824
# confusion matrix: tn, fp, fn, tp [ 96  34   5 926]
# Predict majority: accuracy= 0.8774740810556079
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9382716049382716, 0.7307692307692307, 0.8216216216216217)
# n = 118  accuracy = 0.7203389830508474
# confusion matrix: tn, fp, fn, tp [ 9  5 28 76]
# Predict majority: accuracy= 0.8813559322033898
# Native avg=2.427, stdev=0.456
# fraction 0.995, idx 925.35, ref limit=3.835
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9605809128630706, 0.9946294307196563, 0.9773087071240105)
# n = 1061  accuracy = 0.9594721960414703
# confusion matrix: tn, fp, fn, tp [ 92  38   5 926]
# Predict majority: accuracy= 0.8774740810556079
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9404761904761905, 0.7596153846153846, 0.8404255319148936)
# n = 118  accuracy = 0.7457627118644068
# confusion matrix: tn, fp, fn, tp [ 9  5 25 79]
# Predict majority: accuracy= 0.8813559322033898
# Native avg=2.430, stdev=0.449
# fraction 0.995, idx 929.33, ref limit=3.786
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9647302904564315, 0.9946524064171123, 0.9794628751974723)
# n = 1061  accuracy = 0.9632422243166824
# confusion matrix: tn, fp, fn, tp [ 92  34   5 930]
# Predict majority: accuracy= 0.88124410933082
#
# * TEST RESULTS *
# precision, recall, F1 = (0.961038961038961, 0.74, 0.8361581920903954)
# n = 118  accuracy = 0.7542372881355932
# confusion matrix: tn, fp, fn, tp [15  3 26 74]
# Predict majority: accuracy= 0.847457627118644
# Native avg=2.413, stdev=0.454
# fraction 0.995, idx 923.36, ref limit=3.779
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9675392670157068, 0.9946178686759957, 0.9808917197452229)
# n = 1061  accuracy = 0.9660697455230914
# confusion matrix: tn, fp, fn, tp [101  31   5 924]
# Predict majority: accuracy= 0.8755890669180019
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9620253164556962, 0.7169811320754716, 0.8216216216216216)
# n = 118  accuracy = 0.7203389830508474
# confusion matrix: tn, fp, fn, tp [ 9  3 30 76]
# Predict majority: accuracy= 0.8983050847457628
# Native avg=2.428, stdev=0.457
# fraction 0.995, idx 926.35, ref limit=3.852
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9626168224299065, 0.9946351931330472, 0.9783641160949867)
# n = 1061  accuracy = 0.9613572101790764
# confusion matrix: tn, fp, fn, tp [ 93  36   5 927]
# Predict majority: accuracy= 0.8784165881244109
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9431818181818182, 0.8058252427184466, 0.8691099476439791)
# n = 118  accuracy = 0.788135593220339
# confusion matrix: tn, fp, fn, tp [10  5 20 83]
# Predict majority: accuracy= 0.8728813559322034
# Native avg=2.433, stdev=0.456
# fraction 0.995, idx 924.36, ref limit=3.852
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9575569358178054, 0.9946236559139785, 0.9757383966244727)
# n = 1061  accuracy = 0.9566446748350612
# confusion matrix: tn, fp, fn, tp [ 90  41   5 925]
# Predict majority: accuracy= 0.8765315739868049
#
# * TEST RESULTS *
# precision, recall, F1 = (0.963855421686747, 0.7619047619047619, 0.8510638297872339)
# n = 118  accuracy = 0.7627118644067796
# confusion matrix: tn, fp, fn, tp [10  3 25 80]
# Predict majority: accuracy= 0.8898305084745762
# Native avg=2.433, stdev=0.454
# fraction 0.995, idx 921.37, ref limit=3.882
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.953464322647363, 0.9946062567421791, 0.9736008447729673)
# n = 1061  accuracy = 0.9528746465598492
# confusion matrix: tn, fp, fn, tp [ 89  45   5 922]
# Predict majority: accuracy= 0.8737040527803959
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9425287356321839, 0.7592592592592593, 0.841025641025641)
# n = 118  accuracy = 0.7372881355932204
# confusion matrix: tn, fp, fn, tp [ 5  5 26 82]
# Predict majority: accuracy= 0.9152542372881356
# Native avg=2.433, stdev=0.446
# fraction 0.995, idx 927.34, ref limit=3.827
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9596690796277145, 0.9946409431939979, 0.9768421052631578)
# n = 1061  accuracy = 0.9585296889726673
# confusion matrix: tn, fp, fn, tp [ 89  39   5 928]
# Predict majority: accuracy= 0.879359095193214
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9634146341463414, 0.7745098039215687, 0.8586956521739132)
# n = 118  accuracy = 0.7796610169491526
# confusion matrix: tn, fp, fn, tp [13  3 23 79]
# Predict majority: accuracy= 0.864406779661017
# Native avg=2.422, stdev=0.466
# fraction 0.995, idx 927.34, ref limit=3.885
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9606625258799172, 0.9946409431939979, 0.9773565034228542)
# n = 1061  accuracy = 0.9594721960414703
# confusion matrix: tn, fp, fn, tp [ 90  38   5 928]
# Predict majority: accuracy= 0.879359095193214
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9411764705882353, 0.7843137254901961, 0.8556149732620321)
# n = 118  accuracy = 0.7711864406779662
# confusion matrix: tn, fp, fn, tp [11  5 22 80]
# Predict majority: accuracy= 0.864406779661017
# Native avg=2.423, stdev=0.463
# fraction 0.995, idx 928.34, ref limit=3.914
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9607032057911065, 0.9946466809421841, 0.9773803261441346)
# n = 1062  accuracy = 0.9595103578154426
# confusion matrix: tn, fp, fn, tp [ 90  38   5 929]
# Predict majority: accuracy= 0.879472693032015
#
# * TEST RESULTS *
# precision, recall, F1 = (0.927710843373494, 0.7623762376237624, 0.8369565217391305)
# n = 117  accuracy = 0.7435897435897436
# confusion matrix: tn, fp, fn, tp [10  6 24 77]
# Predict majority: accuracy= 0.8632478632478633
#
#             Acc   Maj_acc      Prec    Recall        F1
# Mean   0.752325  0.877850  0.948368  0.759555  0.843229
# StDev  0.023306  0.019745  0.012983  0.025852  0.015491
#
# ImbaburaQuechua
# Native avg=2.362, stdev=0.479
# fraction 0.995, idx 836.79, ref limit=3.829
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8829113924050633, 0.994061757719715, 0.9351955307262569)
# n = 1187  accuracy = 0.9022746419545071
# confusion matrix: tn, fp, fn, tp [234 111   5 837]
# Predict majority: accuracy= 0.7093513058129739
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9120879120879121, 0.9222222222222223, 0.9171270718232044)
# n = 132  accuracy = 0.8863636363636364
# confusion matrix: tn, fp, fn, tp [34  8  7 83]
# Predict majority: accuracy= 0.6818181818181818
# Native avg=2.364, stdev=0.479
# fraction 0.995, idx 830.83, ref limit=3.746
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8925886143931256, 0.9940191387559809, 0.9405772495755518)
# n = 1187  accuracy = 0.9115417017691659
# confusion matrix: tn, fp, fn, tp [251 100   5 831]
# Predict majority: accuracy= 0.7042965459140691
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8571428571428571, 0.9375, 0.8955223880597014)
# n = 132  accuracy = 0.8409090909090909
# confusion matrix: tn, fp, fn, tp [21 15  6 90]
# Predict majority: accuracy= 0.7272727272727273
# Native avg=2.371, stdev=0.468
# fraction 0.995, idx 838.78, ref limit=3.721
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.888771186440678, 0.9940758293838863, 0.9384787472035795)
# n = 1187  accuracy = 0.9073294018534119
# confusion matrix: tn, fp, fn, tp [238 105   5 839]
# Predict majority: accuracy= 0.7110362257792755
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8804347826086957, 0.9204545454545454, 0.8999999999999999)
# n = 132  accuracy = 0.8636363636363636
# confusion matrix: tn, fp, fn, tp [33 11  7 81]
# Predict majority: accuracy= 0.6666666666666666
# Native avg=2.370, stdev=0.471
# fraction 0.995, idx 826.85, ref limit=3.796
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.889247311827957, 0.9939903846153846, 0.938706015891033)
# n = 1187  accuracy = 0.9090143218197135
# confusion matrix: tn, fp, fn, tp [252 103   5 827]
# Predict majority: accuracy= 0.7009267059814659
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8666666666666667, 0.91, 0.8878048780487805)
# n = 132  accuracy = 0.8257575757575758
# confusion matrix: tn, fp, fn, tp [18 14  9 91]
# Predict majority: accuracy= 0.7575757575757576
# Native avg=2.364, stdev=0.474
# fraction 0.995, idx 838.78, ref limit=3.767
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8897136797454931, 0.9940758293838863, 0.9390039171796307)
# n = 1187  accuracy = 0.9081718618365627
# confusion matrix: tn, fp, fn, tp [239 104   5 839]
# Predict majority: accuracy= 0.7110362257792755
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8617021276595744, 0.9204545454545454, 0.8901098901098901)
# n = 132  accuracy = 0.8484848484848485
# confusion matrix: tn, fp, fn, tp [31 13  7 81]
# Predict majority: accuracy= 0.6666666666666666
# Native avg=2.369, stdev=0.459
# fraction 0.995, idx 836.79, ref limit=3.751
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.883843717001056, 0.994061757719715, 0.9357182783678033)
# n = 1187  accuracy = 0.9031171019376579
# confusion matrix: tn, fp, fn, tp [235 110   5 837]
# Predict majority: accuracy= 0.7093513058129739
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8888888888888888, 0.8888888888888888, 0.8888888888888888)
# n = 132  accuracy = 0.8484848484848485
# confusion matrix: tn, fp, fn, tp [32 10 10 80]
# Predict majority: accuracy= 0.6818181818181818
# Native avg=2.372, stdev=0.474
# fraction 0.995, idx 834.80, ref limit=3.776
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8845338983050848, 0.9940476190476191, 0.9360986547085203)
# n = 1187  accuracy = 0.9039595619208087
# confusion matrix: tn, fp, fn, tp [238 109   5 835]
# Predict majority: accuracy= 0.7076663858466723
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9032258064516129, 0.9130434782608695, 0.9081081081081082)
# n = 132  accuracy = 0.8712121212121212
# confusion matrix: tn, fp, fn, tp [31  9  8 84]
# Predict majority: accuracy= 0.696969696969697
# Native avg=2.366, stdev=0.478
# fraction 0.995, idx 837.79, ref limit=3.773
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8867724867724868, 0.9940688018979834, 0.9373601789709173)
# n = 1187  accuracy = 0.9056444818871103
# confusion matrix: tn, fp, fn, tp [237 107   5 838]
# Predict majority: accuracy= 0.7101937657961247
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8947368421052632, 0.9550561797752809, 0.9239130434782609)
# n = 132  accuracy = 0.8939393939393939
# confusion matrix: tn, fp, fn, tp [33 10  4 85]
# Predict majority: accuracy= 0.6742424242424242
# Native avg=2.356, stdev=0.475
# fraction 0.995, idx 832.81, ref limit=3.736
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8861702127659574, 0.9940334128878282, 0.937007874015748)
# n = 1187  accuracy = 0.9056444818871103
# confusion matrix: tn, fp, fn, tp [242 107   5 833]
# Predict majority: accuracy= 0.7059814658803707
#
# * TEST RESULTS *
# precision, recall, F1 = (0.86, 0.9148936170212766, 0.8865979381443299)
# n = 132  accuracy = 0.8333333333333334
# confusion matrix: tn, fp, fn, tp [24 14  8 86]
# Predict majority: accuracy= 0.7121212121212122
# Native avg=2.363, stdev=0.467
# fraction 0.995, idx 821.87, ref limit=3.742
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8857758620689655, 0.9939540507859734, 0.9367521367521368)
# n = 1188  accuracy = 0.9065656565656566
# confusion matrix: tn, fp, fn, tp [255 106   5 822]
# Predict majority: accuracy= 0.6961279461279462
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8921568627450981, 0.8666666666666667, 0.8792270531400966)
# n = 131  accuracy = 0.8091603053435115
# confusion matrix: tn, fp, fn, tp [15 11 14 91]
# Predict majority: accuracy= 0.8015267175572519
#
#             Acc   Maj_acc      Prec    Recall        F1
# Mean   0.852128  0.706668  0.881704  0.914918  0.897730
# StDev  0.026800  0.044253  0.019491  0.024196  0.014455
#
# Mapudungun
# Native avg=2.660, stdev=0.490
# fraction 0.995, idx 966.14, ref limit=4.181
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8945420906567992, 0.9948559670781894, 0.9420360448124696)
# n = 1270  accuracy = 0.9062992125984252
# confusion matrix: tn, fp, fn, tp [184 114   5 967]
# Predict majority: accuracy= 0.7653543307086614
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8627450980392157, 0.8148148148148148, 0.838095238095238)
# n = 142  accuracy = 0.7605633802816901
# confusion matrix: tn, fp, fn, tp [20 14 20 88]
# Predict majority: accuracy= 0.7605633802816901
# Native avg=2.671, stdev=0.488
# fraction 0.995, idx 963.16, ref limit=4.149
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8917668825161887, 0.9948400412796697, 0.9404878048780487)
# n = 1270  accuracy = 0.9039370078740158
# confusion matrix: tn, fp, fn, tp [184 117   5 964]
# Predict majority: accuracy= 0.7629921259842519
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8857142857142857, 0.8378378378378378, 0.8611111111111112)
# n = 142  accuracy = 0.7887323943661971
# confusion matrix: tn, fp, fn, tp [19 12 18 93]
# Predict majority: accuracy= 0.7816901408450704
# Native avg=2.664, stdev=0.490
# fraction 0.995, idx 959.18, ref limit=4.205
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8815426997245179, 0.9948186528497409, 0.934761441090555)
# n = 1271  accuracy = 0.8945712037765539
# confusion matrix: tn, fp, fn, tp [177 129   5 960]
# Predict majority: accuracy= 0.7592446892210858
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9065420560747663, 0.8434782608695652, 0.8738738738738738)
# n = 141  accuracy = 0.8014184397163121
# confusion matrix: tn, fp, fn, tp [16 10 18 97]
# Predict majority: accuracy= 0.8156028368794326
# Native avg=2.668, stdev=0.482
# fraction 0.995, idx 961.17, ref limit=4.059
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8973880597014925, 0.9948293691830403, 0.9435998038254045)
# n = 1271  accuracy = 0.9095200629425649
# confusion matrix: tn, fp, fn, tp [194 110   5 962]
# Predict majority: accuracy= 0.7608182533438238
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9150943396226415, 0.8584070796460177, 0.8858447488584474)
# n = 141  accuracy = 0.8226950354609929
# confusion matrix: tn, fp, fn, tp [19  9 16 97]
# Predict majority: accuracy= 0.8014184397163121
# Native avg=2.661, stdev=0.477
# fraction 0.995, idx 960.17, ref limit=4.154
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8840846366145354, 0.994824016563147, 0.9361909400876766)
# n = 1271  accuracy = 0.8969315499606609
# confusion matrix: tn, fp, fn, tp [179 126   5 961]
# Predict majority: accuracy= 0.7600314712824547
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9191919191919192, 0.7982456140350878, 0.8544600938967137)
# n = 141  accuracy = 0.7801418439716312
# confusion matrix: tn, fp, fn, tp [19  8 23 91]
# Predict majority: accuracy= 0.8085106382978723
# Native avg=2.677, stdev=0.489
# fraction 0.995, idx 960.17, ref limit=4.131
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8857142857142857, 0.994824016563147, 0.9371038517796196)
# n = 1271  accuracy = 0.898505114083399
# confusion matrix: tn, fp, fn, tp [181 124   5 961]
# Predict majority: accuracy= 0.7600314712824547
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9292035398230089, 0.9210526315789473, 0.9251101321585904)
# n = 141  accuracy = 0.8794326241134752
# confusion matrix: tn, fp, fn, tp [ 19   8   9 105]
# Predict majority: accuracy= 0.8085106382978723
# Native avg=2.664, stdev=0.492
# fraction 0.995, idx 971.12, ref limit=4.239
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.889295516925892, 0.9948822927328557, 0.9391304347826086)
# n = 1271  accuracy = 0.9008654602675059
# confusion matrix: tn, fp, fn, tp [173 121   5 972]
# Predict majority: accuracy= 0.7686860739575138
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8640776699029126, 0.8640776699029126, 0.8640776699029126)
# n = 141  accuracy = 0.8014184397163121
# confusion matrix: tn, fp, fn, tp [24 14 14 89]
# Predict majority: accuracy= 0.7304964539007093
# Native avg=2.676, stdev=0.479
# fraction 0.995, idx 973.11, ref limit=4.113
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8993536472760849, 0.9948927477017364, 0.9447138700290979)
# n = 1271  accuracy = 0.9103068450039339
# confusion matrix: tn, fp, fn, tp [183 109   5 974]
# Predict majority: accuracy= 0.7702596380802518
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8461538461538461, 0.8712871287128713, 0.8585365853658536)
# n = 141  accuracy = 0.7943262411347518
# confusion matrix: tn, fp, fn, tp [24 16 13 88]
# Predict majority: accuracy= 0.7163120567375887
# Native avg=2.670, stdev=0.491
# fraction 0.995, idx 974.11, ref limit=4.196
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8961397058823529, 0.9948979591836735, 0.9429400386847194)
# n = 1271  accuracy = 0.9071597167584579
# confusion matrix: tn, fp, fn, tp [178 113   5 975]
# Predict majority: accuracy= 0.7710464201416207
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8165137614678899, 0.89, 0.8516746411483254)
# n = 141  accuracy = 0.7801418439716312
# confusion matrix: tn, fp, fn, tp [21 20 11 89]
# Predict majority: accuracy= 0.7092198581560284
# Native avg=2.673, stdev=0.480
# fraction 0.995, idx 973.11, ref limit=4.072
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9026876737720111, 0.9948927477017364, 0.9465500485908649)
# n = 1271  accuracy = 0.9134539732494099
# confusion matrix: tn, fp, fn, tp [187 105   5 974]
# Predict majority: accuracy= 0.7702596380802518
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8148148148148148, 0.8712871287128713, 0.8421052631578947)
# n = 141  accuracy = 0.7659574468085106
# confusion matrix: tn, fp, fn, tp [20 20 13 88]
# Predict majority: accuracy= 0.7163120567375887
#
#             Acc   Maj_acc      Prec    Recall        F1
# Mean   0.797483  0.764864  0.876005  0.857049  0.865489
# StDev  0.034038  0.043480  0.041823  0.035643  0.025207
#
# Qeqchi
# Native avg=2.764, stdev=0.485
# fraction 0.995, idx 1509.41, ref limit=4.517
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9280442804428044, 0.9940711462450593, 0.9599236641221375)
# n = 1795  accuracy = 0.9298050139275766
# confusion matrix: tn, fp, fn, tp [ 160  117    9 1509]
# Predict majority: accuracy= 0.8456824512534818
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9135802469135802, 0.8809523809523809, 0.8969696969696969)
# n = 200  accuracy = 0.83
# confusion matrix: tn, fp, fn, tp [ 18  14  20 148]
# Predict majority: accuracy= 0.84
# Native avg=2.760, stdev=0.498
# fraction 0.995, idx 1507.42, ref limit=4.570
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.923973022685469, 0.9940633245382586, 0.957737527804258)
# n = 1795  accuracy = 0.9259052924791087
# confusion matrix: tn, fp, fn, tp [ 155  124    9 1507]
# Predict majority: accuracy= 0.8445682451253482
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9166666666666666, 0.9058823529411765, 0.9112426035502958)
# n = 200  accuracy = 0.85
# confusion matrix: tn, fp, fn, tp [ 16  14  16 154]
# Predict majority: accuracy= 0.85
# Native avg=2.754, stdev=0.494
# fraction 0.995, idx 1506.43, ref limit=4.433
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9313967861557478, 0.9947194719471947, 0.9620172358761571)
# n = 1795  accuracy = 0.9337047353760446
# confusion matrix: tn, fp, fn, tp [ 169  111    8 1507]
# Predict majority: accuracy= 0.8440111420612814
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9363057324840764, 0.8596491228070176, 0.8963414634146342)
# n = 200  accuracy = 0.83
# confusion matrix: tn, fp, fn, tp [ 19  10  24 147]
# Predict majority: accuracy= 0.855
# Native avg=2.760, stdev=0.496
# fraction 0.995, idx 1511.40, ref limit=4.499
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9287031346035648, 0.9940789473684211, 0.9602796313949793)
# n = 1795  accuracy = 0.9303621169916435
# confusion matrix: tn, fp, fn, tp [ 159  116    9 1511]
# Predict majority: accuracy= 0.8467966573816156
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9121621621621622, 0.8132530120481928, 0.8598726114649682)
# n = 200  accuracy = 0.78
# confusion matrix: tn, fp, fn, tp [ 21  13  31 135]
# Predict majority: accuracy= 0.83
# Native avg=2.763, stdev=0.496
# fraction 0.995, idx 1514.39, ref limit=4.496
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9323076923076923, 0.9947472094550229, 0.9625158831003812)
# n = 1795  accuracy = 0.9342618384401115
# confusion matrix: tn, fp, fn, tp [ 162  110    8 1515]
# Predict majority: accuracy= 0.8484679665738162
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8930817610062893, 0.8711656441717791, 0.8819875776397514)
# n = 200  accuracy = 0.81
# confusion matrix: tn, fp, fn, tp [ 20  17  21 142]
# Predict majority: accuracy= 0.815
# Native avg=2.759, stdev=0.497
# fraction 0.995, idx 1511.40, ref limit=4.506
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9287031346035648, 0.9940789473684211, 0.9602796313949793)
# n = 1796  accuracy = 0.9304008908685969
# confusion matrix: tn, fp, fn, tp [ 160  116    9 1511]
# Predict majority: accuracy= 0.8463251670378619
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9113924050632911, 0.8674698795180723, 0.8888888888888888)
# n = 199  accuracy = 0.8190954773869347
# confusion matrix: tn, fp, fn, tp [ 19  14  22 144]
# Predict majority: accuracy= 0.8341708542713567
# Native avg=2.756, stdev=0.505
# fraction 0.995, idx 1504.44, ref limit=4.500
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9266789895255699, 0.9940515532055518, 0.9591836734693878)
# n = 1796  accuracy = 0.9287305122494433
# confusion matrix: tn, fp, fn, tp [ 164  119    9 1504]
# Predict majority: accuracy= 0.8424276169265034
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9254658385093167, 0.861271676300578, 0.8922155688622754)
# n = 199  accuracy = 0.8190954773869347
# confusion matrix: tn, fp, fn, tp [ 14  12  24 149]
# Predict majority: accuracy= 0.8693467336683417
# Native avg=2.770, stdev=0.488
# fraction 0.995, idx 1506.43, ref limit=4.477
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9285274183610598, 0.9947194719471947, 0.9604843849585724)
# n = 1796  accuracy = 0.9309576837416481
# confusion matrix: tn, fp, fn, tp [ 165  116    8 1507]
# Predict majority: accuracy= 0.8435412026726058
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9386503067484663, 0.8947368421052632, 0.9161676646706587)
# n = 199  accuracy = 0.8592964824120602
# confusion matrix: tn, fp, fn, tp [ 18  10  18 153]
# Predict majority: accuracy= 0.8592964824120602
# Native avg=2.759, stdev=0.499
# fraction 0.995, idx 1513.39, ref limit=4.466
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9299754299754299, 0.9947437582128777, 0.9612698412698413)
# n = 1796  accuracy = 0.9320712694877505
# confusion matrix: tn, fp, fn, tp [ 160  114    8 1514]
# Predict majority: accuracy= 0.8474387527839644
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8987341772151899, 0.8658536585365854, 0.8819875776397516)
# n = 199  accuracy = 0.8090452261306532
# confusion matrix: tn, fp, fn, tp [ 19  16  22 142]
# Predict majority: accuracy= 0.8241206030150754
# Native avg=2.758, stdev=0.501
# fraction 0.995, idx 1503.44, ref limit=4.515
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9249692496924969, 0.9947089947089947, 0.9585723390694709)
# n = 1796  accuracy = 0.9276169265033407
# confusion matrix: tn, fp, fn, tp [ 162  122    8 1504]
# Predict majority: accuracy= 0.8418708240534521
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9470588235294117, 0.9252873563218391, 0.936046511627907)
# n = 199  accuracy = 0.8894472361809045
# confusion matrix: tn, fp, fn, tp [ 16   9  13 161]
# Predict majority: accuracy= 0.8743718592964824
#
#             Acc   Maj_acc      Prec    Recall        F1
# Mean   0.829598  0.845131  0.919310  0.874552  0.896172
# StDev  0.030491  0.019686  0.017435  0.030363  0.021099
#
# Wichi
# Native avg=2.601, stdev=0.458
# fraction 0.995, idx 1031.82, ref limit=4.009
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9467889908256881, 0.9942196531791907, 0.9699248120300752)
# n = 1224  accuracy = 0.9477124183006536
# confusion matrix: tn, fp, fn, tp [ 128   58    6 1032]
# Predict majority: accuracy= 0.8480392156862745
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9363636363636364, 0.8879310344827587, 0.9115044247787611)
# n = 137  accuracy = 0.8540145985401459
# confusion matrix: tn, fp, fn, tp [ 14   7  13 103]
# Predict majority: accuracy= 0.8467153284671532
# Native avg=2.601, stdev=0.455
# fraction 0.995, idx 1034.80, ref limit=4.026
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9504132231404959, 0.9942363112391931, 0.971830985915493)
# n = 1225  accuracy = 0.9510204081632653
# confusion matrix: tn, fp, fn, tp [ 130   54    6 1035]
# Predict majority: accuracy= 0.8497959183673469
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9065420560747663, 0.8584070796460177, 0.8818181818181818)
# n = 136  accuracy = 0.8088235294117647
# confusion matrix: tn, fp, fn, tp [13 10 16 97]
# Predict majority: accuracy= 0.8308823529411765
# Native avg=2.600, stdev=0.453
# fraction 0.995, idx 1030.82, ref limit=4.105
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9372727272727273, 0.9942140790742526, 0.9649040711277492)
# n = 1225  accuracy = 0.9387755102040817
# confusion matrix: tn, fp, fn, tp [ 119   69    6 1031]
# Predict majority: accuracy= 0.846530612244898
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9615384615384616, 0.8547008547008547, 0.9049773755656108)
# n = 136  accuracy = 0.8455882352941176
# confusion matrix: tn, fp, fn, tp [ 15   4  17 100]
# Predict majority: accuracy= 0.8602941176470589
# Native avg=2.593, stdev=0.453
# fraction 0.995, idx 1034.80, ref limit=4.017
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9556786703601108, 0.9942363112391931, 0.9745762711864407)
# n = 1225  accuracy = 0.9559183673469388
# confusion matrix: tn, fp, fn, tp [ 136   48    6 1035]
# Predict majority: accuracy= 0.8497959183673469
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9428571428571428, 0.8761061946902655, 0.9082568807339451)
# n = 136  accuracy = 0.8529411764705882
# confusion matrix: tn, fp, fn, tp [17  6 14 99]
# Predict majority: accuracy= 0.8308823529411765
# Native avg=2.595, stdev=0.446
# fraction 0.995, idx 1039.78, ref limit=3.985
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9576427255985267, 0.994263862332696, 0.9756097560975611)
# n = 1225  accuracy = 0.9575510204081633
# confusion matrix: tn, fp, fn, tp [ 133   46    6 1040]
# Predict majority: accuracy= 0.8538775510204082
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9183673469387755, 0.8333333333333334, 0.8737864077669903)
# n = 136  accuracy = 0.8088235294117647
# confusion matrix: tn, fp, fn, tp [20  8 18 90]
# Predict majority: accuracy= 0.7941176470588235
# Native avg=2.605, stdev=0.455
# fraction 0.995, idx 1033.81, ref limit=4.001
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9521178637200737, 0.9942307692307693, 0.9727187206020697)
# n = 1225  accuracy = 0.9526530612244898
# confusion matrix: tn, fp, fn, tp [ 133   52    6 1034]
# Predict majority: accuracy= 0.8489795918367347
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9304347826086956, 0.9385964912280702, 0.9344978165938864)
# n = 136  accuracy = 0.8897058823529411
# confusion matrix: tn, fp, fn, tp [ 14   8   7 107]
# Predict majority: accuracy= 0.8382352941176471
# Native avg=2.598, stdev=0.460
# fraction 0.995, idx 1026.84, ref limit=4.084
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9430670339761249, 0.9941916747337851, 0.9679547596606974)
# n = 1225  accuracy = 0.9444897959183673
# confusion matrix: tn, fp, fn, tp [ 130   62    6 1027]
# Predict majority: accuracy= 0.843265306122449
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9541284403669725, 0.859504132231405, 0.9043478260869566)
# n = 136  accuracy = 0.8382352941176471
# confusion matrix: tn, fp, fn, tp [ 10   5  17 104]
# Predict majority: accuracy= 0.8897058823529411
# Native avg=2.604, stdev=0.462
# fraction 0.995, idx 1028.83, ref limit=4.036
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9449035812672176, 0.9942028985507246, 0.9689265536723164)
# n = 1225  accuracy = 0.9461224489795919
# confusion matrix: tn, fp, fn, tp [ 130   60    6 1029]
# Predict majority: accuracy= 0.8448979591836735
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9482758620689655, 0.9243697478991597, 0.9361702127659575)
# n = 136  accuracy = 0.8897058823529411
# confusion matrix: tn, fp, fn, tp [ 11   6   9 110]
# Predict majority: accuracy= 0.875
# Native avg=2.600, stdev=0.460
# fraction 0.995, idx 1030.82, ref limit=4.076
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9415525114155251, 0.9942140790742526, 0.9671669793621014)
# n = 1225  accuracy = 0.9428571428571428
# confusion matrix: tn, fp, fn, tp [ 124   64    6 1031]
# Predict majority: accuracy= 0.846530612244898
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9459459459459459, 0.8974358974358975, 0.9210526315789475)
# n = 136  accuracy = 0.8676470588235294
# confusion matrix: tn, fp, fn, tp [ 13   6  12 105]
# Predict majority: accuracy= 0.8602941176470589
# Native avg=2.598, stdev=0.453
# fraction 0.995, idx 1031.82, ref limit=4.053
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9424657534246575, 0.9942196531791907, 0.9676511954992969)
# n = 1225  accuracy = 0.9436734693877551
# confusion matrix: tn, fp, fn, tp [ 124   63    6 1032]
# Predict majority: accuracy= 0.8473469387755102
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9809523809523809, 0.8879310344827587, 0.9321266968325793)
# n = 136  accuracy = 0.8897058823529411
# confusion matrix: tn, fp, fn, tp [ 18   2  13 103]
# Predict majority: accuracy= 0.8529411764705882
#
#             Acc   Maj_acc      Prec    Recall        F1
# Mean   0.854519  0.847907  0.942541  0.881832  0.910854
# StDev  0.030570  0.026628  0.021292  0.032520  0.021233

# %%
# Test k-fold native basis word discrimination - Based on segmented IPA (segments).
# No interest in return table of k-fold trials, thus the _ return value.
for l in languages:
    _ = k_fold_language_word_discrimination_native_basis(l, form='scas', smoothing=0.5, k_fold=10, p=.995)
# Out:
# Language=English, form=scas
# Native avg=2.547, stdev=0.422
# fraction 0.995, idx 782.07, ref limit=4.002
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.6264, 0.9949174078780177, 0.7687776141384388)
# n = 1364  accuracy = 0.6546920821114369
# confusion matrix: tn, fp, fn, tp [110 467   4 783]
# Predict majority: accuracy= 0.5769794721407625
#
# * TEST RESULTS *
# precision, recall, F1 = (0.5905511811023622, 0.872093023255814, 0.7042253521126759)
# n = 152  accuracy = 0.5855263157894737
# confusion matrix: tn, fp, fn, tp [14 52 11 75]
# Predict majority: accuracy= 0.5657894736842105
# Native avg=2.534, stdev=0.420
# fraction 0.995, idx 785.05, ref limit=4.062
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.6233148295003965, 0.9949367088607595, 0.7664553876157972)
# n = 1364  accuracy = 0.6488269794721407
# confusion matrix: tn, fp, fn, tp [ 99 475   4 786]
# Predict majority: accuracy= 0.5791788856304986
#
# * TEST RESULTS *
# precision, recall, F1 = (0.556390977443609, 0.891566265060241, 0.6851851851851851)
# n = 152  accuracy = 0.5526315789473685
# confusion matrix: tn, fp, fn, tp [10 59  9 74]
# Predict majority: accuracy= 0.5460526315789473
# Native avg=2.536, stdev=0.428
# fraction 0.995, idx 776.10, ref limit=4.119
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.6089341692789969, 0.9948783610755442, 0.7554691298006806)
# n = 1364  accuracy = 0.6312316715542522
# confusion matrix: tn, fp, fn, tp [ 84 499   4 777]
# Predict majority: accuracy= 0.5725806451612904
#
# * TEST RESULTS *
# precision, recall, F1 = (0.6204379562043796, 0.9239130434782609, 0.7423580786026202)
# n = 152  accuracy = 0.6118421052631579
# confusion matrix: tn, fp, fn, tp [ 8 52  7 85]
# Predict majority: accuracy= 0.6052631578947368
# Native avg=2.535, stdev=0.413
# fraction 0.995, idx 770.13, ref limit=3.939
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.621273166800967, 0.9948387096774194, 0.7648809523809523)
# n = 1364  accuracy = 0.6524926686217009
# confusion matrix: tn, fp, fn, tp [119 470   4 771]
# Predict majority: accuracy= 0.5681818181818182
#
# * TEST RESULTS *
# precision, recall, F1 = (0.6557377049180327, 0.8163265306122449, 0.7272727272727273)
# n = 152  accuracy = 0.6052631578947368
# confusion matrix: tn, fp, fn, tp [12 42 18 80]
# Predict majority: accuracy= 0.6447368421052632
# Native avg=2.540, stdev=0.420
# fraction 0.995, idx 787.04, ref limit=3.836
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.6365105008077544, 0.9949494949494949, 0.7763546798029556)
# n = 1364  accuracy = 0.6671554252199413
# confusion matrix: tn, fp, fn, tp [122 450   4 788]
# Predict majority: accuracy= 0.5806451612903226
#
# * TEST RESULTS *
# precision, recall, F1 = (0.5691056910569106, 0.8641975308641975, 0.6862745098039215)
# n = 152  accuracy = 0.5789473684210527
# confusion matrix: tn, fp, fn, tp [18 53 11 70]
# Predict majority: accuracy= 0.5328947368421053
# Native avg=2.542, stdev=0.422
# fraction 0.995, idx 792.02, ref limit=3.862
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.6400322841000807, 0.9949811794228356, 0.7789783889980353)
# n = 1364  accuracy = 0.6700879765395894
# confusion matrix: tn, fp, fn, tp [121 446   4 793]
# Predict majority: accuracy= 0.5843108504398827
#
# * TEST RESULTS *
# precision, recall, F1 = (0.5245901639344263, 0.8421052631578947, 0.6464646464646464)
# n = 152  accuracy = 0.5394736842105263
# confusion matrix: tn, fp, fn, tp [18 58 12 64]
# Predict majority: accuracy= 0.5
# Native avg=2.537, stdev=0.422
# fraction 0.995, idx 780.08, ref limit=4.011
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.6208267090620032, 0.9949044585987261, 0.7645619187469408)
# n = 1365  accuracy = 0.6476190476190476
# confusion matrix: tn, fp, fn, tp [103 477   4 781]
# Predict majority: accuracy= 0.575091575091575
#
# * TEST RESULTS *
# precision, recall, F1 = (0.5859375, 0.8522727272727273, 0.6944444444444444)
# n = 151  accuracy = 0.5629139072847682
# confusion matrix: tn, fp, fn, tp [10 53 13 75]
# Predict majority: accuracy= 0.5827814569536424
# Native avg=2.540, stdev=0.428
# fraction 0.995, idx 781.08, ref limit=3.917
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.6276083467094703, 0.9949109414758269, 0.7696850393700787)
# n = 1365  accuracy = 0.6571428571428571
# confusion matrix: tn, fp, fn, tp [115 464   4 782]
# Predict majority: accuracy= 0.5758241758241758
#
# * TEST RESULTS *
# precision, recall, F1 = (0.6209677419354839, 0.8850574712643678, 0.7298578199052134)
# n = 151  accuracy = 0.6225165562913907
# confusion matrix: tn, fp, fn, tp [17 47 10 77]
# Predict majority: accuracy= 0.5761589403973509
# Native avg=2.541, stdev=0.426
# fraction 0.995, idx 780.08, ref limit=4.119
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.6120689655172413, 0.9949044585987261, 0.7578845220766617)
# n = 1365  accuracy = 0.6344322344322344
# confusion matrix: tn, fp, fn, tp [ 85 495   4 781]
# Predict majority: accuracy= 0.575091575091575
#
# * TEST RESULTS *
# precision, recall, F1 = (0.5789473684210527, 0.875, 0.6968325791855203)
# n = 151  accuracy = 0.5562913907284768
# confusion matrix: tn, fp, fn, tp [ 7 56 11 77]
# Predict majority: accuracy= 0.5827814569536424
# Native avg=2.528, stdev=0.426
# fraction 0.995, idx 774.11, ref limit=3.898
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.6300813008130082, 0.9948652118100129, 0.7715281234444998)
# n = 1365  accuracy = 0.6637362637362637
# confusion matrix: tn, fp, fn, tp [131 455   4 775]
# Predict majority: accuracy= 0.5706959706959707
#
# * TEST RESULTS *
# precision, recall, F1 = (0.6299212598425197, 0.851063829787234, 0.7239819004524887)
# n = 151  accuracy = 0.5960264900662252
# confusion matrix: tn, fp, fn, tp [10 47 14 80]
# Predict majority: accuracy= 0.6225165562913907
#
#             Acc   Maj_acc      Prec    Recall        F1
# Mean   0.581143  0.575898  0.593259  0.867360  0.703690
# StDev  0.027850  0.042781  0.038984  0.029671  0.028287
#
# Language=Hup, form=scas
# Native avg=2.280, stdev=0.412
# fraction 0.995, idx 926.35, ref limit=3.745
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9325955734406438, 0.9946351931330472, 0.9626168224299065)
# n = 1061  accuracy = 0.9321394910461829
# confusion matrix: tn, fp, fn, tp [ 62  67   5 927]
# Predict majority: accuracy= 0.8784165881244109
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9509803921568627, 0.941747572815534, 0.9463414634146341)
# n = 118  accuracy = 0.9067796610169492
# confusion matrix: tn, fp, fn, tp [10  5  6 97]
# Predict majority: accuracy= 0.8728813559322034
# Native avg=2.283, stdev=0.410
# fraction 0.995, idx 925.35, ref limit=3.703
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9381965552178319, 0.9946294307196563, 0.9655891553701773)
# n = 1061  accuracy = 0.937794533459001
# confusion matrix: tn, fp, fn, tp [ 69  61   5 926]
# Predict majority: accuracy= 0.8774740810556079
#
# * TEST RESULTS *
# precision, recall, F1 = (0.908256880733945, 0.9519230769230769, 0.9295774647887324)
# n = 118  accuracy = 0.8728813559322034
# confusion matrix: tn, fp, fn, tp [ 4 10  5 99]
# Predict majority: accuracy= 0.8813559322033898
# Native avg=2.287, stdev=0.410
# fraction 0.995, idx 929.33, ref limit=3.755
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9375, 0.9946524064171123, 0.9652309289050337)
# n = 1061  accuracy = 0.9368520263901979
# confusion matrix: tn, fp, fn, tp [ 64  62   5 930]
# Predict majority: accuracy= 0.88124410933082
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9215686274509803, 0.94, 0.9306930693069307)
# n = 118  accuracy = 0.8813559322033898
# confusion matrix: tn, fp, fn, tp [10  8  6 94]
# Predict majority: accuracy= 0.847457627118644
# Native avg=2.280, stdev=0.414
# fraction 0.995, idx 928.34, ref limit=3.706
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.936491935483871, 0.9946466809421841, 0.9646936656282451)
# n = 1061  accuracy = 0.9359095193213949
# confusion matrix: tn, fp, fn, tp [ 64  63   5 929]
# Predict majority: accuracy= 0.8803016022620169
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9405940594059405, 0.9405940594059405, 0.9405940594059405)
# n = 118  accuracy = 0.8983050847457628
# confusion matrix: tn, fp, fn, tp [11  6  6 95]
# Predict majority: accuracy= 0.8559322033898306
# Native avg=2.279, stdev=0.418
# fraction 0.995, idx 930.33, ref limit=3.754
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.938508064516129, 0.9946581196581197, 0.9657676348547718)
# n = 1061  accuracy = 0.937794533459001
# confusion matrix: tn, fp, fn, tp [ 64  61   5 931]
# Predict majority: accuracy= 0.882186616399623
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8932038834951457, 0.9292929292929293, 0.9108910891089108)
# n = 118  accuracy = 0.847457627118644
# confusion matrix: tn, fp, fn, tp [ 8 11  7 92]
# Predict majority: accuracy= 0.8389830508474576
# Native avg=2.268, stdev=0.414
# fraction 0.995, idx 923.36, ref limit=3.725
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9371196754563894, 0.9946178686759957, 0.9650130548302872)
# n = 1061  accuracy = 0.9368520263901979
# confusion matrix: tn, fp, fn, tp [ 70  62   5 924]
# Predict majority: accuracy= 0.8755890669180019
#
# * TEST RESULTS *
# precision, recall, F1 = (0.96, 0.9056603773584906, 0.9320388349514563)
# n = 118  accuracy = 0.8813559322033898
# confusion matrix: tn, fp, fn, tp [ 8  4 10 96]
# Predict majority: accuracy= 0.8983050847457628
# Native avg=2.274, stdev=0.408
# fraction 0.995, idx 925.35, ref limit=3.676
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9381965552178319, 0.9946294307196563, 0.9655891553701773)
# n = 1061  accuracy = 0.937794533459001
# confusion matrix: tn, fp, fn, tp [ 69  61   5 926]
# Predict majority: accuracy= 0.8774740810556079
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9519230769230769, 0.9519230769230769, 0.9519230769230769)
# n = 118  accuracy = 0.9152542372881356
# confusion matrix: tn, fp, fn, tp [ 9  5  5 99]
# Predict majority: accuracy= 0.8813559322033898
# Native avg=2.280, stdev=0.411
# fraction 0.995, idx 925.35, ref limit=3.755
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9353535353535354, 0.9946294307196563, 0.9640812077043207)
# n = 1061  accuracy = 0.9349670122525919
# confusion matrix: tn, fp, fn, tp [ 66  64   5 926]
# Predict majority: accuracy= 0.8774740810556079
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9528301886792453, 0.9711538461538461, 0.9619047619047619)
# n = 118  accuracy = 0.9322033898305084
# confusion matrix: tn, fp, fn, tp [  9   5   3 101]
# Predict majority: accuracy= 0.8813559322033898
# Native avg=2.272, stdev=0.412
# fraction 0.995, idx 923.36, ref limit=3.690
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9399796541200407, 0.9946178686759957, 0.9665271966527197)
# n = 1061  accuracy = 0.939679547596607
# confusion matrix: tn, fp, fn, tp [ 73  59   5 924]
# Predict majority: accuracy= 0.8755890669180019
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9345794392523364, 0.9433962264150944, 0.9389671361502347)
# n = 118  accuracy = 0.8898305084745762
# confusion matrix: tn, fp, fn, tp [  5   7   6 100]
# Predict majority: accuracy= 0.8983050847457628
# Native avg=2.268, stdev=0.414
# fraction 0.995, idx 921.37, ref limit=3.736
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9341438703140831, 0.9946062567421791, 0.9634273772204807)
# n = 1062  accuracy = 0.9340866290018832
# confusion matrix: tn, fp, fn, tp [ 70  65   5 922]
# Predict majority: accuracy= 0.8728813559322034
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9528301886792453, 0.9351851851851852, 0.9439252336448598)
# n = 117  accuracy = 0.8974358974358975
# confusion matrix: tn, fp, fn, tp [  4   5   7 101]
# Predict majority: accuracy= 0.9230769230769231
#
#             Acc   Maj_acc      Prec    Recall        F1
# Mean   0.892286  0.877901  0.936677  0.941088  0.938686
# StDev  0.023629  0.025514  0.022232  0.016915  0.014015
#
# Language=ImbaburaQuechua, form=scas
# Native avg=2.353, stdev=0.449
# fraction 0.995, idx 830.83, ref limit=3.657
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8177339901477833, 0.992822966507177, 0.8968125337655323)
# n = 1187  accuracy = 0.8390901432181971
# confusion matrix: tn, fp, fn, tp [166 185   6 830]
# Predict majority: accuracy= 0.7042965459140691
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8348623853211009, 0.9479166666666666, 0.8878048780487804)
# n = 132  accuracy = 0.8257575757575758
# confusion matrix: tn, fp, fn, tp [18 18  5 91]
# Predict majority: accuracy= 0.7272727272727273
# Native avg=2.339, stdev=0.446
# fraction 0.995, idx 835.80, ref limit=3.638
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8277227722772277, 0.9940546967895363, 0.9032955159373312)
# n = 1187  accuracy = 0.8491996630160067
# confusion matrix: tn, fp, fn, tp [172 174   5 836]
# Predict majority: accuracy= 0.7085088458298231
#
# * TEST RESULTS *
# precision, recall, F1 = (0.7961165048543689, 0.9010989010989011, 0.845360824742268)
# n = 132  accuracy = 0.7727272727272727
# confusion matrix: tn, fp, fn, tp [20 21  9 82]
# Predict majority: accuracy= 0.6893939393939394
# Native avg=2.341, stdev=0.444
# fraction 0.995, idx 835.80, ref limit=3.649
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8212180746561886, 0.9940546967895363, 0.8994082840236687)
# n = 1187  accuracy = 0.8424599831508003
# confusion matrix: tn, fp, fn, tp [164 182   5 836]
# Predict majority: accuracy= 0.7085088458298231
#
# * TEST RESULTS *
# precision, recall, F1 = (0.7777777777777778, 0.9230769230769231, 0.8442211055276381)
# n = 132  accuracy = 0.7651515151515151
# confusion matrix: tn, fp, fn, tp [17 24  7 84]
# Predict majority: accuracy= 0.6893939393939394
# Native avg=2.332, stdev=0.445
# fraction 0.995, idx 827.84, ref limit=3.640
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8206144697720515, 0.9939975990396158, 0.8990228013029317)
# n = 1187  accuracy = 0.8433024431339511
# confusion matrix: tn, fp, fn, tp [173 181   5 828]
# Predict majority: accuracy= 0.7017691659646167
#
# * TEST RESULTS *
# precision, recall, F1 = (0.822429906542056, 0.8888888888888888, 0.8543689320388348)
# n = 132  accuracy = 0.7727272727272727
# confusion matrix: tn, fp, fn, tp [14 19 11 88]
# Predict majority: accuracy= 0.75
# Native avg=2.349, stdev=0.449
# fraction 0.995, idx 842.76, ref limit=3.572
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8305418719211822, 0.9941037735849056, 0.9049919484702093)
# n = 1187  accuracy = 0.8508845829823083
# confusion matrix: tn, fp, fn, tp [167 172   5 843]
# Predict majority: accuracy= 0.7144060657118787
#
# * TEST RESULTS *
# precision, recall, F1 = (0.803921568627451, 0.9761904761904762, 0.8817204301075269)
# n = 132  accuracy = 0.8333333333333334
# confusion matrix: tn, fp, fn, tp [28 20  2 82]
# Predict majority: accuracy= 0.6363636363636364
# Native avg=2.350, stdev=0.451
# fraction 0.995, idx 839.78, ref limit=3.611
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8275862068965517, 0.9940828402366864, 0.9032258064516129)
# n = 1187  accuracy = 0.8483572030328559
# confusion matrix: tn, fp, fn, tp [167 175   5 840]
# Predict majority: accuracy= 0.7118786857624263
#
# * TEST RESULTS *
# precision, recall, F1 = (0.7924528301886793, 0.9655172413793104, 0.8704663212435234)
# n = 132  accuracy = 0.8106060606060606
# confusion matrix: tn, fp, fn, tp [23 22  3 84]
# Predict majority: accuracy= 0.6590909090909091
# Native avg=2.343, stdev=0.452
# fraction 0.995, idx 822.87, ref limit=3.630
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8221778221778222, 0.9939613526570048, 0.8999453253143794)
# n = 1187  accuracy = 0.8458298230834035
# confusion matrix: tn, fp, fn, tp [181 178   5 823]
# Predict majority: accuracy= 0.6975568660488627
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8727272727272727, 0.9230769230769231, 0.897196261682243)
# n = 132  accuracy = 0.8333333333333334
# confusion matrix: tn, fp, fn, tp [14 14  8 96]
# Predict majority: accuracy= 0.7878787878787878
# Native avg=2.338, stdev=0.450
# fraction 0.995, idx 835.80, ref limit=3.616
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8273809523809523, 0.9916765755053508, 0.9021092482422931)
# n = 1187  accuracy = 0.8475147430497051
# confusion matrix: tn, fp, fn, tp [172 174   7 834]
# Predict majority: accuracy= 0.7085088458298231
#
# * TEST RESULTS *
# precision, recall, F1 = (0.7884615384615384, 0.9010989010989011, 0.841025641025641)
# n = 132  accuracy = 0.7651515151515151
# confusion matrix: tn, fp, fn, tp [19 22  9 82]
# Predict majority: accuracy= 0.6893939393939394
# Native avg=2.339, stdev=0.458
# fraction 0.995, idx 832.81, ref limit=3.717
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8198818897637795, 0.9940334128878282, 0.8985976267529665)
# n = 1187  accuracy = 0.8416175231676495
# confusion matrix: tn, fp, fn, tp [166 183   5 833]
# Predict majority: accuracy= 0.7059814658803707
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8018018018018018, 0.9468085106382979, 0.8682926829268293)
# n = 132  accuracy = 0.7954545454545454
# confusion matrix: tn, fp, fn, tp [16 22  5 89]
# Predict majority: accuracy= 0.7121212121212122
# Native avg=2.341, stdev=0.451
# fraction 0.995, idx 831.82, ref limit=3.752
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8123167155425219, 0.992831541218638, 0.8935483870967742)
# n = 1188  accuracy = 0.8333333333333334
# confusion matrix: tn, fp, fn, tp [159 192   6 831]
# Predict majority: accuracy= 0.7045454545454546
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8365384615384616, 0.9157894736842105, 0.8743718592964824)
# n = 131  accuracy = 0.8091603053435115
# confusion matrix: tn, fp, fn, tp [19 17  8 87]
# Predict majority: accuracy= 0.7251908396946565
#
#             Acc   Maj_acc      Prec    Recall        F1
# Mean   0.798340  0.706610  0.812709  0.928946  0.866483
# StDev  0.027872  0.043934  0.028762  0.029147  0.019573
#
# Language=Mapudungun, form=scas
# Native avg=2.594, stdev=0.459
# fraction 0.995, idx 959.18, ref limit=3.907
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8617594254937163, 0.9948186528497409, 0.9235209235209234)
# n = 1270  accuracy = 0.8748031496062992
# confusion matrix: tn, fp, fn, tp [151 154   5 960]
# Predict majority: accuracy= 0.7598425196850394
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8559322033898306, 0.8782608695652174, 0.8669527896995708)
# n = 142  accuracy = 0.7816901408450704
# confusion matrix: tn, fp, fn, tp [ 10  17  14 101]
# Predict majority: accuracy= 0.8098591549295775
# Native avg=2.596, stdev=0.462
# fraction 0.995, idx 963.16, ref limit=3.920
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8546099290780141, 0.9948400412796697, 0.9194086790653314)
# n = 1270  accuracy = 0.8669291338582678
# confusion matrix: tn, fp, fn, tp [137 164   5 964]
# Predict majority: accuracy= 0.7629921259842519
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8888888888888888, 0.9369369369369369, 0.9122807017543859)
# n = 142  accuracy = 0.8591549295774648
# confusion matrix: tn, fp, fn, tp [ 18  13   7 104]
# Predict majority: accuracy= 0.7816901408450704
# Native avg=2.589, stdev=0.460
# fraction 0.995, idx 972.12, ref limit=4.014
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8587819947043248, 0.9948875255623721, 0.9218379914732354)
# n = 1271  accuracy = 0.8701809598741149
# confusion matrix: tn, fp, fn, tp [133 160   5 973]
# Predict majority: accuracy= 0.7694728560188828
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8, 0.9411764705882353, 0.8648648648648648)
# n = 141  accuracy = 0.7872340425531915
# confusion matrix: tn, fp, fn, tp [15 24  6 96]
# Predict majority: accuracy= 0.723404255319149
# Native avg=2.587, stdev=0.461
# fraction 0.995, idx 970.12, ref limit=3.945
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8585322723253758, 0.9948770491803278, 0.9216896060749882)
# n = 1271  accuracy = 0.8701809598741149
# confusion matrix: tn, fp, fn, tp [135 160   5 971]
# Predict majority: accuracy= 0.7678992918961448
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8275862068965517, 0.9230769230769231, 0.8727272727272727)
# n = 141  accuracy = 0.8014184397163121
# confusion matrix: tn, fp, fn, tp [17 20  8 96]
# Predict majority: accuracy= 0.7375886524822695
# Native avg=2.584, stdev=0.455
# fraction 0.995, idx 968.13, ref limit=3.967
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8620996441281139, 0.9948665297741273, 0.9237368922783603)
# n = 1271  accuracy = 0.8741148701809599
# confusion matrix: tn, fp, fn, tp [142 155   5 969]
# Predict majority: accuracy= 0.7663257277734068
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8378378378378378, 0.8773584905660378, 0.8571428571428571)
# n = 141  accuracy = 0.7801418439716312
# confusion matrix: tn, fp, fn, tp [17 18 13 93]
# Predict majority: accuracy= 0.75177304964539
# Native avg=2.609, stdev=0.458
# fraction 0.995, idx 962.16, ref limit=4.006
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8514588859416445, 0.9948347107438017, 0.9175797999047166)
# n = 1271  accuracy = 0.8638867033831629
# confusion matrix: tn, fp, fn, tp [135 168   5 963]
# Predict majority: accuracy= 0.7616050354051928
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8661417322834646, 0.9821428571428571, 0.9205020920502093)
# n = 141  accuracy = 0.8652482269503546
# confusion matrix: tn, fp, fn, tp [ 12  17   2 110]
# Predict majority: accuracy= 0.7943262411347518
# Native avg=2.585, stdev=0.461
# fraction 0.995, idx 975.10, ref limit=3.965
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8660159716060337, 0.9949031600407747, 0.9259962049335863)
# n = 1271  accuracy = 0.8772619984264359
# confusion matrix: tn, fp, fn, tp [139 151   5 976]
# Predict majority: accuracy= 0.7718332022029898
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8095238095238095, 0.8585858585858586, 0.8333333333333333)
# n = 141  accuracy = 0.7588652482269503
# confusion matrix: tn, fp, fn, tp [22 20 14 85]
# Predict majority: accuracy= 0.7021276595744681
# Native avg=2.591, stdev=0.462
# fraction 0.995, idx 961.17, ref limit=4.051
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8490732568402471, 0.9948293691830403, 0.9161904761904762)
# n = 1271  accuracy = 0.8615263571990559
# confusion matrix: tn, fp, fn, tp [133 171   5 962]
# Predict majority: accuracy= 0.7608182533438238
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8760330578512396, 0.9380530973451328, 0.9059829059829061)
# n = 141  accuracy = 0.8439716312056738
# confusion matrix: tn, fp, fn, tp [ 13  15   7 106]
# Predict majority: accuracy= 0.8014184397163121
# Native avg=2.584, stdev=0.461
# fraction 0.995, idx 967.14, ref limit=3.912
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.863514719000892, 0.9948612538540597, 0.9245463228271251)
# n = 1271  accuracy = 0.8756884343036979
# confusion matrix: tn, fp, fn, tp [145 153   5 968]
# Predict majority: accuracy= 0.7655389457120377
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8425925925925926, 0.8504672897196262, 0.8465116279069766)
# n = 141  accuracy = 0.7659574468085106
# confusion matrix: tn, fp, fn, tp [17 17 16 91]
# Predict majority: accuracy= 0.7588652482269503
# Native avg=2.585, stdev=0.467
# fraction 0.995, idx 963.16, ref limit=4.084
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8456140350877193, 0.9948400412796697, 0.9141773352299667)
# n = 1271  accuracy = 0.8575924468922108
# confusion matrix: tn, fp, fn, tp [126 176   5 964]
# Predict majority: accuracy= 0.7623918174665618
#
# * TEST RESULTS *
# precision, recall, F1 = (0.847457627118644, 0.9009009009009009, 0.8733624454148471)
# n = 141  accuracy = 0.7943262411347518
# confusion matrix: tn, fp, fn, tp [ 12  18  11 100]
# Predict majority: accuracy= 0.7872340425531915
#
#             Acc   Maj_acc      Prec    Recall        F1
# Mean   0.803801  0.764829  0.845199  0.908696  0.875366
# StDev  0.038476  0.035930  0.028098  0.042409  0.028792
#
# Language=Qeqchi, form=scas
# Native avg=2.686, stdev=0.460
# fraction 0.995, idx 1514.39, ref limit=4.460
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8875219683655536, 0.9947472094550229, 0.9380804953560372)
# n = 1795  accuracy = 0.8885793871866295
# confusion matrix: tn, fp, fn, tp [  80  192    8 1515]
# Predict majority: accuracy= 0.8484679665738162
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8539325842696629, 0.9325153374233128, 0.8914956011730205)
# n = 200  accuracy = 0.815
# confusion matrix: tn, fp, fn, tp [ 11  26  11 152]
# Predict majority: accuracy= 0.815
# Native avg=2.677, stdev=0.466
# fraction 0.995, idx 1507.42, ref limit=4.268
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8907265209686946, 0.9947229551451188, 0.9398566531629791)
# n = 1795  accuracy = 0.8924791086350975
# confusion matrix: tn, fp, fn, tp [  94  185    8 1508]
# Predict majority: accuracy= 0.8445682451253482
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8888888888888888, 0.9411764705882353, 0.9142857142857143)
# n = 200  accuracy = 0.85
# confusion matrix: tn, fp, fn, tp [ 10  20  10 160]
# Predict majority: accuracy= 0.85
# Native avg=2.687, stdev=0.469
# fraction 0.995, idx 1507.42, ref limit=4.386
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8834212067955477, 0.9947229551451188, 0.9357741234874342)
# n = 1795  accuracy = 0.8846796657381616
# confusion matrix: tn, fp, fn, tp [  80  199    8 1508]
# Predict majority: accuracy= 0.8445682451253482
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9016393442622951, 0.9705882352941176, 0.9348441926345609)
# n = 200  accuracy = 0.885
# confusion matrix: tn, fp, fn, tp [ 12  18   5 165]
# Predict majority: accuracy= 0.85
# Native avg=2.690, stdev=0.462
# fraction 0.995, idx 1508.42, ref limit=4.515
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8824561403508772, 0.994726433750824, 0.9352339634335296)
# n = 1795  accuracy = 0.8835654596100279
# confusion matrix: tn, fp, fn, tp [  77  201    8 1509]
# Predict majority: accuracy= 0.8451253481894151
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8810810810810811, 0.9644970414201184, 0.9209039548022598)
# n = 200  accuracy = 0.86
# confusion matrix: tn, fp, fn, tp [  9  22   6 163]
# Predict majority: accuracy= 0.845
# Native avg=2.686, stdev=0.467
# fraction 0.995, idx 1508.42, ref limit=4.312
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8918439716312057, 0.994726433750824, 0.9404799002804614)
# n = 1795  accuracy = 0.8935933147632312
# confusion matrix: tn, fp, fn, tp [  95  183    8 1509]
# Predict majority: accuracy= 0.8451253481894151
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8670212765957447, 0.9644970414201184, 0.9131652661064427)
# n = 200  accuracy = 0.845
# confusion matrix: tn, fp, fn, tp [  6  25   6 163]
# Predict majority: accuracy= 0.845
# Native avg=2.686, stdev=0.466
# fraction 0.995, idx 1505.43, ref limit=4.370
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8843217850851439, 0.9947159841479525, 0.9362760335716506)
# n = 1796  accuracy = 0.8858574610244989
# confusion matrix: tn, fp, fn, tp [  85  197    8 1506]
# Predict majority: accuracy= 0.8429844097995546
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9116022099447514, 0.9593023255813954, 0.934844192634561)
# n = 199  accuracy = 0.8844221105527639
# confusion matrix: tn, fp, fn, tp [ 11  16   7 165]
# Predict majority: accuracy= 0.864321608040201
# Native avg=2.683, stdev=0.461
# fraction 0.995, idx 1512.40, ref limit=4.507
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8858313817330211, 0.9947403024326101, 0.9371322390833076)
# n = 1796  accuracy = 0.8869710467706013
# confusion matrix: tn, fp, fn, tp [  80  195    8 1513]
# Predict majority: accuracy= 0.8468819599109132
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8579234972677595, 0.9515151515151515, 0.9022988505747126)
# n = 199  accuracy = 0.8291457286432161
# confusion matrix: tn, fp, fn, tp [  8  26   8 157]
# Predict majority: accuracy= 0.8291457286432161
# Native avg=2.691, stdev=0.465
# fraction 0.995, idx 1500.46, ref limit=4.489
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8793204452255419, 0.9946984758117959, 0.933457711442786)
# n = 1796  accuracy = 0.8808463251670379
# confusion matrix: tn, fp, fn, tp [  81  206    8 1501]
# Predict majority: accuracy= 0.8402004454342984
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9210526315789473, 0.9887005649717514, 0.9536784741144415)
# n = 199  accuracy = 0.914572864321608
# confusion matrix: tn, fp, fn, tp [  7  15   2 175]
# Predict majority: accuracy= 0.8894472361809045
# Native avg=2.689, stdev=0.463
# fraction 0.995, idx 1515.38, ref limit=4.498
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8849970811441915, 0.994750656167979, 0.9366697559468644)
# n = 1796  accuracy = 0.8858574610244989
# confusion matrix: tn, fp, fn, tp [  75  197    8 1516]
# Predict majority: accuracy= 0.8485523385300668
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8440860215053764, 0.9691358024691358, 0.9022988505747127)
# n = 199  accuracy = 0.8291457286432161
# confusion matrix: tn, fp, fn, tp [  8  29   5 157]
# Predict majority: accuracy= 0.8140703517587939
# Native avg=2.679, stdev=0.467
# fraction 0.995, idx 1508.42, ref limit=4.524
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8819403857393338, 0.994726433750824, 0.9349442379182157)
# n = 1796  accuracy = 0.8830734966592427
# confusion matrix: tn, fp, fn, tp [  77  202    8 1509]
# Predict majority: accuracy= 0.8446547884187082
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8722222222222222, 0.9289940828402367, 0.8997134670487106)
# n = 199  accuracy = 0.8241206030150754
# confusion matrix: tn, fp, fn, tp [  7  23  12 157]
# Predict majority: accuracy= 0.8492462311557789
#
#             Acc   Maj_acc      Prec    Recall        F1
# Mean   0.853641  0.845123  0.879945  0.957092  0.916753
# StDev  0.032209  0.022422  0.025643  0.018615  0.019438
#
# Language=Wichi, form=scas
# Native avg=2.642, stdev=0.437
# fraction 0.995, idx 1025.85, ref limit=4.134
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9136242208370436, 0.9941860465116279, 0.9522041763341067)
# n = 1224  accuracy = 0.9158496732026143
# confusion matrix: tn, fp, fn, tp [  95   97    6 1026]
# Predict majority: accuracy= 0.8431372549019608
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9344262295081968, 0.9344262295081968, 0.9344262295081968)
# n = 137  accuracy = 0.8832116788321168
# confusion matrix: tn, fp, fn, tp [  7   8   8 114]
# Predict majority: accuracy= 0.8905109489051095
# Native avg=2.643, stdev=0.430
# fraction 0.995, idx 1034.80, ref limit=4.059
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9232827832292596, 0.9942363112391931, 0.9574468085106383)
# n = 1225  accuracy = 0.9248979591836735
# confusion matrix: tn, fp, fn, tp [  98   86    6 1035]
# Predict majority: accuracy= 0.8497959183673469
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8983050847457628, 0.9380530973451328, 0.9177489177489178)
# n = 136  accuracy = 0.8602941176470589
# confusion matrix: tn, fp, fn, tp [ 11  12   7 106]
# Predict majority: accuracy= 0.8308823529411765
# Native avg=2.641, stdev=0.434
# fraction 0.995, idx 1028.83, ref limit=3.970
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9278629395852119, 0.9942028985507246, 0.9598880597014925)
# n = 1225  accuracy = 0.929795918367347
# confusion matrix: tn, fp, fn, tp [ 110   80    6 1029]
# Predict majority: accuracy= 0.8448979591836735
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9380530973451328, 0.8907563025210085, 0.9137931034482759)
# n = 136  accuracy = 0.8529411764705882
# confusion matrix: tn, fp, fn, tp [ 10   7  13 106]
# Predict majority: accuracy= 0.875
# Native avg=2.644, stdev=0.422
# fraction 0.995, idx 1029.83, ref limit=3.951
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9321266968325792, 0.9942084942084942, 0.9621672115833722)
# n = 1225  accuracy = 0.9338775510204081
# confusion matrix: tn, fp, fn, tp [ 114   75    6 1030]
# Predict majority: accuracy= 0.8457142857142858
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9396551724137931, 0.923728813559322, 0.9316239316239315)
# n = 136  accuracy = 0.8823529411764706
# confusion matrix: tn, fp, fn, tp [ 11   7   9 109]
# Predict majority: accuracy= 0.8676470588235294
# Native avg=2.637, stdev=0.434
# fraction 0.995, idx 1032.81, ref limit=3.997
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9256272401433692, 0.9942252165543792, 0.9587006960556845)
# n = 1225  accuracy = 0.9273469387755102
# confusion matrix: tn, fp, fn, tp [ 103   83    6 1033]
# Predict majority: accuracy= 0.8481632653061224
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8983050847457628, 0.9217391304347826, 0.9098712446351932)
# n = 136  accuracy = 0.8455882352941176
# confusion matrix: tn, fp, fn, tp [  9  12   9 106]
# Predict majority: accuracy= 0.8455882352941176
# Native avg=2.646, stdev=0.439
# fraction 0.995, idx 1042.76, ref limit=4.133
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9181338028169014, 0.994280266920877, 0.9546910755148742)
# n = 1225  accuracy = 0.9191836734693878
# confusion matrix: tn, fp, fn, tp [  83   93    6 1043]
# Predict majority: accuracy= 0.856326530612245
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8559322033898306, 0.9619047619047619, 0.9058295964125561)
# n = 136  accuracy = 0.8455882352941176
# confusion matrix: tn, fp, fn, tp [ 14  17   4 101]
# Predict majority: accuracy= 0.7720588235294118
# Native avg=2.645, stdev=0.438
# fraction 0.995, idx 1031.82, ref limit=4.030
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9239033124440466, 0.9942196531791907, 0.9577726218097448)
# n = 1225  accuracy = 0.9257142857142857
# confusion matrix: tn, fp, fn, tp [ 102   85    6 1032]
# Predict majority: accuracy= 0.8473469387755102
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9243697478991597, 0.9482758620689655, 0.9361702127659575)
# n = 136  accuracy = 0.8897058823529411
# confusion matrix: tn, fp, fn, tp [ 11   9   6 110]
# Predict majority: accuracy= 0.8529411764705882
# Native avg=2.641, stdev=0.433
# fraction 0.995, idx 1032.81, ref limit=3.986
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9247985675917636, 0.9942252165543792, 0.958256029684601)
# n = 1225  accuracy = 0.926530612244898
# confusion matrix: tn, fp, fn, tp [ 102   84    6 1033]
# Predict majority: accuracy= 0.8481632653061224
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9272727272727272, 0.8869565217391304, 0.9066666666666666)
# n = 136  accuracy = 0.8455882352941176
# confusion matrix: tn, fp, fn, tp [ 13   8  13 102]
# Predict majority: accuracy= 0.8455882352941176
# Native avg=2.645, stdev=0.428
# fraction 0.995, idx 1034.80, ref limit=3.930
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9324324324324325, 0.9942363112391931, 0.9623430962343097)
# n = 1225  accuracy = 0.9338775510204081
# confusion matrix: tn, fp, fn, tp [ 109   75    6 1035]
# Predict majority: accuracy= 0.8497959183673469
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9357798165137615, 0.9026548672566371, 0.918918918918919)
# n = 136  accuracy = 0.8676470588235294
# confusion matrix: tn, fp, fn, tp [ 16   7  11 102]
# Predict majority: accuracy= 0.8308823529411765
# Native avg=2.640, stdev=0.426
# fraction 0.995, idx 1029.83, ref limit=4.010
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9188224799286352, 0.9942084942084942, 0.9550301344459898)
# n = 1225  accuracy = 0.9208163265306123
# confusion matrix: tn, fp, fn, tp [  98   91    6 1030]
# Predict majority: accuracy= 0.8457142857142858
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9469026548672567, 0.9067796610169492, 0.9264069264069263)
# n = 136  accuracy = 0.875
# confusion matrix: tn, fp, fn, tp [ 12   6  11 107]
# Predict majority: accuracy= 0.8676470588235294
#
#             Acc   Maj_acc      Prec    Recall        F1
# Mean   0.864792  0.847875  0.919900  0.921528  0.920146
# StDev  0.017152  0.032825  0.027911  0.024734  0.011409

# %% [markdown]
# # Word discrimination - based on native and loan entropy models
# ## k-fold fit on known native and loan and validation on unknown

# %%
# Test k_fold dual basis word discrimination - Based on formchars.
# No interest in return table of k-fold trials, thus the _ return value.
for l in languages:
    _ = k_fold_language_word_discrimination_dual_basis(l, form='formchars', smoothing=0.5, k_fold=10)
# Out:
# English
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9487836107554417, 0.9391634980988594, 0.9439490445859873)
# n = 1364  accuracy = 0.9354838709677419
# confusion matrix: tn, fp, fn, tp [535  40  48 741]
# Predict majority: accuracy= 0.5784457478005866
#
# * TEST RESULTS *
# precision, recall, F1 = (0.7804878048780488, 0.7619047619047619, 0.7710843373493976)
# n = 152  accuracy = 0.75
# confusion matrix: tn, fp, fn, tp [50 18 20 64]
# Predict majority: accuracy= 0.5526315789473685
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9403553299492385, 0.9403553299492385, 0.9403553299492385)
# n = 1364  accuracy = 0.9310850439882697
# confusion matrix: tn, fp, fn, tp [529  47  47 741]
# Predict majority: accuracy= 0.5777126099706745
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8414634146341463, 0.8117647058823529, 0.8263473053892215)
# n = 152  accuracy = 0.8092105263157895
# confusion matrix: tn, fp, fn, tp [54 13 16 69]
# Predict majority: accuracy= 0.5592105263157895
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9478371501272265, 0.9430379746835443, 0.9454314720812182)
# n = 1364  accuracy = 0.9369501466275659
# confusion matrix: tn, fp, fn, tp [533  41  45 745]
# Predict majority: accuracy= 0.5791788856304986
#
# * TEST RESULTS *
# precision, recall, F1 = (0.75, 0.7590361445783133, 0.7544910179640718)
# n = 152  accuracy = 0.7302631578947368
# confusion matrix: tn, fp, fn, tp [48 21 20 63]
# Predict majority: accuracy= 0.5460526315789473
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9469026548672567, 0.9457070707070707, 0.9463044851547694)
# n = 1364  accuracy = 0.9376832844574781
# confusion matrix: tn, fp, fn, tp [530  42  43 749]
# Predict majority: accuracy= 0.5806451612903226
#
# * TEST RESULTS *
# precision, recall, F1 = (0.7654320987654321, 0.7654320987654321, 0.7654320987654321)
# n = 152  accuracy = 0.75
# confusion matrix: tn, fp, fn, tp [52 19 19 62]
# Predict majority: accuracy= 0.5328947368421053
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9367088607594937, 0.9462915601023018, 0.9414758269720102)
# n = 1364  accuracy = 0.9325513196480938
# confusion matrix: tn, fp, fn, tp [532  50  42 740]
# Predict majority: accuracy= 0.5733137829912024
#
# * TEST RESULTS *
# precision, recall, F1 = (0.78125, 0.8241758241758241, 0.8021390374331551)
# n = 152  accuracy = 0.756578947368421
# confusion matrix: tn, fp, fn, tp [40 21 16 75]
# Predict majority: accuracy= 0.5986842105263158
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9467005076142132, 0.9407313997477932, 0.9437065148640101)
# n = 1364  accuracy = 0.9347507331378299
# confusion matrix: tn, fp, fn, tp [529  42  47 746]
# Predict majority: accuracy= 0.5813782991202346
#
# * TEST RESULTS *
# precision, recall, F1 = (0.696969696969697, 0.8625, 0.7709497206703911)
# n = 152  accuracy = 0.7302631578947368
# confusion matrix: tn, fp, fn, tp [42 30 11 69]
# Predict majority: accuracy= 0.5263157894736842
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9401273885350319, 0.9485861182519281, 0.944337811900192)
# n = 1365  accuracy = 0.9362637362637363
# confusion matrix: tn, fp, fn, tp [540  47  40 738]
# Predict majority: accuracy= 0.5699633699633699
#
# * TEST RESULTS *
# precision, recall, F1 = (0.7931034482758621, 0.7263157894736842, 0.7582417582417583)
# n = 151  accuracy = 0.7086092715231788
# confusion matrix: tn, fp, fn, tp [38 18 26 69]
# Predict majority: accuracy= 0.6291390728476821
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9469598965071151, 0.9432989690721649, 0.9451258876694641)
# n = 1365  accuracy = 0.9377289377289377
# confusion matrix: tn, fp, fn, tp [548  41  44 732]
# Predict majority: accuracy= 0.5684981684981685
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8395061728395061, 0.7010309278350515, 0.7640449438202246)
# n = 151  accuracy = 0.7218543046357616
# confusion matrix: tn, fp, fn, tp [41 13 29 68]
# Predict majority: accuracy= 0.6423841059602649
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9421383647798742, 0.951715374841169, 0.9469026548672567)
# n = 1365  accuracy = 0.9384615384615385
# confusion matrix: tn, fp, fn, tp [532  46  38 749]
# Predict majority: accuracy= 0.5765567765567765
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8170731707317073, 0.7790697674418605, 0.7976190476190477)
# n = 151  accuracy = 0.7748344370860927
# confusion matrix: tn, fp, fn, tp [50 15 19 67]
# Predict majority: accuracy= 0.5695364238410596
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9482535575679172, 0.9373401534526854, 0.9427652733118972)
# n = 1365  accuracy = 0.9347985347985348
# confusion matrix: tn, fp, fn, tp [543  40  49 733]
# Predict majority: accuracy= 0.5728937728937729
#
# * TEST RESULTS *
# precision, recall, F1 = (0.7444444444444445, 0.7362637362637363, 0.7403314917127072)
# n = 151  accuracy = 0.6887417218543046
# confusion matrix: tn, fp, fn, tp [37 23 24 67]
# Predict majority: accuracy= 0.6026490066225165
#
#             Acc   Maj_acc      Prec    Recall        F1
# Mean   0.742036  0.575950  0.780973  0.772749  0.775068
# StDev  0.034268  0.040206  0.044880  0.048594  0.025887
#
# Hup
#
# * TRAIN RESULTS *
# precision, recall, F1 = (1.0, 0.9849624060150376, 0.9924242424242424)
# n = 1061  accuracy = 0.9868049010367578
# confusion matrix: tn, fp, fn, tp [130   0  14 917]
# Predict majority: accuracy= 0.8774740810556079
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9693877551020408, 0.9134615384615384, 0.9405940594059407)
# n = 118  accuracy = 0.8983050847457628
# confusion matrix: tn, fp, fn, tp [11  3  9 95]
# Predict majority: accuracy= 0.8813559322033898
#
# * TRAIN RESULTS *
# precision, recall, F1 = (1.0, 0.9892703862660944, 0.9946062567421791)
# n = 1061  accuracy = 0.9905749293119699
# confusion matrix: tn, fp, fn, tp [129   0  10 922]
# Predict majority: accuracy= 0.8784165881244109
#
# * TEST RESULTS *
# precision, recall, F1 = (0.96875, 0.9029126213592233, 0.9346733668341708)
# n = 118  accuracy = 0.8898305084745762
# confusion matrix: tn, fp, fn, tp [12  3 10 93]
# Predict majority: accuracy= 0.8728813559322034
#
# * TRAIN RESULTS *
# precision, recall, F1 = (1.0, 0.99140708915145, 0.9956850053937433)
# n = 1061  accuracy = 0.9924599434495759
# confusion matrix: tn, fp, fn, tp [130   0   8 923]
# Predict majority: accuracy= 0.8774740810556079
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9619047619047619, 0.9711538461538461, 0.9665071770334929)
# n = 118  accuracy = 0.940677966101695
# confusion matrix: tn, fp, fn, tp [ 10   4   3 101]
# Predict majority: accuracy= 0.8813559322033898
#
# * TRAIN RESULTS *
# precision, recall, F1 = (1.0, 0.9859913793103449, 0.9929462832338579)
# n = 1061  accuracy = 0.9877474081055608
# confusion matrix: tn, fp, fn, tp [133   0  13 915]
# Predict majority: accuracy= 0.8746465598491989
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9896907216494846, 0.897196261682243, 0.9411764705882352)
# n = 118  accuracy = 0.8983050847457628
# confusion matrix: tn, fp, fn, tp [10  1 11 96]
# Predict majority: accuracy= 0.9067796610169492
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9989189189189189, 0.9882352941176471, 0.9935483870967742)
# n = 1061  accuracy = 0.9886899151743638
# confusion matrix: tn, fp, fn, tp [125   1  11 924]
# Predict majority: accuracy= 0.88124410933082
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9696969696969697, 0.96, 0.964824120603015)
# n = 118  accuracy = 0.940677966101695
# confusion matrix: tn, fp, fn, tp [15  3  4 96]
# Predict majority: accuracy= 0.847457627118644
#
# * TRAIN RESULTS *
# precision, recall, F1 = (1.0, 0.9861407249466951, 0.9930220075147611)
# n = 1061  accuracy = 0.9877474081055608
# confusion matrix: tn, fp, fn, tp [123   0  13 925]
# Predict majority: accuracy= 0.884071630537229
#
# * TEST RESULTS *
# precision, recall, F1 = (1.0, 0.8969072164948454, 0.9456521739130436)
# n = 118  accuracy = 0.9152542372881356
# confusion matrix: tn, fp, fn, tp [21  0 10 87]
# Predict majority: accuracy= 0.8220338983050848
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9989106753812637, 0.9881465517241379, 0.9934994582881906)
# n = 1061  accuracy = 0.9886899151743638
# confusion matrix: tn, fp, fn, tp [132   1  11 917]
# Predict majority: accuracy= 0.8746465598491989
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9900990099009901, 0.9345794392523364, 0.9615384615384615)
# n = 118  accuracy = 0.9322033898305084
# confusion matrix: tn, fp, fn, tp [ 10   1   7 100]
# Predict majority: accuracy= 0.9067796610169492
#
# * TRAIN RESULTS *
# precision, recall, F1 = (1.0, 0.987152034261242, 0.9935344827586208)
# n = 1061  accuracy = 0.9886899151743638
# confusion matrix: tn, fp, fn, tp [127   0  12 922]
# Predict majority: accuracy= 0.8803016022620169
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9693877551020408, 0.9405940594059405, 0.9547738693467337)
# n = 118  accuracy = 0.923728813559322
# confusion matrix: tn, fp, fn, tp [14  3  6 95]
# Predict majority: accuracy= 0.8559322033898306
# * TRAIN RESULTS *
# precision, recall, F1 = (0.998914223669924, 0.9924487594390508, 0.9956709956709957)
# n = 1061  accuracy = 0.9924599434495759
# confusion matrix: tn, fp, fn, tp [133   1   7 920]
# Predict majority: accuracy= 0.8737040527803959
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9716981132075472, 0.9537037037037037, 0.9626168224299064)
# n = 118  accuracy = 0.9322033898305084
# confusion matrix: tn, fp, fn, tp [  7   3   5 103]
# Predict majority: accuracy= 0.9152542372881356
#
# * TRAIN RESULTS *
# precision, recall, F1 = (1.0, 0.9871106337271751, 0.9935135135135136)
# n = 1062  accuracy = 0.9887005649717514
# confusion matrix: tn, fp, fn, tp [131   0  12 919]
# Predict majority: accuracy= 0.876647834274953
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9693877551020408, 0.9134615384615384, 0.9405940594059407)
# n = 117  accuracy = 0.8974358974358975
# confusion matrix: tn, fp, fn, tp [10  3  9 95]
# Predict majority: accuracy= 0.8888888888888888
#
#             Acc   Maj_acc      Prec    Recall        F1
# Mean   0.916862  0.877872  0.976000  0.928397  0.951295
# StDev  0.019584  0.029370  0.012485  0.027315  0.012015
#
# ImbaburaQuechua
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9866342648845686, 0.9598108747044918, 0.9730377471539844)
# n = 1187  accuracy = 0.962089300758214
# confusion matrix: tn, fp, fn, tp [330  11  34 812]
# Predict majority: accuracy= 0.7127211457455771
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9473684210526315, 0.8372093023255814, 0.8888888888888888)
# n = 132  accuracy = 0.8636363636363636
# confusion matrix: tn, fp, fn, tp [42  4 14 72]
# Predict majority: accuracy= 0.6515151515151515
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9851116625310173, 0.948626045400239, 0.9665246500304322)
# n = 1187  accuracy = 0.953664700926706
# confusion matrix: tn, fp, fn, tp [338  12  43 794]
# Predict majority: accuracy= 0.7051390058972199
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9545454545454546, 0.8842105263157894, 0.9180327868852459)
# n = 132  accuracy = 0.8863636363636364
# confusion matrix: tn, fp, fn, tp [33  4 11 84]
# Predict majority: accuracy= 0.7196969696969697
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9838909541511772, 0.9474940334128878, 0.9653495440729483)
# n = 1187  accuracy = 0.9519797809604044
# confusion matrix: tn, fp, fn, tp [336  13  44 794]
# Predict majority: accuracy= 0.7059814658803707
#
# * TEST RESULTS *
# precision, recall, F1 = (0.946236559139785, 0.9361702127659575, 0.9411764705882354)
# n = 132  accuracy = 0.9166666666666666
# confusion matrix: tn, fp, fn, tp [33  5  6 88]
# Predict majority: accuracy= 0.7121212121212122
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9874843554443054, 0.9494584837545126, 0.9680981595092024)
# n = 1187  accuracy = 0.9561920808761584
# confusion matrix: tn, fp, fn, tp [346  10  42 789]
# Predict majority: accuracy= 0.7000842459983151
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9489795918367347, 0.9207920792079208, 0.934673366834171)
# n = 132  accuracy = 0.9015151515151515
# confusion matrix: tn, fp, fn, tp [26  5  8 93]
# Predict majority: accuracy= 0.7651515151515151
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9862671660424469, 0.9483793517406963, 0.966952264381885)
# n = 1187  accuracy = 0.9545071609098568
# confusion matrix: tn, fp, fn, tp [343  11  43 790]
# Predict majority: accuracy= 0.7017691659646167
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9444444444444444, 0.8585858585858586, 0.8994708994708994)
# n = 132  accuracy = 0.8560606060606061
# confusion matrix: tn, fp, fn, tp [28  5 14 85]
# Predict majority: accuracy= 0.75
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9888751545117429, 0.9456264775413712, 0.9667673716012085)
# n = 1187  accuracy = 0.953664700926706
# confusion matrix: tn, fp, fn, tp [332   9  46 800]
# Predict majority: accuracy= 0.7127211457455771
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8829787234042553, 0.9651162790697675, 0.9222222222222223)
# n = 132  accuracy = 0.8939393939393939
# confusion matrix: tn, fp, fn, tp [35 11  3 83]
# Predict majority: accuracy= 0.6515151515151515
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9876390605686032, 0.9523241954707986, 0.9696601941747572)
# n = 1187  accuracy = 0.95787700084246
# confusion matrix: tn, fp, fn, tp [338  10  40 799]
# Predict majority: accuracy= 0.7068239258635215
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9382716049382716, 0.8172043010752689, 0.8735632183908048)
# n = 132  accuracy = 0.8333333333333334
# confusion matrix: tn, fp, fn, tp [34  5 17 76]
# Predict majority: accuracy= 0.7045454545454546
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9849435382685069, 0.9469240048250904, 0.965559655596556)
# n = 1187  accuracy = 0.9528222409435552
# confusion matrix: tn, fp, fn, tp [346  12  44 785]
# Predict majority: accuracy= 0.6983993260320135
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9603960396039604, 0.941747572815534, 0.9509803921568628)
# n = 132  accuracy = 0.9242424242424242
# confusion matrix: tn, fp, fn, tp [25  4  6 97]
# Predict majority: accuracy= 0.7803030303030303
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9828641370869033, 0.9491725768321513, 0.9657245941070355)
# n = 1187  accuracy = 0.9519797809604044
# confusion matrix: tn, fp, fn, tp [327  14  43 803]
# Predict majority: accuracy= 0.7127211457455771
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9176470588235294, 0.9069767441860465, 0.9122807017543859)
# n = 132  accuracy = 0.8863636363636364
# confusion matrix: tn, fp, fn, tp [39  7  8 78]
# Predict majority: accuracy= 0.6515151515151515
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9900990099009901, 0.9489916963226572, 0.9691096305269533)
# n = 1188  accuracy = 0.9570707070707071
# confusion matrix: tn, fp, fn, tp [337   8  43 800]
# Predict majority: accuracy= 0.7095959595959596
#
# * TEST RESULTS *
# precision, recall, F1 = (0.891566265060241, 0.8314606741573034, 0.8604651162790697)
# n = 131  accuracy = 0.816793893129771
# confusion matrix: tn, fp, fn, tp [33  9 15 74]
# Predict majority: accuracy= 0.6793893129770993
#
#             Acc   Maj_acc      Prec    Recall        F1
# Mean   0.877892  0.706575  0.933243  0.889947  0.910175
# StDev  0.034975  0.048067  0.026801  0.051878  0.029471
#
# Mapudungun
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9967602591792657, 0.9525283797729618, 0.9741424802110817)
# n = 1270  accuracy = 0.9614173228346456
# confusion matrix: tn, fp, fn, tp [298   3  46 923]
# Predict majority: accuracy= 0.7629921259842519
#
# * TEST RESULTS *
# precision, recall, F1 = (0.908256880733945, 0.8918918918918919, 0.9)
# n = 142  accuracy = 0.8450704225352113
# confusion matrix: tn, fp, fn, tp [21 10 12 99]
# Predict majority: accuracy= 0.7816901408450704
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9956803455723542, 0.9514963880288958, 0.9730870712401055)
# n = 1270  accuracy = 0.9598425196850394
# confusion matrix: tn, fp, fn, tp [297   4  47 922]
# Predict majority: accuracy= 0.7629921259842519
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9252336448598131, 0.8918918918918919, 0.908256880733945)
# n = 142  accuracy = 0.8591549295774648
# confusion matrix: tn, fp, fn, tp [23  8 12 99]
# Predict majority: accuracy= 0.7816901408450704
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9946695095948828, 0.9520408163265306, 0.97288842544317)
# n = 1271  accuracy = 0.959087332808812
# confusion matrix: tn, fp, fn, tp [286   5  47 933]
# Predict majority: accuracy= 0.7710464201416207
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8673469387755102, 0.85, 0.8585858585858585)
# n = 141  accuracy = 0.8014184397163121
# confusion matrix: tn, fp, fn, tp [28 13 15 85]
# Predict majority: accuracy= 0.7092198581560284
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9914163090128756, 0.9575129533678757, 0.974169741697417)
# n = 1271  accuracy = 0.9614476789929189
# confusion matrix: tn, fp, fn, tp [298   8  41 924]
# Predict majority: accuracy= 0.7592446892210858
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9339622641509434, 0.8608695652173913, 0.8959276018099547)
# n = 141  accuracy = 0.8368794326241135
# confusion matrix: tn, fp, fn, tp [19  7 16 99]
# Predict majority: accuracy= 0.8156028368794326
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9925213675213675, 0.9498977505112475, 0.9707419017763845)
# n = 1271  accuracy = 0.955940204563336
# confusion matrix: tn, fp, fn, tp [286   7  49 929]
# Predict majority: accuracy= 0.7694728560188828
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9438202247191011, 0.8235294117647058, 0.8795811518324608)
# n = 141  accuracy = 0.8368794326241135
# confusion matrix: tn, fp, fn, tp [34  5 18 84]
# Predict majority: accuracy= 0.723404255319149
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9935965848452508, 0.9519427402862985, 0.9723237597911227)
# n = 1271  accuracy = 0.9583005507474429
# confusion matrix: tn, fp, fn, tp [287   6  47 931]
# Predict majority: accuracy= 0.7694728560188828
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9306930693069307, 0.9215686274509803, 0.9261083743842364)
# n = 141  accuracy = 0.8936170212765957
# confusion matrix: tn, fp, fn, tp [32  7  8 94]
# Predict majority: accuracy= 0.723404255319149
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9978260869565218, 0.9483471074380165, 0.9724576271186441)
# n = 1271  accuracy = 0.959087332808812
# confusion matrix: tn, fp, fn, tp [301   2  50 918]
# Predict majority: accuracy= 0.7616050354051928
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9805825242718447, 0.9017857142857143, 0.9395348837209301)
# n = 141  accuracy = 0.9078014184397163
# confusion matrix: tn, fp, fn, tp [ 27   2  11 101]
# Predict majority: accuracy= 0.7943262411347518
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9946351931330472, 0.9517453798767967, 0.9727177334732424)
# n = 1271  accuracy = 0.959087332808812
# confusion matrix: tn, fp, fn, tp [292   5  47 927]
# Predict majority: accuracy= 0.7663257277734068
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9587628865979382, 0.8773584905660378, 0.916256157635468)
# n = 141  accuracy = 0.8794326241134752
# confusion matrix: tn, fp, fn, tp [31  4 13 93]
# Predict majority: accuracy= 0.75177304964539
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9978494623655914, 0.9547325102880658, 0.9758149316508938)
# n = 1271  accuracy = 0.963808025177026
# confusion matrix: tn, fp, fn, tp [297   2  44 928]
# Predict majority: accuracy= 0.7647521636506688
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9595959595959596, 0.8796296296296297, 0.9178743961352657)
# n = 141  accuracy = 0.8794326241134752
# confusion matrix: tn, fp, fn, tp [29  4 13 95]
# Predict majority: accuracy= 0.7659574468085106
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9956616052060737, 0.9493278179937953, 0.9719428268925357)
# n = 1271  accuracy = 0.9583005507474429
# confusion matrix: tn, fp, fn, tp [300   4  49 918]
# Predict majority: accuracy= 0.7608182533438238
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9238095238095239, 0.8584070796460177, 0.8899082568807339)
# n = 141  accuracy = 0.8297872340425532
# confusion matrix: tn, fp, fn, tp [20  8 16 97]
# Predict majority: accuracy= 0.8014184397163121
#
#             Acc   Maj_acc      Prec    Recall        F1
# Mean   0.856947  0.764849  0.933206  0.875693  0.903203
# StDev  0.032854  0.036593  0.031315  0.028340  0.023675
#
# Qeqchi
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9938356164383562, 0.9583883751651255, 0.9757901815736383)
# n = 1795  accuracy = 0.9598885793871866
# confusion matrix: tn, fp, fn, tp [ 272    9   63 1451]
# Predict majority: accuracy= 0.8434540389972145
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9506172839506173, 0.8953488372093024, 0.9221556886227545)
# n = 200  accuracy = 0.87
# confusion matrix: tn, fp, fn, tp [ 20   8  18 154]
# Predict majority: accuracy= 0.86
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9925423728813559, 0.9625246548323472, 0.9773030707610149)
# n = 1795  accuracy = 0.962116991643454
# confusion matrix: tn, fp, fn, tp [ 263   11   57 1464]
# Predict majority: accuracy= 0.8473537604456824
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9006211180124224, 0.8787878787878788, 0.8895705521472393)
# n = 200  accuracy = 0.82
# confusion matrix: tn, fp, fn, tp [ 19  16  20 145]
# Predict majority: accuracy= 0.825
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.992445054945055, 0.9563203176704169, 0.9740478597910348)
# n = 1795  accuracy = 0.9571030640668524
# confusion matrix: tn, fp, fn, tp [ 273   11   66 1445]
# Predict majority: accuracy= 0.8417827298050139
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9440993788819876, 0.8685714285714285, 0.9047619047619048)
# n = 200  accuracy = 0.84
# confusion matrix: tn, fp, fn, tp [ 16   9  23 152]
# Predict majority: accuracy= 0.875
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9952283571915473, 0.958634274458306, 0.9765886287625418)
# n = 1795  accuracy = 0.9610027855153204
# confusion matrix: tn, fp, fn, tp [ 265    7   63 1460]
# Predict majority: accuracy= 0.8484679665738162
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9171974522292994, 0.8834355828220859, 0.9)
# n = 200  accuracy = 0.84
# confusion matrix: tn, fp, fn, tp [ 24  13  19 144]
# Predict majority: accuracy= 0.815
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9931412894375857, 0.9570389953734303, 0.9747559744193873)
# n = 1795  accuracy = 0.958217270194986
# confusion matrix: tn, fp, fn, tp [ 272   10   65 1448]
# Predict majority: accuracy= 0.8428969359331476
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9802631578947368, 0.861271676300578, 0.916923076923077)
# n = 200  accuracy = 0.865
# confusion matrix: tn, fp, fn, tp [ 24   3  24 149]
# Predict majority: accuracy= 0.865
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9945652173913043, 0.9625246548323472, 0.9782826595389242)
# n = 1796  accuracy = 0.9638084632516704
# confusion matrix: tn, fp, fn, tp [ 267    8   57 1464]
# Predict majority: accuracy= 0.8468819599109132
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9050632911392406, 0.8666666666666667, 0.8854489164086687)
# n = 199  accuracy = 0.8140703517587939
# confusion matrix: tn, fp, fn, tp [ 19  15  22 143]
# Predict majority: accuracy= 0.8291457286432161
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9959183673469387, 0.9606299212598425, 0.9779559118236472)
# n = 1796  accuracy = 0.9632516703786191
# confusion matrix: tn, fp, fn, tp [ 266    6   60 1464]
# Predict majority: accuracy= 0.8485523385300668
#
# * TEST RESULTS *
# precision, recall, F1 = (0.91875, 0.9074074074074074, 0.9130434782608695)
# n = 199  accuracy = 0.8592964824120602
# confusion matrix: tn, fp, fn, tp [ 24  13  15 147]
# Predict majority: accuracy= 0.8140703517587939
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9945578231292517, 0.9624753127057275, 0.9782535965205754)
# n = 1796  accuracy = 0.9638084632516704
# confusion matrix: tn, fp, fn, tp [ 269    8   57 1462]
# Predict majority: accuracy= 0.8457683741648107
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9386503067484663, 0.9161676646706587, 0.9272727272727274)
# n = 199  accuracy = 0.8793969849246231
# confusion matrix: tn, fp, fn, tp [ 22  10  14 153]
# Predict majority: accuracy= 0.8391959798994975
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9917638984214139, 0.9588586595885866, 0.975033738191633)
# n = 1796  accuracy = 0.9587973273942093
# confusion matrix: tn, fp, fn, tp [ 277   12   62 1445]
# Predict majority: accuracy= 0.839086859688196
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9810126582278481, 0.8659217877094972, 0.9198813056379822)
# n = 199  accuracy = 0.864321608040201
# confusion matrix: tn, fp, fn, tp [ 17   3  24 155]
# Predict majority: accuracy= 0.8994974874371859
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9945317840054683, 0.9566074950690335, 0.975201072386059)
# n = 1796  accuracy = 0.9587973273942093
# confusion matrix: tn, fp, fn, tp [ 267    8   66 1455]
# Predict majority: accuracy= 0.8468819599109132
#
# * TEST RESULTS *
# precision, recall, F1 = (0.91875, 0.8909090909090909, 0.9046153846153846)
# n = 199  accuracy = 0.8442211055276382
# confusion matrix: tn, fp, fn, tp [ 21  13  18 147]
# Predict majority: accuracy= 0.8291457286432161
#
#             Acc   Maj_acc      Prec    Recall        F1
# Mean   0.849631  0.845106  0.935502  0.883449  0.908367
# StDev  0.021612  0.028456  0.028726  0.018754  0.013948
#
# Wichi
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9931305201177625, 0.9730769230769231, 0.9830014570179698)
# n = 1224  accuracy = 0.9714052287581699
# confusion matrix: tn, fp, fn, tp [ 177    7   28 1012]
# Predict majority: accuracy= 0.8496732026143791
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9732142857142857, 0.956140350877193, 0.9646017699115044)
# n = 137  accuracy = 0.9416058394160584
# confusion matrix: tn, fp, fn, tp [ 20   3   5 109]
# Predict majority: accuracy= 0.8321167883211679
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9960707269155207, 0.9731285988483686, 0.9844660194174758)
# n = 1225  accuracy = 0.9738775510204082
# confusion matrix: tn, fp, fn, tp [ 179    4   28 1014]
# Predict majority: accuracy= 0.8506122448979592
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9646017699115044, 0.9732142857142857, 0.9688888888888889)
# n = 136  accuracy = 0.9485294117647058
# confusion matrix: tn, fp, fn, tp [ 20   4   3 109]
# Predict majority: accuracy= 0.8235294117647058
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9931305201177625, 0.9758919961427194, 0.9844357976653696)
# n = 1225  accuracy = 0.9738775510204082
# confusion matrix: tn, fp, fn, tp [ 181    7   25 1012]
# Predict majority: accuracy= 0.846530612244898
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9734513274336283, 0.9401709401709402, 0.9565217391304347)
# n = 136  accuracy = 0.9264705882352942
# confusion matrix: tn, fp, fn, tp [ 16   3   7 110]
# Predict majority: accuracy= 0.8602941176470589
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9950738916256158, 0.9730250481695568, 0.9839259620068193)
# n = 1225  accuracy = 0.9730612244897959
# confusion matrix: tn, fp, fn, tp [ 182    5   28 1010]
# Predict majority: accuracy= 0.8473469387755102
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9636363636363636, 0.9137931034482759, 0.9380530973451328)
# n = 136  accuracy = 0.8970588235294118
# confusion matrix: tn, fp, fn, tp [ 16   4  10 106]
# Predict majority: accuracy= 0.8529411764705882
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9950835791543756, 0.9721421709894332, 0.9834791059280855)
# n = 1225  accuracy = 0.9722448979591837
# confusion matrix: tn, fp, fn, tp [ 179    5   29 1012]
# Predict majority: accuracy= 0.8497959183673469
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9469026548672567, 0.9469026548672567, 0.9469026548672567)
# n = 136  accuracy = 0.9117647058823529
# confusion matrix: tn, fp, fn, tp [ 17   6   6 107]
# Predict majority: accuracy= 0.8308823529411765
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9940828402366864, 0.9720347155255545, 0.9829351535836178)
# n = 1225  accuracy = 0.9714285714285714
# confusion matrix: tn, fp, fn, tp [ 182    6   29 1008]
# Predict majority: accuracy= 0.846530612244898
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9824561403508771, 0.9572649572649573, 0.9696969696969696)
# n = 136  accuracy = 0.9485294117647058
# confusion matrix: tn, fp, fn, tp [ 17   2   5 112]
# Predict majority: accuracy= 0.8602941176470589
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9941176470588236, 0.976878612716763, 0.9854227405247814)
# n = 1225  accuracy = 0.9755102040816327
# confusion matrix: tn, fp, fn, tp [ 181    6   24 1014]
# Predict majority: accuracy= 0.8473469387755102
#
# * TEST RESULTS *
# precision, recall, F1 = (1.0, 0.9396551724137931, 0.9688888888888889)
# n = 136  accuracy = 0.9485294117647058
# confusion matrix: tn, fp, fn, tp [ 20   0   7 109]
# Predict majority: accuracy= 0.8529411764705882
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.994140625, 0.9760306807286673, 0.9850024189646831)
# n = 1225  accuracy = 0.9746938775510204
# confusion matrix: tn, fp, fn, tp [ 176    6   25 1018]
# Predict majority: accuracy= 0.8514285714285714
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9642857142857143, 0.972972972972973, 0.968609865470852)
# n = 136  accuracy = 0.9485294117647058
# confusion matrix: tn, fp, fn, tp [ 21   4   3 108]
# Predict majority: accuracy= 0.8161764705882353
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9940944881889764, 0.9702209414024976, 0.9820126397666504)
# n = 1225  accuracy = 0.9697959183673469
# confusion matrix: tn, fp, fn, tp [ 178    6   31 1010]
# Predict majority: accuracy= 0.8497959183673469
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9537037037037037, 0.911504424778761, 0.9321266968325793)
# n = 136  accuracy = 0.8897058823529411
# confusion matrix: tn, fp, fn, tp [ 18   5  10 103]
# Predict majority: accuracy= 0.8308823529411765
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9940476190476191, 0.9737609329446064, 0.98379970544919)
# n = 1225  accuracy = 0.9730612244897959
# confusion matrix: tn, fp, fn, tp [ 190    6   27 1002]
# Predict majority: accuracy= 0.84
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9830508474576272, 0.928, 0.9547325102880659)
# n = 136  accuracy = 0.9191176470588235
# confusion matrix: tn, fp, fn, tp [  9   2   9 116]
# Predict majority: accuracy= 0.9191176470588235
#
#             Acc   Maj_acc      Prec    Recall        F1
# Mean   0.927984  0.847918  0.970530  0.943962  0.956902
# StDev  0.022705  0.029550  0.015443  0.021814  0.013830

# %%
# Test k_fold dual basis word discrimination - Based on segmented IPA (segments).
# No interest in return table of k-fold trials, thus the _ return value.
for l in languages:
    _ = k_fold_language_word_discrimination_dual_basis(l, form='segments', smoothing=0.5, k_fold=10)
# Out:
# English
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9734177215189873, 0.9746514575411914, 0.9740341988600381)
# n = 1364  accuracy = 0.9699413489736071
# confusion matrix: tn, fp, fn, tp [554  21  20 769]
# Predict majority: accuracy= 0.5784457478005866
#
# * TEST RESULTS *
# precision, recall, F1 = (0.7558139534883721, 0.7738095238095238, 0.7647058823529412)
# n = 152  accuracy = 0.7368421052631579
# confusion matrix: tn, fp, fn, tp [47 21 19 65]
# Predict majority: accuracy= 0.5526315789473685
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9720812182741116, 0.9782886334610472, 0.9751750477402928)
# n = 1364  accuracy = 0.9714076246334311
# confusion matrix: tn, fp, fn, tp [559  22  17 766]
# Predict majority: accuracy= 0.5740469208211144
#
# * TEST RESULTS *
# precision, recall, F1 = (0.7530864197530864, 0.6777777777777778, 0.7134502923976608)
# n = 152  accuracy = 0.6776315789473685
# confusion matrix: tn, fp, fn, tp [42 20 29 61]
# Predict majority: accuracy= 0.5921052631578947
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9768339768339769, 0.9693486590038314, 0.9730769230769232)
# n = 1364  accuracy = 0.969208211143695
# confusion matrix: tn, fp, fn, tp [563  18  24 759]
# Predict majority: accuracy= 0.5740469208211144
#
# * TEST RESULTS *
# precision, recall, F1 = (0.7333333333333333, 0.7333333333333333, 0.7333333333333333)
# n = 152  accuracy = 0.6842105263157895
# confusion matrix: tn, fp, fn, tp [38 24 24 66]
# Predict majority: accuracy= 0.5921052631578947
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9820742637644047, 0.9721166032953105, 0.9770700636942674)
# n = 1364  accuracy = 0.9736070381231672
# confusion matrix: tn, fp, fn, tp [561  14  22 767]
# Predict majority: accuracy= 0.5784457478005866
#
# * TEST RESULTS *
# precision, recall, F1 = (0.7317073170731707, 0.7142857142857143, 0.7228915662650603)
# n = 152  accuracy = 0.6973684210526315
# confusion matrix: tn, fp, fn, tp [46 22 24 60]
# Predict majority: accuracy= 0.5526315789473685
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9732484076433121, 0.9707750952986023, 0.9720101781170484)
# n = 1364  accuracy = 0.967741935483871
# confusion matrix: tn, fp, fn, tp [556  21  23 764]
# Predict majority: accuracy= 0.5769794721407625
#
# * TEST RESULTS *
# precision, recall, F1 = (0.7802197802197802, 0.8255813953488372, 0.8022598870056498)
# n = 152  accuracy = 0.7697368421052632
# confusion matrix: tn, fp, fn, tp [46 20 15 71]
# Predict majority: accuracy= 0.5657894736842105
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9759493670886076, 0.969811320754717, 0.9728706624605679)
# n = 1364  accuracy = 0.968475073313783
# confusion matrix: tn, fp, fn, tp [550  19  24 771]
# Predict majority: accuracy= 0.5828445747800587
#
# * TEST RESULTS *
# precision, recall, F1 = (0.6708860759493671, 0.6794871794871795, 0.6751592356687899)
# n = 152  accuracy = 0.6644736842105263
# confusion matrix: tn, fp, fn, tp [48 26 25 53]
# Predict majority: accuracy= 0.5131578947368421
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9794079794079794, 0.9756410256410256, 0.9775208734746307)
# n = 1365  accuracy = 0.9743589743589743
# confusion matrix: tn, fp, fn, tp [569  16  19 761]
# Predict majority: accuracy= 0.5714285714285714
#
# * TEST RESULTS *
# precision, recall, F1 = (0.75, 0.7096774193548387, 0.729281767955801)
# n = 151  accuracy = 0.6754966887417219
# confusion matrix: tn, fp, fn, tp [36 22 27 66]
# Predict majority: accuracy= 0.6158940397350994
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9793014230271668, 0.9705128205128205, 0.9748873148744366)
# n = 1365  accuracy = 0.9714285714285714
# confusion matrix: tn, fp, fn, tp [569  16  23 757]
# Predict majority: accuracy= 0.5714285714285714
#
# * TEST RESULTS *
# precision, recall, F1 = (0.7608695652173914, 0.7526881720430108, 0.7567567567567567)
# n = 151  accuracy = 0.7019867549668874
# confusion matrix: tn, fp, fn, tp [36 22 23 70]
# Predict majority: accuracy= 0.6158940397350994
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9720457433290979, 0.9770114942528736, 0.9745222929936306)
# n = 1365  accuracy = 0.9706959706959707
# confusion matrix: tn, fp, fn, tp [560  22  18 765]
# Predict majority: accuracy= 0.5736263736263736
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8072289156626506, 0.7444444444444445, 0.7745664739884394)
# n = 151  accuracy = 0.7417218543046358
# confusion matrix: tn, fp, fn, tp [45 16 23 67]
# Predict majority: accuracy= 0.5960264900662252
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9781771501925546, 0.9670050761421319, 0.9725590299936183)
# n = 1365  accuracy = 0.9684981684981685
# confusion matrix: tn, fp, fn, tp [560  17  26 762]
# Predict majority: accuracy= 0.5772893772893772
#
# * TEST RESULTS *
# precision, recall, F1 = (0.75, 0.7764705882352941, 0.7630057803468209)
# n = 151  accuracy = 0.7284768211920529
# confusion matrix: tn, fp, fn, tp [44 22 19 66]
# Predict majority: accuracy= 0.5629139072847682
#
#             Acc   Maj_acc      Prec    Recall        F1
# Mean   0.707795  0.575915  0.749315  0.738756  0.743541
# StDev  0.034621  0.032352  0.035303  0.046093  0.036098
#
# Hup
#
# * TRAIN RESULTS *
# precision, recall, F1 = (1.0, 0.976545842217484, 0.9881337648327939)
# n = 1061  accuracy = 0.9792648444863337
# confusion matrix: tn, fp, fn, tp [123   0  22 916]
# Predict majority: accuracy= 0.884071630537229
#
# * TEST RESULTS *
# precision, recall, F1 = (0.967032967032967, 0.9072164948453608, 0.9361702127659575)
# n = 118  accuracy = 0.8983050847457628
# confusion matrix: tn, fp, fn, tp [18  3  9 88]
# Predict majority: accuracy= 0.8220338983050848
#
# * TRAIN RESULTS *
# precision, recall, F1 = (1.0, 0.9796137339055794, 0.9897018970189702)
# n = 1061  accuracy = 0.9820923656927427
# confusion matrix: tn, fp, fn, tp [129   0  19 913]
# Predict majority: accuracy= 0.8784165881244109
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9591836734693877, 0.912621359223301, 0.9353233830845772)
# n = 118  accuracy = 0.8898305084745762
# confusion matrix: tn, fp, fn, tp [11  4  9 94]
# Predict majority: accuracy= 0.8728813559322034
#
# * TRAIN RESULTS *
# precision, recall, F1 = (1.0, 0.975268817204301, 0.9874795862819815)
# n = 1061  accuracy = 0.9783223374175306
# confusion matrix: tn, fp, fn, tp [131   0  23 907]
# Predict majority: accuracy= 0.8765315739868049
#
# * TEST RESULTS *
# precision, recall, F1 = (0.970873786407767, 0.9523809523809523, 0.9615384615384616)
# n = 118  accuracy = 0.9322033898305084
# confusion matrix: tn, fp, fn, tp [ 10   3   5 100]
# Predict majority: accuracy= 0.8898305084745762
#
# * TRAIN RESULTS *
# precision, recall, F1 = (1.0, 0.9806034482758621, 0.9902067464635473)
# n = 1061  accuracy = 0.9830348727615457
# confusion matrix: tn, fp, fn, tp [133   0  18 910]
# Predict majority: accuracy= 0.8746465598491989
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9795918367346939, 0.897196261682243, 0.9365853658536586)
# n = 118  accuracy = 0.8898305084745762
# confusion matrix: tn, fp, fn, tp [ 9  2 11 96]
# Predict majority: accuracy= 0.9067796610169492
#
# * TRAIN RESULTS *
# precision, recall, F1 = (1.0, 0.9816810344827587, 0.9907558455682436)
# n = 1061  accuracy = 0.9839773798303487
# confusion matrix: tn, fp, fn, tp [133   0  17 911]
# Predict majority: accuracy= 0.8746465598491989
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9894736842105263, 0.8785046728971962, 0.9306930693069306)
# n = 118  accuracy = 0.8813559322033898
# confusion matrix: tn, fp, fn, tp [10  1 13 94]
# Predict majority: accuracy= 0.9067796610169492
#
# * TRAIN RESULTS *
# precision, recall, F1 = (1.0, 0.9743315508021391, 0.9869989165763814)
# n = 1061  accuracy = 0.9773798303487277
# confusion matrix: tn, fp, fn, tp [126   0  24 911]
# Predict majority: accuracy= 0.88124410933082
#
# * TEST RESULTS *
# precision, recall, F1 = (0.978494623655914, 0.91, 0.9430051813471503)
# n = 118  accuracy = 0.9067796610169492
# confusion matrix: tn, fp, fn, tp [16  2  9 91]
# Predict majority: accuracy= 0.847457627118644
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9989047097480832, 0.9838187702265372, 0.9913043478260869)
# n = 1061  accuracy = 0.9849198868991518
# confusion matrix: tn, fp, fn, tp [133   1  15 912]
# Predict majority: accuracy= 0.8737040527803959
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9797979797979798, 0.8981481481481481, 0.9371980676328502)
# n = 118  accuracy = 0.8898305084745762
# confusion matrix: tn, fp, fn, tp [ 8  2 11 97]
# Predict majority: accuracy= 0.9152542372881356
#
# * TRAIN RESULTS *
# precision, recall, F1 = (1.0, 0.9773706896551724, 0.9885558583106266)
# n = 1061  accuracy = 0.9802073515551367
# confusion matrix: tn, fp, fn, tp [133   0  21 907]
# Predict majority: accuracy= 0.8746465598491989
#
# * TEST RESULTS *
# precision, recall, F1 = (1.0, 0.897196261682243, 0.9458128078817734)
# n = 118  accuracy = 0.9067796610169492
# confusion matrix: tn, fp, fn, tp [11  0 11 96]
# Predict majority: accuracy= 0.9067796610169492
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9989071038251366, 0.9785867237687366, 0.9886425094645753)
# n = 1061  accuracy = 0.9802073515551367
# confusion matrix: tn, fp, fn, tp [126   1  20 914]
# Predict majority: accuracy= 0.8803016022620169
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9655172413793104, 0.8316831683168316, 0.8936170212765958)
# n = 118  accuracy = 0.8305084745762712
# confusion matrix: tn, fp, fn, tp [14  3 17 84]
# Predict majority: accuracy= 0.8559322033898306
#
# * TRAIN RESULTS *
# precision, recall, F1 = (1.0, 0.9796791443850268, 0.9897352782279849)
# n = 1062  accuracy = 0.9821092278719398
# confusion matrix: tn, fp, fn, tp [127   0  19 916]
# Predict majority: accuracy= 0.8804143126177024
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9479166666666666, 0.91, 0.9285714285714285)
# n = 117  accuracy = 0.8803418803418803
# confusion matrix: tn, fp, fn, tp [12  5  9 91]
# Predict majority: accuracy= 0.8547008547008547
#
#             Acc   Maj_acc      Prec    Recall        F1
# Mean   0.890577  0.877843  0.973788  0.899495  0.934851
# StDev  0.026071  0.031856  0.015019  0.030370  0.017212
#
# ImbaburaQuechua
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.98531211750306, 0.961768219832736, 0.9733978234582831)
# n = 1187  accuracy = 0.9629317607413648
# confusion matrix: tn, fp, fn, tp [338  12  32 805]
# Predict majority: accuracy= 0.7051390058972199
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9375, 0.9473684210526315, 0.9424083769633508)
# n = 132  accuracy = 0.9166666666666666
# confusion matrix: tn, fp, fn, tp [31  6  5 90]
# Predict majority: accuracy= 0.7196969696969697
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9863861386138614, 0.9567827130852341, 0.9713589274832419)
# n = 1187  accuracy = 0.9604043807919124
# confusion matrix: tn, fp, fn, tp [343  11  36 797]
# Predict majority: accuracy= 0.7017691659646167
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9680851063829787, 0.9191919191919192, 0.9430051813471503)
# n = 132  accuracy = 0.9166666666666666
# confusion matrix: tn, fp, fn, tp [30  3  8 91]
# Predict majority: accuracy= 0.75
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9877450980392157, 0.9595238095238096, 0.9734299516908212)
# n = 1187  accuracy = 0.9629317607413648
# confusion matrix: tn, fp, fn, tp [337  10  34 806]
# Predict majority: accuracy= 0.7076663858466723
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8804347826086957, 0.8804347826086957, 0.8804347826086957)
# n = 132  accuracy = 0.8333333333333334
# confusion matrix: tn, fp, fn, tp [29 11 11 81]
# Predict majority: accuracy= 0.696969696969697
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.989010989010989, 0.9585798816568047, 0.9735576923076924)
# n = 1187  accuracy = 0.9629317607413648
# confusion matrix: tn, fp, fn, tp [333   9  35 810]
# Predict majority: accuracy= 0.7118786857624263
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9156626506024096, 0.8735632183908046, 0.8941176470588235)
# n = 132  accuracy = 0.8636363636363636
# confusion matrix: tn, fp, fn, tp [38  7 11 76]
# Predict majority: accuracy= 0.6590909090909091
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9890377588306942, 0.9586776859504132, 0.9736211031175058)
# n = 1187  accuracy = 0.9629317607413648
# confusion matrix: tn, fp, fn, tp [331   9  35 812]
# Predict majority: accuracy= 0.7135636057287279
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9239130434782609, 1.0, 0.96045197740113)
# n = 132  accuracy = 0.946969696969697
# confusion matrix: tn, fp, fn, tp [40  7  0 85]
# Predict majority: accuracy= 0.6439393939393939
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9888888888888889, 0.9581339712918661, 0.9732685297691372)
# n = 1187  accuracy = 0.9629317607413648
# confusion matrix: tn, fp, fn, tp [342   9  35 801]
# Predict majority: accuracy= 0.7042965459140691
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9354838709677419, 0.90625, 0.9206349206349206)
# n = 132  accuracy = 0.8863636363636364
# confusion matrix: tn, fp, fn, tp [30  6  9 87]
# Predict majority: accuracy= 0.7272727272727273
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9866666666666667, 0.961038961038961, 0.9736842105263157)
# n = 1187  accuracy = 0.9629317607413648
# confusion matrix: tn, fp, fn, tp [329  11  33 814]
# Predict majority: accuracy= 0.7135636057287279
#
# * TEST RESULTS *
# precision, recall, F1 = (0.96, 0.8470588235294118, 0.8999999999999999)
# n = 132  accuracy = 0.8787878787878788
# confusion matrix: tn, fp, fn, tp [44  3 13 72]
# Predict majority: accuracy= 0.6439393939393939
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9901477832512315, 0.9560047562425684, 0.9727767695099818)
# n = 1187  accuracy = 0.962089300758214
# confusion matrix: tn, fp, fn, tp [338   8  37 804]
# Predict majority: accuracy= 0.7085088458298231
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9310344827586207, 0.8901098901098901, 0.9101123595505618)
# n = 132  accuracy = 0.8787878787878788
# confusion matrix: tn, fp, fn, tp [35  6 10 81]
# Predict majority: accuracy= 0.6893939393939394
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9899874843554443, 0.9518652226233454, 0.9705521472392638)
# n = 1187  accuracy = 0.9595619208087616
# confusion matrix: tn, fp, fn, tp [348   8  40 791]
# Predict majority: accuracy= 0.7000842459983151
#
# * TEST RESULTS *
# precision, recall, F1 = (0.968421052631579, 0.9108910891089109, 0.9387755102040817)
# n = 132  accuracy = 0.9090909090909091
# confusion matrix: tn, fp, fn, tp [28  3  9 92]
# Predict majority: accuracy= 0.7651515151515151
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9863692688971499, 0.9578820697954272, 0.9719169719169719)
# n = 1188  accuracy = 0.9612794612794613
# confusion matrix: tn, fp, fn, tp [346  11  35 796]
# Predict majority: accuracy= 0.6994949494949495
#
# * TEST RESULTS *
# precision, recall, F1 = (0.956989247311828, 0.8811881188118812, 0.9175257731958764)
# n = 131  accuracy = 0.8778625954198473
# confusion matrix: tn, fp, fn, tp [26  4 12 89]
# Predict majority: accuracy= 0.7709923664122137
#
#             Acc   Maj_acc      Prec    Recall        F1
# Mean   0.890817  0.706645  0.937752  0.905606  0.920747
# StDev  0.032221  0.047791  0.027367  0.043194  0.025286
#
# Mapudungun
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9967948717948718, 0.9598765432098766, 0.9779874213836478)
# n = 1270  accuracy = 0.9669291338582677
# confusion matrix: tn, fp, fn, tp [295   3  39 933]
# Predict majority: accuracy= 0.7653543307086614
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9223300970873787, 0.8796296296296297, 0.9004739336492891)
# n = 142  accuracy = 0.852112676056338
# confusion matrix: tn, fp, fn, tp [26  8 13 95]
# Predict majority: accuracy= 0.7605633802816901
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9956709956709957, 0.9603340292275574, 0.977683315621679)
# n = 1270  accuracy = 0.9669291338582677
# confusion matrix: tn, fp, fn, tp [308   4  38 920]
# Predict majority: accuracy= 0.7543307086614173
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9557522123893806, 0.8852459016393442, 0.9191489361702128)
# n = 142  accuracy = 0.8661971830985915
# confusion matrix: tn, fp, fn, tp [ 15   5  14 108]
# Predict majority: accuracy= 0.8591549295774648
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9967776584317938, 0.9586776859504132, 0.9773565034228542)
# n = 1271  accuracy = 0.966168371361133
# confusion matrix: tn, fp, fn, tp [300   3  40 928]
# Predict majority: accuracy= 0.7616050354051928
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9615384615384616, 0.8928571428571429, 0.9259259259259259)
# n = 141  accuracy = 0.8865248226950354
# confusion matrix: tn, fp, fn, tp [ 25   4  12 100]
# Predict majority: accuracy= 0.7943262411347518
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9968017057569296, 0.9609455292908531, 0.97854526425955)
# n = 1271  accuracy = 0.967741935483871
# confusion matrix: tn, fp, fn, tp [295   3  38 935]
# Predict majority: accuracy= 0.7655389457120377
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8899082568807339, 0.9065420560747663, 0.8981481481481481)
# n = 141  accuracy = 0.8439716312056738
# confusion matrix: tn, fp, fn, tp [22 12 10 97]
# Predict majority: accuracy= 0.7588652482269503
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9968253968253968, 0.9651639344262295, 0.9807391983342009)
# n = 1271  accuracy = 0.970889063729347
# confusion matrix: tn, fp, fn, tp [292   3  34 942]
# Predict majority: accuracy= 0.7678992918961448
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9361702127659575, 0.8461538461538461, 0.8888888888888888)
# n = 141  accuracy = 0.8439716312056738
# confusion matrix: tn, fp, fn, tp [31  6 16 88]
# Predict majority: accuracy= 0.7375886524822695
# * TRAIN RESULTS *
# precision, recall, F1 = (0.996822033898305, 0.9592252803261978, 0.9776623376623378)
# n = 1271  accuracy = 0.966168371361133
# confusion matrix: tn, fp, fn, tp [287   3  40 941]
# Predict majority: accuracy= 0.7718332022029898
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9247311827956989, 0.8686868686868687, 0.8958333333333334)
# n = 141  accuracy = 0.8581560283687943
# confusion matrix: tn, fp, fn, tp [35  7 13 86]
# Predict majority: accuracy= 0.7021276595744681
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9978813559322034, 0.9612244897959183, 0.9792099792099791)
# n = 1271  accuracy = 0.96852871754524
# confusion matrix: tn, fp, fn, tp [289   2  38 942]
# Predict majority: accuracy= 0.7710464201416207
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9651162790697675, 0.83, 0.8924731182795699)
# n = 141  accuracy = 0.8581560283687943
# confusion matrix: tn, fp, fn, tp [38  3 17 83]
# Predict majority: accuracy= 0.7092198581560284
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9956989247311828, 0.95562435500516, 0.9752501316482358)
# n = 1271  accuracy = 0.963021243115657
# confusion matrix: tn, fp, fn, tp [298   4  43 926]
# Predict majority: accuracy= 0.7623918174665618
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8918918918918919, 0.8918918918918919, 0.8918918918918919)
# n = 141  accuracy = 0.8297872340425532
# confusion matrix: tn, fp, fn, tp [18 12 12 99]
# Predict majority: accuracy= 0.7872340425531915
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9956803455723542, 0.9604166666666667, 0.9777306468716862)
# n = 1271  accuracy = 0.9669551534225019
# confusion matrix: tn, fp, fn, tp [307   4  38 922]
# Predict majority: accuracy= 0.7553107789142408
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9611650485436893, 0.825, 0.8878923766816144)
# n = 141  accuracy = 0.8226950354609929
# confusion matrix: tn, fp, fn, tp [17  4 21 99]
# Predict majority: accuracy= 0.851063829787234
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9968454258675079, 0.9643947100712106, 0.9803516028955531)
# n = 1271  accuracy = 0.970102281667978
# confusion matrix: tn, fp, fn, tp [285   3  35 948]
# Predict majority: accuracy= 0.7734067663257278
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8877551020408163, 0.8969072164948454, 0.8923076923076922)
# n = 141  accuracy = 0.851063829787234
# confusion matrix: tn, fp, fn, tp [33 11 10 87]
# Predict majority: accuracy= 0.6879432624113475
#
#             Acc   Maj_acc      Prec    Recall        F1
# Mean   0.851264  0.764809  0.929636  0.872291  0.899298
# StDev  0.018092  0.059102  0.031322  0.028923  0.012938
#
# Qeqchi
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.99527983816588, 0.9723320158102767, 0.9836721092969011)
# n = 1795  accuracy = 0.9727019498607242
# confusion matrix: tn, fp, fn, tp [ 270    7   42 1476]
# Predict majority: accuracy= 0.8456824512534818
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9367088607594937, 0.8809523809523809, 0.9079754601226993)
# n = 200  accuracy = 0.85
# confusion matrix: tn, fp, fn, tp [ 22  10  20 148]
# Predict majority: accuracy= 0.84
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9966124661246613, 0.9735274652547982, 0.9849347171074657)
# n = 1795  accuracy = 0.9749303621169917
# confusion matrix: tn, fp, fn, tp [ 279    5   40 1471]
# Predict majority: accuracy= 0.8417827298050139
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9457831325301205, 0.8971428571428571, 0.9208211143695015)
# n = 200  accuracy = 0.865
# confusion matrix: tn, fp, fn, tp [ 16   9  18 157]
# Predict majority: accuracy= 0.875
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9979743416610398, 0.9717291255752795, 0.9846768820786143)
# n = 1795  accuracy = 0.9743732590529248
# confusion matrix: tn, fp, fn, tp [ 271    3   43 1478]
# Predict majority: accuracy= 0.8473537604456824
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9383561643835616, 0.8303030303030303, 0.8810289389067524)
# n = 200  accuracy = 0.815
# confusion matrix: tn, fp, fn, tp [ 26   9  28 137]
# Predict majority: accuracy= 0.825
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9959404600811907, 0.9716171617161716, 0.9836284664216505)
# n = 1795  accuracy = 0.9727019498607242
# confusion matrix: tn, fp, fn, tp [ 274    6   43 1472]
# Predict majority: accuracy= 0.8440111420612814
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9503105590062112, 0.8947368421052632, 0.9216867469879517)
# n = 200  accuracy = 0.87
# confusion matrix: tn, fp, fn, tp [ 21   8  18 153]
# Predict majority: accuracy= 0.855
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9945872801082544, 0.9683794466403162, 0.9813084112149533)
# n = 1795  accuracy = 0.9688022284122563
# confusion matrix: tn, fp, fn, tp [ 269    8   48 1470]
# Predict majority: accuracy= 0.8456824512534818
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9433962264150944, 0.8928571428571429, 0.9174311926605505)
# n = 200  accuracy = 0.865
# confusion matrix: tn, fp, fn, tp [ 23   9  18 150]
# Predict majority: accuracy= 0.84
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.997968855788761, 0.9690992767915845, 0.9833222148098733)
# n = 1796  accuracy = 0.9721603563474388
# confusion matrix: tn, fp, fn, tp [ 272    3   47 1474]
# Predict majority: accuracy= 0.8468819599109132
#
# * TEST RESULTS *
# precision, recall, F1 = (0.930379746835443, 0.8909090909090909, 0.9102167182662539)
# n = 199  accuracy = 0.8542713567839196
# confusion matrix: tn, fp, fn, tp [ 23  11  18 147]
# Predict majority: accuracy= 0.8291457286432161
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9973172367538564, 0.972531066056246, 0.9847682119205298)
# n = 1796  accuracy = 0.9743875278396437
# confusion matrix: tn, fp, fn, tp [ 263    4   42 1487]
# Predict majority: accuracy= 0.8513363028953229
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9060402684563759, 0.8598726114649682, 0.8823529411764707)
# n = 199  accuracy = 0.8190954773869347
# confusion matrix: tn, fp, fn, tp [ 28  14  22 135]
# Predict majority: accuracy= 0.7889447236180904
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9966307277628033, 0.9730263157894737, 0.9846870838881491)
# n = 1796  accuracy = 0.9743875278396437
# confusion matrix: tn, fp, fn, tp [ 271    5   41 1479]
# Predict majority: accuracy= 0.8463251670378619
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9090909090909091, 0.8433734939759037, 0.8750000000000001)
# n = 199  accuracy = 0.7989949748743719
# confusion matrix: tn, fp, fn, tp [ 19  14  26 140]
# Predict majority: accuracy= 0.8341708542713567
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9966055668703326, 0.9734748010610079, 0.9849043944984904)
# n = 1796  accuracy = 0.9749443207126949
# confusion matrix: tn, fp, fn, tp [ 283    5   40 1468]
# Predict majority: accuracy= 0.8396436525612472
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9875776397515528, 0.8932584269662921, 0.9380530973451326)
# n = 199  accuracy = 0.8944723618090452
# confusion matrix: tn, fp, fn, tp [ 19   2  19 159]
# Predict majority: accuracy= 0.8944723618090452
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.995945945945946, 0.9742233972240582, 0.9849649181423321)
# n = 1796  accuracy = 0.9749443207126949
# confusion matrix: tn, fp, fn, tp [ 277    6   39 1474]
# Predict majority: accuracy= 0.8424276169265034
#
# * TEST RESULTS *
# precision, recall, F1 = (0.95, 0.8786127167630058, 0.9129129129129129)
# n = 199  accuracy = 0.8542713567839196
# confusion matrix: tn, fp, fn, tp [ 18   8  21 152]
# Predict majority: accuracy= 0.8693467336683417
#
#             Acc   Maj_acc      Prec    Recall        F1
# Mean   0.848611  0.845108  0.939764  0.876202  0.906748
# StDev  0.029110  0.029816  0.022923  0.023679  0.020633
#
# Wichi
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9960822722820764, 0.9769452449567724, 0.9864209505334626)
# n = 1224  accuracy = 0.9771241830065359
# confusion matrix: tn, fp, fn, tp [ 179    4   24 1017]
# Predict majority: accuracy= 0.8504901960784313
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9636363636363636, 0.9380530973451328, 0.9506726457399104)
# n = 137  accuracy = 0.9197080291970803
# confusion matrix: tn, fp, fn, tp [ 20   4   7 106]
# Predict majority: accuracy= 0.8248175182481752
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9951124144672532, 0.9797882579403272, 0.9873908826382153)
# n = 1225  accuracy = 0.9787755102040816
# confusion matrix: tn, fp, fn, tp [ 181    5   21 1018]
# Predict majority: accuracy= 0.8481632653061224
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9557522123893806, 0.9391304347826087, 0.9473684210526316)
# n = 136  accuracy = 0.9117647058823529
# confusion matrix: tn, fp, fn, tp [ 16   5   7 108]
# Predict majority: accuracy= 0.8455882352941176
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9980449657869013, 0.9760994263862333, 0.9869502174963751)
# n = 1225  accuracy = 0.9779591836734693
# confusion matrix: tn, fp, fn, tp [ 177    2   25 1021]
# Predict majority: accuracy= 0.8538775510204082
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9626168224299065, 0.9537037037037037, 0.958139534883721)
# n = 136  accuracy = 0.9338235294117647
# confusion matrix: tn, fp, fn, tp [ 24   4   5 103]
# Predict majority: accuracy= 0.7941176470588235
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9960552268244576, 0.974903474903475, 0.9853658536585366)
# n = 1225  accuracy = 0.9755102040816327
# confusion matrix: tn, fp, fn, tp [ 185    4   26 1010]
# Predict majority: accuracy= 0.8457142857142858
#
# * TEST RESULTS *
# precision, recall, F1 = (1.0, 0.864406779661017, 0.9272727272727274)
# n = 136  accuracy = 0.8823529411764706
# confusion matrix: tn, fp, fn, tp [ 18   0  16 102]
# Predict majority: accuracy= 0.8676470588235294
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9970873786407767, 0.9837164750957854, 0.9903567984570877)
# n = 1225  accuracy = 0.9836734693877551
# confusion matrix: tn, fp, fn, tp [ 178    3   17 1027]
# Predict majority: accuracy= 0.8522448979591837
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9459459459459459, 0.9545454545454546, 0.9502262443438914)
# n = 136  accuracy = 0.9191176470588235
# confusion matrix: tn, fp, fn, tp [ 20   6   5 105]
# Predict majority: accuracy= 0.8088235294117647
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9950592885375494, 0.9748305905130688, 0.984841075794621)
# n = 1225  accuracy = 0.9746938775510204
# confusion matrix: tn, fp, fn, tp [ 187    5   26 1007]
# Predict majority: accuracy= 0.843265306122449
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9914529914529915, 0.9586776859504132, 0.9747899159663866)
# n = 136  accuracy = 0.9558823529411765
# confusion matrix: tn, fp, fn, tp [ 14   1   5 116]
# Predict majority: accuracy= 0.8897058823529411
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9960668633235005, 0.978743961352657, 0.9873294346978557)
# n = 1225  accuracy = 0.9787755102040816
# confusion matrix: tn, fp, fn, tp [ 186    4   22 1013]
# Predict majority: accuracy= 0.8448979591836735
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9743589743589743, 0.957983193277311, 0.9661016949152542)
# n = 136  accuracy = 0.9411764705882353
# confusion matrix: tn, fp, fn, tp [ 14   3   5 114]
# Predict majority: accuracy= 0.875
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9980430528375733, 0.9798270893371758, 0.9888511875908871)
# n = 1225  accuracy = 0.9812244897959184
# confusion matrix: tn, fp, fn, tp [ 182    2   21 1020]
# Predict majority: accuracy= 0.8497959183673469
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9545454545454546, 0.9292035398230089, 0.9417040358744395)
# n = 136  accuracy = 0.9044117647058824
# confusion matrix: tn, fp, fn, tp [ 18   5   8 105]
# Predict majority: accuracy= 0.8308823529411765
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9960629921259843, 0.9768339768339769, 0.9863547758284601)
# n = 1225  accuracy = 0.9771428571428571
# confusion matrix: tn, fp, fn, tp [ 185    4   24 1012]
# Predict majority: accuracy= 0.8457142857142858
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9741379310344828, 0.9576271186440678, 0.9658119658119658)
# n = 136  accuracy = 0.9411764705882353
# confusion matrix: tn, fp, fn, tp [ 15   3   5 113]
# Predict majority: accuracy= 0.8676470588235294
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9950884086444007, 0.978743961352657, 0.9868485143692157)
# n = 1225  accuracy = 0.9779591836734693
# confusion matrix: tn, fp, fn, tp [ 185    5   22 1013]
# Predict majority: accuracy= 0.8448979591836735
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9830508474576272, 0.9747899159663865, 0.9789029535864979)
# n = 136  accuracy = 0.9632352941176471
# confusion matrix: tn, fp, fn, tp [ 15   2   3 116]
# Predict majority: accuracy= 0.875
#
#             Acc   Maj_acc      Prec    Recall        F1
# Mean   0.927265  0.847923  0.970550  0.942812  0.956099
# StDev  0.024599  0.032048  0.017253  0.030458  0.015798

# %%
# Test k_fold dual basis word discrimination - Based on segmented IPA (segments).
# No interest in return table of k-fold trials, thus the _ return value.
for l in languages:
    _ = k_fold_language_word_discrimination_dual_basis(l, form='scas', smoothing=0.5, k_fold=10)
# Out:
# Language=English, form=scas
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8920377867746289, 0.8335435056746532, 0.8617992177314211)
# n = 1364  accuracy = 0.844574780058651
# confusion matrix: tn, fp, fn, tp [491  80 132 661]
# Predict majority: accuracy= 0.5813782991202346
#
# * TEST RESULTS *
# precision, recall, F1 = (0.65, 0.65, 0.65)
# n = 152  accuracy = 0.631578947368421
# confusion matrix: tn, fp, fn, tp [44 28 28 52]
# Predict majority: accuracy= 0.5263157894736842
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9003931847968545, 0.870722433460076, 0.8853092783505154)
# n = 1364  accuracy = 0.8695014662756598
# confusion matrix: tn, fp, fn, tp [499  76 102 687]
# Predict majority: accuracy= 0.5784457478005866
#
# * TEST RESULTS *
# precision, recall, F1 = (0.618421052631579, 0.5595238095238095, 0.5875)
# n = 152  accuracy = 0.5657894736842105
# confusion matrix: tn, fp, fn, tp [39 29 37 47]
# Predict majority: accuracy= 0.5526315789473685
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.891566265060241, 0.8451776649746193, 0.8677524429967426)
# n = 1364  accuracy = 0.8511730205278593
# confusion matrix: tn, fp, fn, tp [495  81 122 666]
# Predict majority: accuracy= 0.5777126099706745
#
# * TEST RESULTS *
# precision, recall, F1 = (0.6947368421052632, 0.7764705882352941, 0.7333333333333334)
# n = 152  accuracy = 0.6842105263157895
# confusion matrix: tn, fp, fn, tp [38 29 19 66]
# Predict majority: accuracy= 0.5592105263157895
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8831521739130435, 0.8419689119170984, 0.8620689655172414)
# n = 1364  accuracy = 0.8475073313782991
# confusion matrix: tn, fp, fn, tp [506  86 122 650]
# Predict majority: accuracy= 0.5659824046920822
#
# * TEST RESULTS *
# precision, recall, F1 = (0.7951807228915663, 0.6534653465346535, 0.7173913043478262)
# n = 152  accuracy = 0.6578947368421053
# confusion matrix: tn, fp, fn, tp [34 17 35 66]
# Predict majority: accuracy= 0.6644736842105263
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8933518005540166, 0.8301158301158301, 0.8605737158105402)
# n = 1364  accuracy = 0.8467741935483871
# confusion matrix: tn, fp, fn, tp [510  77 132 645]
# Predict majority: accuracy= 0.5696480938416423
#
# * TEST RESULTS *
# precision, recall, F1 = (0.7317073170731707, 0.625, 0.6741573033707865)
# n = 152  accuracy = 0.618421052631579
# confusion matrix: tn, fp, fn, tp [34 22 36 60]
# Predict majority: accuracy= 0.631578947368421
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8913043478260869, 0.8388746803069054, 0.8642951251646904)
# n = 1364  accuracy = 0.8489736070381232
# confusion matrix: tn, fp, fn, tp [502  80 126 656]
# Predict majority: accuracy= 0.5733137829912024
#
# * TEST RESULTS *
# precision, recall, F1 = (0.6790123456790124, 0.6043956043956044, 0.6395348837209301)
# n = 152  accuracy = 0.5921052631578947
# confusion matrix: tn, fp, fn, tp [35 26 36 55]
# Predict majority: accuracy= 0.5986842105263158
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8845637583892617, 0.8384223918575063, 0.860875244937949)
# n = 1365  accuracy = 0.843956043956044
# confusion matrix: tn, fp, fn, tp [493  86 127 659]
# Predict majority: accuracy= 0.5758241758241758
#
# * TEST RESULTS *
# precision, recall, F1 = (0.7088607594936709, 0.6436781609195402, 0.674698795180723)
# n = 151  accuracy = 0.6423841059602649
# confusion matrix: tn, fp, fn, tp [41 23 31 56]
# Predict majority: accuracy= 0.5761589403973509
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8882978723404256, 0.8423707440100883, 0.8647249190938512)
# n = 1365  accuracy = 0.8468864468864469
# confusion matrix: tn, fp, fn, tp [488  84 125 668]
# Predict majority: accuracy= 0.580952380952381
#
# * TEST RESULTS *
# precision, recall, F1 = (0.647887323943662, 0.575, 0.609271523178808)
# n = 151  accuracy = 0.609271523178808
# confusion matrix: tn, fp, fn, tp [46 25 34 46]
# Predict majority: accuracy= 0.5298013245033113
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8960863697705803, 0.8480204342273308, 0.8713910761154855)
# n = 1365  accuracy = 0.8564102564102564
# confusion matrix: tn, fp, fn, tp [505  77 119 664]
# Predict majority: accuracy= 0.5736263736263736
#
# * TEST RESULTS *
# precision, recall, F1 = (0.7228915662650602, 0.6666666666666666, 0.6936416184971098)
# n = 151  accuracy = 0.6490066225165563
# confusion matrix: tn, fp, fn, tp [38 23 30 60]
# Predict majority: accuracy= 0.5960264900662252
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8854860186418109, 0.8375314861460957, 0.86084142394822)
# n = 1365  accuracy = 0.8424908424908425
# confusion matrix: tn, fp, fn, tp [485  86 129 665]
# Predict majority: accuracy= 0.5816849816849817
#
# * TEST RESULTS *
# precision, recall, F1 = (0.6842105263157895, 0.6582278481012658, 0.6709677419354839)
# n = 151  accuracy = 0.6622516556291391
# confusion matrix: tn, fp, fn, tp [48 24 27 52]
# Predict majority: accuracy= 0.5231788079470199
#
#             Acc   Maj_acc      Prec    Recall        F1
# Mean   0.631291  0.575806  0.693291  0.641243  0.665050
# StDev  0.035559  0.047203  0.050338  0.059760  0.045257
#
# Language=Hup, form=scas
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9921700223713646, 0.9517167381974249, 0.9715224534501642)
# n = 1061  accuracy = 0.9509896324222432
# confusion matrix: tn, fp, fn, tp [122   7  45 887]
# Predict majority: accuracy= 0.8784165881244109
#
# * TEST RESULTS *
# precision, recall, F1 = (1.0, 0.9029126213592233, 0.9489795918367347)
# n = 118  accuracy = 0.9152542372881356
# confusion matrix: tn, fp, fn, tp [15  0 10 93]
# Predict majority: accuracy= 0.8728813559322034
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9888268156424581, 0.9495708154506438, 0.9688013136288999)
# n = 1061  accuracy = 0.946277097078228
# confusion matrix: tn, fp, fn, tp [119  10  47 885]
# Predict majority: accuracy= 0.8784165881244109
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9595959595959596, 0.9223300970873787, 0.9405940594059405)
# n = 118  accuracy = 0.8983050847457628
# confusion matrix: tn, fp, fn, tp [11  4  8 95]
# Predict majority: accuracy= 0.8728813559322034
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.992152466367713, 0.9516129032258065, 0.9714599341383097)
# n = 1061  accuracy = 0.9509896324222432
# confusion matrix: tn, fp, fn, tp [124   7  45 885]
# Predict majority: accuracy= 0.8765315739868049
#
# * TEST RESULTS *
# precision, recall, F1 = (0.97, 0.9238095238095239, 0.9463414634146342)
# n = 118  accuracy = 0.9067796610169492
# confusion matrix: tn, fp, fn, tp [10  3  8 97]
# Predict majority: accuracy= 0.8898305084745762
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9944008958566629, 0.9517684887459807, 0.972617743702081)
# n = 1061  accuracy = 0.9528746465598492
# confusion matrix: tn, fp, fn, tp [123   5  45 888]
# Predict majority: accuracy= 0.879359095193214
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9509803921568627, 0.9509803921568627, 0.9509803921568627)
# n = 118  accuracy = 0.9152542372881356
# confusion matrix: tn, fp, fn, tp [11  5  5 97]
# Predict majority: accuracy= 0.864406779661017
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9932356257046223, 0.9462943071965628, 0.9691969196919692)
# n = 1061  accuracy = 0.9472196041470311
# confusion matrix: tn, fp, fn, tp [124   6  50 881]
# Predict majority: accuracy= 0.8774740810556079
#
# * TEST RESULTS *
# precision, recall, F1 = (0.979381443298969, 0.9134615384615384, 0.9452736318407959)
# n = 118  accuracy = 0.9067796610169492
# confusion matrix: tn, fp, fn, tp [12  2  9 95]
# Predict majority: accuracy= 0.8813559322033898
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9910714285714286, 0.9497326203208556, 0.9699617695248498)
# n = 1061  accuracy = 0.9481621112158342
# confusion matrix: tn, fp, fn, tp [118   8  47 888]
# Predict majority: accuracy= 0.88124410933082
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9494949494949495, 0.94, 0.9447236180904524)
# n = 118  accuracy = 0.9067796610169492
# confusion matrix: tn, fp, fn, tp [13  5  6 94]
# Predict majority: accuracy= 0.847457627118644
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.995475113122172, 0.946236559139785, 0.9702315325248071)
# n = 1061  accuracy = 0.9491046182846371
# confusion matrix: tn, fp, fn, tp [127   4  50 880]
# Predict majority: accuracy= 0.8765315739868049
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9603960396039604, 0.9238095238095239, 0.941747572815534)
# n = 118  accuracy = 0.8983050847457628
# confusion matrix: tn, fp, fn, tp [ 9  4  8 97]
# Predict majority: accuracy= 0.8898305084745762
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9932659932659933, 0.9505907626208379, 0.9714599341383097)
# n = 1061  accuracy = 0.9509896324222432
# confusion matrix: tn, fp, fn, tp [124   6  46 885]
# Predict majority: accuracy= 0.8774740810556079
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9893617021276596, 0.8942307692307693, 0.9393939393939394)
# n = 118  accuracy = 0.8983050847457628
# confusion matrix: tn, fp, fn, tp [13  1 11 93]
# Predict majority: accuracy= 0.8813559322033898
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9887892376681614, 0.9504310344827587, 0.9692307692307692)
# n = 1061  accuracy = 0.9472196041470311
# confusion matrix: tn, fp, fn, tp [123  10  46 882]
# Predict majority: accuracy= 0.8746465598491989
#
# * TEST RESULTS *
# precision, recall, F1 = (0.96, 0.897196261682243, 0.927536231884058)
# n = 118  accuracy = 0.8728813559322034
# confusion matrix: tn, fp, fn, tp [ 7  4 11 96]
# Predict majority: accuracy= 0.9067796610169492
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.99, 0.954983922829582, 0.9721767594108021)
# n = 1062  accuracy = 0.9519774011299436
# confusion matrix: tn, fp, fn, tp [120   9  42 891]
# Predict majority: accuracy= 0.8785310734463276
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9484536082474226, 0.9019607843137255, 0.9246231155778893)
# n = 117  accuracy = 0.8717948717948718
# confusion matrix: tn, fp, fn, tp [10  5 10 92]
# Predict majority: accuracy= 0.8717948717948718
#
#             Acc   Maj_acc      Prec    Recall        F1
# Mean   0.899044  0.877857  0.966766  0.917069  0.941019
# StDev  0.015397  0.016121  0.017655  0.018716  0.008671
#
# Language=ImbaburaQuechua, form=scas
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9622641509433962, 0.9150717703349283, 0.938074800735745)
# n = 1187  accuracy = 0.9149115417017691
# confusion matrix: tn, fp, fn, tp [321  30  71 765]
# Predict majority: accuracy= 0.7042965459140691
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9139784946236559, 0.8854166666666666, 0.8994708994708994)
# n = 132  accuracy = 0.8560606060606061
# confusion matrix: tn, fp, fn, tp [28  8 11 85]
# Predict majority: accuracy= 0.7272727272727273
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9647798742138365, 0.9163679808841099, 0.9399509803921569)
# n = 1187  accuracy = 0.9174389216512215
# confusion matrix: tn, fp, fn, tp [322  28  70 767]
# Predict majority: accuracy= 0.7051390058972199
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9080459770114943, 0.8315789473684211, 0.8681318681318682)
# n = 132  accuracy = 0.8181818181818182
# confusion matrix: tn, fp, fn, tp [29  8 16 79]
# Predict majority: accuracy= 0.7196969696969697
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.96375, 0.9156769596199525, 0.9390986601705239)
# n = 1187  accuracy = 0.9157540016849199
# confusion matrix: tn, fp, fn, tp [316  29  71 771]
# Predict majority: accuracy= 0.7093513058129739
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8817204301075269, 0.9111111111111111, 0.8961748633879781)
# n = 132  accuracy = 0.8560606060606061
# confusion matrix: tn, fp, fn, tp [31 11  8 82]
# Predict majority: accuracy= 0.6818181818181818
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9637046307884856, 0.9166666666666666, 0.9395973154362416)
# n = 1187  accuracy = 0.9165964616680707
# confusion matrix: tn, fp, fn, tp [318  29  70 770]
# Predict majority: accuracy= 0.7076663858466723
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8941176470588236, 0.8260869565217391, 0.8587570621468926)
# n = 132  accuracy = 0.8106060606060606
# confusion matrix: tn, fp, fn, tp [31  9 16 76]
# Predict majority: accuracy= 0.696969696969697
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9619631901840491, 0.9322235434007135, 0.9468599033816425)
# n = 1187  accuracy = 0.9258635214827295
# confusion matrix: tn, fp, fn, tp [315  31  57 784]
# Predict majority: accuracy= 0.7085088458298231
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8928571428571429, 0.8241758241758241, 0.8571428571428571)
# n = 132  accuracy = 0.8106060606060606
# confusion matrix: tn, fp, fn, tp [32  9 16 75]
# Predict majority: accuracy= 0.6893939393939394
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9611041405269761, 0.9140811455847255, 0.9370030581039756)
# n = 1187  accuracy = 0.9132266217354675
# confusion matrix: tn, fp, fn, tp [318  31  72 766]
# Predict majority: accuracy= 0.7059814658803707
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9195402298850575, 0.851063829787234, 0.8839779005524862)
# n = 132  accuracy = 0.8409090909090909
# confusion matrix: tn, fp, fn, tp [31  7 14 80]
# Predict majority: accuracy= 0.7121212121212122
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9601494396014943, 0.9135071090047393, 0.9362477231329689)
# n = 1187  accuracy = 0.9115417017691659
# confusion matrix: tn, fp, fn, tp [311  32  73 771]
# Predict majority: accuracy= 0.7110362257792755
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9135802469135802, 0.8409090909090909, 0.8757396449704142)
# n = 132  accuracy = 0.8409090909090909
# confusion matrix: tn, fp, fn, tp [37  7 14 74]
# Predict majority: accuracy= 0.6666666666666666
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9646464646464646, 0.9138755980861244, 0.9385749385749385)
# n = 1187  accuracy = 0.9157540016849199
# confusion matrix: tn, fp, fn, tp [323  28  72 764]
# Predict majority: accuracy= 0.7042965459140691
#
# * TEST RESULTS *
# precision, recall, F1 = (0.967741935483871, 0.9375, 0.9523809523809523)
# n = 132  accuracy = 0.9318181818181818
# confusion matrix: tn, fp, fn, tp [33  3  6 90]
# Predict majority: accuracy= 0.7272727272727273
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9698870765370138, 0.9202380952380952, 0.9444105070250457)
# n = 1187  accuracy = 0.9233361415332771
# confusion matrix: tn, fp, fn, tp [323  24  67 773]
# Predict majority: accuracy= 0.7076663858466723
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9069767441860465, 0.8478260869565217, 0.8764044943820224)
# n = 132  accuracy = 0.8333333333333334
# confusion matrix: tn, fp, fn, tp [32  8 14 78]
# Predict majority: accuracy= 0.696969696969697
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.965865992414665, 0.9160671462829736, 0.9403076923076923)
# n = 1188  accuracy = 0.9183501683501684
# confusion matrix: tn, fp, fn, tp [327  27  70 764]
# Predict majority: accuracy= 0.702020202020202
#
# * TEST RESULTS *
# precision, recall, F1 = (0.925531914893617, 0.8877551020408163, 0.90625)
# n = 131  accuracy = 0.8625954198473282
# confusion matrix: tn, fp, fn, tp [26  7 11 87]
# Predict majority: accuracy= 0.7480916030534351
#
#             Acc   Maj_acc      Prec    Recall        F1
# Mean   0.846108  0.706627  0.912409  0.864342  0.887443
# StDev  0.035487  0.024650  0.023560  0.038987  0.028238
#
# Language=Mapudungun, form=scas
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9900552486187846, 0.9256198347107438, 0.9567538707955153)
# n = 1270  accuracy = 0.9362204724409449
# confusion matrix: tn, fp, fn, tp [293   9  72 896]
# Predict majority: accuracy= 0.7622047244094489
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9489795918367347, 0.8303571428571429, 0.8857142857142859)
# n = 142  accuracy = 0.8309859154929577
# confusion matrix: tn, fp, fn, tp [25  5 19 93]
# Predict majority: accuracy= 0.7887323943661971
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9922992299229924, 0.9308565531475749, 0.9605963791267306)
# n = 1270  accuracy = 0.9417322834645669
# confusion matrix: tn, fp, fn, tp [294   7  67 902]
# Predict majority: accuracy= 0.7629921259842519
#
# * TEST RESULTS *
# precision, recall, F1 = (0.897196261682243, 0.8648648648648649, 0.8807339449541284)
# n = 142  accuracy = 0.8169014084507042
# confusion matrix: tn, fp, fn, tp [20 11 15 96]
# Predict majority: accuracy= 0.7816901408450704
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9900442477876106, 0.9207818930041153, 0.9541577825159914)
# n = 1271  accuracy = 0.932336742722266
# confusion matrix: tn, fp, fn, tp [290   9  77 895]
# Predict majority: accuracy= 0.7647521636506688
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9326923076923077, 0.8981481481481481, 0.9150943396226415)
# n = 141  accuracy = 0.8723404255319149
# confusion matrix: tn, fp, fn, tp [26  7 11 97]
# Predict majority: accuracy= 0.7659574468085106
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.988998899889989, 0.925849639546859, 0.9563829787234043)
# n = 1271  accuracy = 0.9354838709677419
# confusion matrix: tn, fp, fn, tp [290  10  72 899]
# Predict majority: accuracy= 0.7639653815892997
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9320388349514563, 0.8807339449541285, 0.9056603773584906)
# n = 141  accuracy = 0.8581560283687943
# confusion matrix: tn, fp, fn, tp [25  7 13 96]
# Predict majority: accuracy= 0.7730496453900709
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9889867841409692, 0.9219712525667351, 0.9543039319872475)
# n = 1271  accuracy = 0.932336742722266
# confusion matrix: tn, fp, fn, tp [287  10  76 898]
# Predict majority: accuracy= 0.7663257277734068
#
# * TEST RESULTS *
# precision, recall, F1 = (0.91, 0.8584905660377359, 0.883495145631068)
# n = 141  accuracy = 0.8297872340425532
# confusion matrix: tn, fp, fn, tp [26  9 15 91]
# Predict majority: accuracy= 0.75177304964539
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.989010989010989, 0.9278350515463918, 0.9574468085106383)
# n = 1271  accuracy = 0.9370574350904799
# confusion matrix: tn, fp, fn, tp [291  10  70 900]
# Predict majority: accuracy= 0.7631785995279308
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8969072164948454, 0.7909090909090909, 0.8405797101449276)
# n = 141  accuracy = 0.7659574468085106
# confusion matrix: tn, fp, fn, tp [21 10 23 87]
# Predict majority: accuracy= 0.7801418439716312
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9867549668874173, 0.9197530864197531, 0.952076677316294)
# n = 1271  accuracy = 0.9291896144767899
# confusion matrix: tn, fp, fn, tp [287  12  78 894]
# Predict majority: accuracy= 0.7647521636506688
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9247311827956989, 0.7962962962962963, 0.8557213930348259)
# n = 141  accuracy = 0.7943262411347518
# confusion matrix: tn, fp, fn, tp [26  7 22 86]
# Predict majority: accuracy= 0.7659574468085106
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9900662251655629, 0.92, 0.9537480063795853)
# n = 1271  accuracy = 0.9315499606608969
# confusion matrix: tn, fp, fn, tp [287   9  78 897]
# Predict majority: accuracy= 0.7671125098347757
#
# * TEST RESULTS *
# precision, recall, F1 = (0.898989898989899, 0.8476190476190476, 0.8725490196078433)
# n = 141  accuracy = 0.8156028368794326
# confusion matrix: tn, fp, fn, tp [26 10 16 89]
# Predict majority: accuracy= 0.7446808510638298
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9901531728665208, 0.923469387755102, 0.955649419218585)
# n = 1271  accuracy = 0.933910306845004
# confusion matrix: tn, fp, fn, tp [282   9  75 905]
# Predict majority: accuracy= 0.7710464201416207
#
# * TEST RESULTS *
# precision, recall, F1 = (0.875, 0.77, 0.8191489361702129)
# n = 141  accuracy = 0.7588652482269503
# confusion matrix: tn, fp, fn, tp [30 11 23 77]
# Predict majority: accuracy= 0.7092198581560284
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9878721058434399, 0.9246646026831785, 0.9552238805970148)
# n = 1271  accuracy = 0.933910306845004
# confusion matrix: tn, fp, fn, tp [291  11  73 896]
# Predict majority: accuracy= 0.7623918174665618
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9509803921568627, 0.8738738738738738, 0.9107981220657277)
# n = 141  accuracy = 0.8652482269503546
# confusion matrix: tn, fp, fn, tp [25  5 14 97]
# Predict majority: accuracy= 0.7872340425531915
#
#             Acc   Maj_acc      Prec    Recall        F1
# Mean   0.820817  0.764844  0.916752  0.841129  0.876950
# StDev  0.039156  0.024338  0.025038  0.042826  0.031078
#
# Language=Qeqchi, form=scas
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9877609791216703, 0.9098143236074271, 0.9471867449085261)
# n = 1795  accuracy = 0.9147632311977716
# confusion matrix: tn, fp, fn, tp [ 270   17  136 1372]
# Predict majority: accuracy= 0.8401114206128134
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9727891156462585, 0.8033707865168539, 0.8799999999999999)
# n = 200  accuracy = 0.805
# confusion matrix: tn, fp, fn, tp [ 18   4  35 143]
# Predict majority: accuracy= 0.89
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9906609195402298, 0.9060446780551905, 0.9464653397391901)
# n = 1795  accuracy = 0.913091922005571
# confusion matrix: tn, fp, fn, tp [ 260   13  143 1379]
# Predict majority: accuracy= 0.8479108635097493
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9161290322580645, 0.8658536585365854, 0.890282131661442)
# n = 200  accuracy = 0.825
# confusion matrix: tn, fp, fn, tp [ 23  13  22 142]
# Predict majority: accuracy= 0.82
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.990667623833453, 0.9108910891089109, 0.9491059147180193)
# n = 1795  accuracy = 0.9175487465181058
# confusion matrix: tn, fp, fn, tp [ 267   13  135 1380]
# Predict majority: accuracy= 0.8440111420612814
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9503105590062112, 0.8947368421052632, 0.9216867469879517)
# n = 200  accuracy = 0.87
# confusion matrix: tn, fp, fn, tp [ 21   8  18 153]
# Predict majority: accuracy= 0.855
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9914407988587732, 0.9162821357943309, 0.9523809523809523)
# n = 1795  accuracy = 0.9225626740947075
# confusion matrix: tn, fp, fn, tp [ 266   12  127 1390]
# Predict majority: accuracy= 0.8451253481894151
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9395973154362416, 0.8284023668639053, 0.8805031446540881)
# n = 200  accuracy = 0.81
# confusion matrix: tn, fp, fn, tp [ 22   9  29 140]
# Predict majority: accuracy= 0.845
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9858657243816255, 0.9214002642007926, 0.9525435302150905)
# n = 1795  accuracy = 0.9225626740947075
# confusion matrix: tn, fp, fn, tp [ 261   20  119 1395]
# Predict majority: accuracy= 0.8434540389972145
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9403973509933775, 0.8255813953488372, 0.8792569659442725)
# n = 200  accuracy = 0.805
# confusion matrix: tn, fp, fn, tp [ 19   9  30 142]
# Predict majority: accuracy= 0.86
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9879089615931721, 0.9132149901380671, 0.9490946361462247)
# n = 1796  accuracy = 0.9170378619153675
# confusion matrix: tn, fp, fn, tp [ 258   17  132 1389]
# Predict majority: accuracy= 0.8468819599109132
#
# * TEST RESULTS *
# precision, recall, F1 = (0.910828025477707, 0.8666666666666667, 0.8881987577639752)
# n = 199  accuracy = 0.8190954773869347
# confusion matrix: tn, fp, fn, tp [ 20  14  22 143]
# Predict majority: accuracy= 0.8291457286432161
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9900426742532006, 0.9092096668843893, 0.947906026557712)
# n = 1796  accuracy = 0.9148106904231625
# confusion matrix: tn, fp, fn, tp [ 251   14  139 1392]
# Predict majority: accuracy= 0.8524498886414253
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8881118881118881, 0.8193548387096774, 0.8523489932885905)
# n = 199  accuracy = 0.7788944723618091
# confusion matrix: tn, fp, fn, tp [ 28  16  28 127]
# Predict majority: accuracy= 0.7788944723618091
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9912472647702407, 0.8988095238095238, 0.9427679500520292)
# n = 1796  accuracy = 0.9081291759465479
# confusion matrix: tn, fp, fn, tp [ 272   12  153 1359]
# Predict majority: accuracy= 0.8418708240534521
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9463087248322147, 0.8103448275862069, 0.873065015479876)
# n = 199  accuracy = 0.7939698492462312
# confusion matrix: tn, fp, fn, tp [ 17   8  33 141]
# Predict majority: accuracy= 0.8743718592964824
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9906340057636888, 0.9063941990771259, 0.9466437177280551)
# n = 1796  accuracy = 0.9136971046770601
# confusion matrix: tn, fp, fn, tp [ 266   13  142 1375]
# Predict majority: accuracy= 0.8446547884187082
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9235668789808917, 0.8579881656804734, 0.8895705521472392)
# n = 199  accuracy = 0.8190954773869347
# confusion matrix: tn, fp, fn, tp [ 18  12  24 145]
# Predict majority: accuracy= 0.8492462311557789
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9885632594710507, 0.9116677653263019, 0.948559670781893)
# n = 1796  accuracy = 0.9164810690423163
# confusion matrix: tn, fp, fn, tp [ 263   16  134 1383]
# Predict majority: accuracy= 0.8446547884187082
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9655172413793104, 0.8284023668639053, 0.8917197452229301)
# n = 199  accuracy = 0.8291457286432161
# confusion matrix: tn, fp, fn, tp [ 25   5  29 140]
# Predict majority: accuracy= 0.8492462311557789
#
#             Acc   Maj_acc      Prec    Recall        F1
# Mean   0.815520  0.845090  0.935356  0.840070  0.884663
# StDev  0.024328  0.030723  0.025906  0.029483  0.017435
#
# Language=Wichi, form=scas
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9920477137176938, 0.9633204633204633, 0.9774730656219393)
# n = 1224  accuracy = 0.9624183006535948
# confusion matrix: tn, fp, fn, tp [180   8  38 998]
# Predict majority: accuracy= 0.8464052287581699
#
# * TEST RESULTS *
# precision, recall, F1 = (0.954954954954955, 0.8983050847457628, 0.925764192139738)
# n = 137  accuracy = 0.8759124087591241
# confusion matrix: tn, fp, fn, tp [ 14   5  12 106]
# Predict majority: accuracy= 0.8613138686131386
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9939577039274925, 0.9508670520231214, 0.9719350073855244)
# n = 1225  accuracy = 0.953469387755102
# confusion matrix: tn, fp, fn, tp [181   6  51 987]
# Predict majority: accuracy= 0.8473469387755102
#
# * TEST RESULTS *
# precision, recall, F1 = (0.972972972972973, 0.9310344827586207, 0.9515418502202643)
# n = 136  accuracy = 0.9191176470588235
# confusion matrix: tn, fp, fn, tp [ 17   3   8 108]
# Predict majority: accuracy= 0.8529411764705882
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9929859719438878, 0.9565637065637066, 0.9744346116027534)
# n = 1225  accuracy = 0.9575510204081633
# confusion matrix: tn, fp, fn, tp [182   7  45 991]
# Predict majority: accuracy= 0.8457142857142858
#
# * TEST RESULTS *
# precision, recall, F1 = (0.972972972972973, 0.9152542372881356, 0.9432314410480349)
# n = 136  accuracy = 0.9044117647058824
# confusion matrix: tn, fp, fn, tp [ 15   3  10 108]
# Predict majority: accuracy= 0.8676470588235294
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.993, 0.9575699132111861, 0.9749631811487482)
# n = 1225  accuracy = 0.9583673469387755
# confusion matrix: tn, fp, fn, tp [181   7  44 993]
# Predict majority: accuracy= 0.846530612244898
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9739130434782609, 0.9572649572649573, 0.9655172413793104)
# n = 136  accuracy = 0.9411764705882353
# confusion matrix: tn, fp, fn, tp [ 16   3   5 112]
# Predict majority: accuracy= 0.8602941176470589
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9930693069306931, 0.9625719769673704, 0.9775828460038987)
# n = 1225  accuracy = 0.9624489795918367
# confusion matrix: tn, fp, fn, tp [ 176    7   39 1003]
# Predict majority: accuracy= 0.8506122448979592
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9722222222222222, 0.9375, 0.9545454545454546)
# n = 136  accuracy = 0.9264705882352942
# confusion matrix: tn, fp, fn, tp [ 21   3   7 105]
# Predict majority: accuracy= 0.8235294117647058
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9940119760479041, 0.9595375722543352, 0.9764705882352941)
# n = 1225  accuracy = 0.9608163265306122
# confusion matrix: tn, fp, fn, tp [181   6  42 996]
# Predict majority: accuracy= 0.8473469387755102
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9541284403669725, 0.896551724137931, 0.9244444444444444)
# n = 136  accuracy = 0.875
# confusion matrix: tn, fp, fn, tp [ 15   5  12 104]
# Predict majority: accuracy= 0.8529411764705882
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9950396825396826, 0.960727969348659, 0.9775828460038987)
# n = 1225  accuracy = 0.9624489795918367
# confusion matrix: tn, fp, fn, tp [ 176    5   41 1003]
# Predict majority: accuracy= 0.8522448979591837
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9528301886792453, 0.9181818181818182, 0.9351851851851851)
# n = 136  accuracy = 0.8970588235294118
# confusion matrix: tn, fp, fn, tp [ 21   5   9 101]
# Predict majority: accuracy= 0.8088235294117647
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9920792079207921, 0.9653179190751445, 0.9785156249999999)
# n = 1225  accuracy = 0.9640816326530612
# confusion matrix: tn, fp, fn, tp [ 179    8   36 1002]
# Predict majority: accuracy= 0.8473469387755102
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9619047619047619, 0.8706896551724138, 0.9140271493212669)
# n = 136  accuracy = 0.8602941176470589
# confusion matrix: tn, fp, fn, tp [ 16   4  15 101]
# Predict majority: accuracy= 0.8529411764705882
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9930139720558883, 0.9594985535197685, 0.9759686120647376)
# n = 1225  accuracy = 0.96
# confusion matrix: tn, fp, fn, tp [181   7  42 995]
# Predict majority: accuracy= 0.846530612244898
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9658119658119658, 0.9658119658119658, 0.9658119658119658)
# n = 136  accuracy = 0.9411764705882353
# confusion matrix: tn, fp, fn, tp [ 15   4   4 113]
# Predict majority: accuracy= 0.8602941176470589
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.993, 0.9548076923076924, 0.9735294117647059)
# n = 1225  accuracy = 0.9559183673469388
# confusion matrix: tn, fp, fn, tp [178   7  47 993]
# Predict majority: accuracy= 0.8489795918367347
#
# * TEST RESULTS *
# precision, recall, F1 = (0.9619047619047619, 0.8859649122807017, 0.9223744292237442)
# n = 136  accuracy = 0.875
# confusion matrix: tn, fp, fn, tp [ 18   4  13 101]
# Predict majority: accuracy= 0.8382352941176471
#
#             Acc   Maj_acc      Prec    Recall        F1
# Mean   0.901562  0.847896  0.964362  0.917656  0.940244
# StDev  0.029567  0.018761  0.008444  0.030726  0.018634

# %% [markdown]
# # Overfitting of Markov model
# ## k-fold report of entropy mean and standard deviation
# - Table as argument -- allows selection of subset of language table
# - k-fold determines fit and validation fractions
# - Option to specify subset selector for validation study
#     - Can look at only native words with this option.
# - No need for randomization tests of differences
#     - Sufficient evidence in statistical description

# %%
# Test k_fold - train versus val entropy studies - Based on formchars.
# Select native subset of table for native only study - increase k_fold to allow larger train set.
for l in languages:
    k_fold_entropy_for_language(l, k_fold=5, smoothing=[0.5])
    k_fold_entropy_for_language(l, k_fold=10, smoothing=0.5, selector=lambda tbl: tbl.borrowedscore<0.375)
# Out:
# 5-fold entropy for English.
# Sample=1516, k-fold=5, val=304, model=KNI, order=3, smoothing=0.5.
# Statistic: Train mean Train stdev    Val mean  Val stdev
# Mean            2.838       0.411       3.372      0.757
# StdDev         0.0037      0.0064      0.0381     0.0348
# StdErr        0.00185     0.00319     0.01903    0.01741
#
# 10-fold entropy for English.
# Subset selected: See sample and val sizes.
# Sample=873, k-fold=10, val=88, model=KNI, order=3, smoothing=0.5.
# Statistic: Train mean Train stdev    Val mean  Val stdev
# Mean            2.631       0.422       3.272      0.826
# StdDev         0.0062      0.0052      0.0889     0.0762
# StdErr        0.00206     0.00174     0.02963    0.02540
#
# 5-fold entropy for Hup.
# Sample=1179, k-fold=5, val=236, model=KNI, order=3, smoothing=0.5.
# Statistic: Train mean Train stdev    Val mean  Val stdev
# Mean            2.496       0.468       3.451      1.122
# StdDev         0.0114      0.0056      0.0806     0.0409
# StdErr        0.00569     0.00280     0.04030    0.02046
#
# 10-fold entropy for Hup.
# Subset selected: See sample and val sizes.
# Sample=1035, k-fold=10, val=104, model=KNI, order=3, smoothing=0.5.
# Statistic: Train mean Train stdev    Val mean  Val stdev
# Mean            2.431       0.459       3.294      1.093
# StdDev         0.0037      0.0033      0.0850     0.0939
# StdErr        0.00124     0.00109     0.02833    0.03129
#
# 5-fold entropy for ImbaburaQuechua.
# Sample=1319, k-fold=5, val=264, model=KNI, order=3, smoothing=0.5.
# Statistic: Train mean Train stdev    Val mean  Val stdev
# Mean            2.504       0.502       2.862      0.846
# StdDev         0.0078      0.0050      0.0593     0.0702
# StdErr        0.00388     0.00250     0.02963    0.03511
#
# 10-fold entropy for ImbaburaQuechua.
# Subset selected: See sample and val sizes.
# Sample=932, k-fold=10, val=94, model=KNI, order=3, smoothing=0.5.
# Statistic: Train mean Train stdev    Val mean  Val stdev
# Mean            2.300       0.462       2.571      0.677
# StdDev         0.0039      0.0023      0.0679     0.0804
# StdErr        0.00129     0.00075     0.02263    0.02681
#
# 5-fold entropy for Mapudungun.
# Sample=1412, k-fold=5, val=283, model=KNI, order=3, smoothing=0.5.
# Statistic: Train mean Train stdev    Val mean  Val stdev
# Mean            2.723       0.452       3.193      0.817
# StdDev         0.0064      0.0068      0.0344     0.0225
# StdErr        0.00318     0.00339     0.01718    0.01126
#
# 10-fold entropy for Mapudungun.
# Subset selected: See sample and val sizes.
# Sample=1080, k-fold=10, val=108, model=KNI, order=3, smoothing=0.5.
# Statistic: Train mean Train stdev    Val mean  Val stdev
# Mean            2.603       0.454       3.033      0.773
# StdDev         0.0038      0.0042      0.0623     0.1012
# StdErr        0.00126     0.00141     0.02077    0.03375
#
# 5-fold entropy for Qeqchi.
# Sample=1995, k-fold=5, val=399, model=KNI, order=3, smoothing=0.5.
# Statistic: Train mean Train stdev    Val mean  Val stdev
# Mean            2.837       0.469       3.263      0.807
# StdDev         0.0029      0.0065      0.0282     0.0386
# StdErr        0.00147     0.00325     0.01410    0.01931
#
# 10-fold entropy for Qeqchi.
# Subset selected: See sample and val sizes.
# Sample=1686, k-fold=10, val=169, model=KNI, order=3, smoothing=0.5.
# Statistic: Train mean Train stdev    Val mean  Val stdev
# Mean            2.768       0.466       3.143      0.739
# StdDev         0.0015      0.0035      0.0202     0.0490
# StdErr        0.00051     0.00117     0.00674    0.01634
#
# 5-fold entropy for Wichi.
# Sample=1361, k-fold=5, val=273, model=KNI, order=3, smoothing=0.5.
# Statistic: Train mean Train stdev    Val mean  Val stdev
# Mean            2.673       0.455       3.015      0.751
# StdDev         0.0052      0.0039      0.0380     0.0597
# StdErr        0.00259     0.00195     0.01900    0.02984
#
# 10-fold entropy for Wichi.
# Subset selected: See sample and val sizes.
# Sample=1154, k-fold=10, val=116, model=KNI, order=3, smoothing=0.5.
# Statistic: Train mean Train stdev    Val mean  Val stdev
# Mean            2.566       0.429       2.859      0.667
# StdDev         0.0042      0.0039      0.0670     0.0956
# StdErr        0.00138     0.00131     0.02234    0.03188

# %%
# Test k_fold - train versus val entropy studies - Based on segments.
# Select native subset of table for native only study - increase k_fold to allow larger train set.
for l in languages:
    k_fold_entropy_for_language(l, k_fold=5, form='segments', smoothing=[0.5])
    k_fold_entropy_for_language(l, k_fold=10, form='segments', smoothing=0.5, selector=lambda tbl: tbl.borrowedscore<0.375)
# Out:
# 5-fold entropy for English.
# Sample=1516, k-fold=5, val=304, model=KNI, order=3, smoothing=0.5.
# Statistic: Train mean Train stdev    Val mean  Val stdev
# Mean            2.863       0.423       3.878      0.948
# StdDev         0.0029      0.0069      0.0466     0.0592
# StdErr        0.00144     0.00346     0.02328    0.02958
#
# 10-fold entropy for English.
# Subset selected: See sample and val sizes.
# Sample=873, k-fold=10, val=88, model=KNI, order=3, smoothing=0.5.
# Statistic: Train mean Train stdev    Val mean  Val stdev
# Mean            2.673       0.423       3.828      0.978
# StdDev         0.0098      0.0048      0.1312     0.0841
# StdErr        0.00325     0.00161     0.04372    0.02804
#
# 5-fold entropy for Hup.
# Sample=1179, k-fold=5, val=236, model=KNI, order=3, smoothing=0.5.
# Statistic: Train mean Train stdev    Val mean  Val stdev
# Mean            2.503       0.466       3.312      1.080
# StdDev         0.0096      0.0073      0.0953     0.1285
# StdErr        0.00482     0.00367     0.04765    0.06423
#
# 10-fold entropy for Hup.
# Subset selected: See sample and val sizes.
# Sample=1035, k-fold=10, val=104, model=KNI, order=3, smoothing=0.5.
# Statistic: Train mean Train stdev    Val mean  Val stdev
# Mean            2.427       0.454       3.200      1.070
# StdDev         0.0052      0.0023      0.1208     0.1072
# StdErr        0.00175     0.00076     0.04026    0.03575
#
# 5-fold entropy for ImbaburaQuechua.
# Sample=1319, k-fold=5, val=264, model=KNI, order=3, smoothing=0.5.
# Statistic: Train mean Train stdev    Val mean  Val stdev
# Mean            2.560       0.496       2.998      0.867
# StdDev         0.0073      0.0023      0.0361     0.0433
# StdErr        0.00366     0.00114     0.01805    0.02166
#
# 10-fold entropy for ImbaburaQuechua.
# Subset selected: See sample and val sizes.
# Sample=932, k-fold=10, val=94, model=KNI, order=3, smoothing=0.5.
# Statistic: Train mean Train stdev    Val mean  Val stdev
# Mean            2.365       0.472       2.716      0.749
# StdDev         0.0075      0.0024      0.0917     0.0707
# StdErr        0.00250     0.00081     0.03056    0.02356
#
# 5-fold entropy for Mapudungun.
# Sample=1412, k-fold=5, val=283, model=KNI, order=3, smoothing=0.5.
# Statistic: Train mean Train stdev    Val mean  Val stdev
# Mean            2.787       0.470       3.401      0.905
# StdDev         0.0051      0.0102      0.0182     0.0514
# StdErr        0.00254     0.00510     0.00908    0.02570
#
# 10-fold entropy for Mapudungun.
# Subset selected: See sample and val sizes.
# Sample=1080, k-fold=10, val=108, model=KNI, order=3, smoothing=0.5.
# Statistic: Train mean Train stdev    Val mean  Val stdev
# Mean            2.668       0.485       3.241      0.872
# StdDev         0.0077      0.0062      0.0964     0.0636
# StdErr        0.00257     0.00206     0.03215    0.02119
#
# 5-fold entropy for Qeqchi.
# Sample=1995, k-fold=5, val=399, model=KNI, order=3, smoothing=0.5.
# Statistic: Train mean Train stdev    Val mean  Val stdev
# Mean            2.827       0.493       3.534      1.006
# StdDev         0.0068      0.0077      0.0437     0.0818
# StdErr        0.00340     0.00386     0.02184    0.04091
#
# 10-fold entropy for Qeqchi.
# Subset selected: See sample and val sizes.
# Sample=1686, k-fold=10, val=169, model=KNI, order=3, smoothing=0.5.
# Statistic: Train mean Train stdev    Val mean  Val stdev
# Mean            2.760       0.496       3.397      0.936
# StdDev         0.0025      0.0018      0.0502     0.0581
# StdErr        0.00084     0.00060     0.01672    0.01935
#
# 5-fold entropy for Wichi.
# Sample=1361, k-fold=5, val=273, model=KNI, order=3, smoothing=0.5.
# Statistic: Train mean Train stdev    Val mean  Val stdev
# Mean            2.704       0.469       3.237      0.866
# StdDev         0.0122      0.0036      0.0819     0.0476
# StdErr        0.00609     0.00179     0.04095    0.02381
#
# 10-fold entropy for Wichi.
# Subset selected: See sample and val sizes.
# Sample=1154, k-fold=10, val=116, model=KNI, order=3, smoothing=0.5.
# Statistic: Train mean Train stdev    Val mean  Val stdev
# Mean            2.599       0.455       3.084      0.793
# StdDev         0.0053      0.0034      0.0815     0.0858
# StdErr        0.00177     0.00114     0.02717    0.02861

# %%
# Test k_fold - train versus val entropy studies - Based on segments.
# Select native subset of table for native only study - increase k_fold to allow larger train set.
for l in languages:
    k_fold_entropy_for_language(l, k_fold=5, form='scas', smoothing=[0.5])
    k_fold_entropy_for_language(l, k_fold=10, form='scas', smoothing=0.5, selector=lambda tbl: tbl.borrowedscore<0.375)
# Out:
# Language=English, form=scas - 5-fold entropy
# Sample=1516, k-fold=5, val=304, model=KNI, order=3, smoothing=0.5.
# Statistic: Train mean Train stdev    Val mean  Val stdev
# Mean            2.651       0.429       3.007      0.728
# StdDev         0.0070      0.0077      0.0425     0.0493
# StdErr        0.00348     0.00384     0.02125    0.02467
#
# Language=English, form=scas - 10-fold entropy
# Subset selected: See sample and val sizes.
# Sample=873, k-fold=10, val=88, model=KNI, order=3, smoothing=0.5.
# Statistic: Train mean Train stdev    Val mean  Val stdev
# Mean            2.538       0.422       2.992      0.758
# StdDev         0.0034      0.0039      0.0585     0.0676
# StdErr        0.00113     0.00129     0.01951    0.02254
#
# Language=Hup, form=scas - 5-fold entropy
# Sample=1179, k-fold=5, val=236, model=KNI, order=3, smoothing=0.5.
# Statistic: Train mean Train stdev    Val mean  Val stdev
# Mean            2.355       0.429       2.637      0.706
# StdDev         0.0102      0.0096      0.0573     0.0399
# StdErr        0.00512     0.00479     0.02867    0.01996
#
# Language=Hup, form=scas - 10-fold entropy
# Subset selected: See sample and val sizes.
# Sample=1035, k-fold=10, val=104, model=KNI, order=3, smoothing=0.5.
# Statistic: Train mean Train stdev    Val mean  Val stdev
# Mean            2.277       0.412       2.532      0.640
# StdDev         0.0029      0.0041      0.0446     0.0484
# StdErr        0.00097     0.00138     0.01488    0.01614
#
# Language=ImbaburaQuechua, form=scas - 5-fold entropy
# Sample=1319, k-fold=5, val=264, model=KNI, order=3, smoothing=0.5.
# Statistic: Train mean Train stdev    Val mean  Val stdev
# Mean            2.488       0.465       2.727      0.741
# StdDev         0.0062      0.0072      0.0451     0.0716
# StdErr        0.00312     0.00360     0.02253    0.03582
#
# Language=ImbaburaQuechua, form=scas - 10-fold entropy
# Subset selected: See sample and val sizes.
# Sample=932, k-fold=10, val=94, model=KNI, order=3, smoothing=0.5.
# Statistic: Train mean Train stdev    Val mean  Val stdev
# Mean            2.343       0.449       2.552      0.635
# StdDev         0.0027      0.0040      0.0291     0.0586
# StdErr        0.00091     0.00134     0.00970    0.01952
#
# Language=Mapudungun, form=scas - 5-fold entropy
# Sample=1412, k-fold=5, val=283, model=KNI, order=3, smoothing=0.5.
# Statistic: Train mean Train stdev    Val mean  Val stdev
# Mean            2.709       0.455       3.081      0.772
# StdDev         0.0060      0.0067      0.0522     0.0517
# StdErr        0.00300     0.00337     0.02611    0.02583
#
# Language=Mapudungun, form=scas - 10-fold entropy
# Subset selected: See sample and val sizes.
# Sample=1080, k-fold=10, val=108, model=KNI, order=3, smoothing=0.5.
# Statistic: Train mean Train stdev    Val mean  Val stdev
# Mean            2.590       0.461       2.925      0.727
# StdDev         0.0038      0.0053      0.0526     0.0864
# StdErr        0.00125     0.00176     0.01752    0.02879
#
# Language=Qeqchi, form=scas - 5-fold entropy
# Sample=1995, k-fold=5, val=399, model=KNI, order=3, smoothing=0.5.
# Statistic: Train mean Train stdev    Val mean  Val stdev
# Mean            2.747       0.475       3.039      0.718
# StdDev         0.0039      0.0053      0.0322     0.0404
# StdErr        0.00195     0.00267     0.01608    0.02020
#
# Language=Qeqchi, form=scas - 10-fold entropy
# Subset selected: See sample and val sizes.
# Sample=1686, k-fold=10, val=169, model=KNI, order=3, smoothing=0.5.
# Statistic: Train mean Train stdev    Val mean  Val stdev
# Mean            2.686       0.465       2.947      0.669
# StdDev         0.0054      0.0029      0.0753     0.0672
# StdErr        0.00181     0.00097     0.02511    0.02239
#
# Language=Wichi, form=scas - 5-fold entropy
# Sample=1361, k-fold=5, val=273, model=KNI, order=3, smoothing=0.5.
# Statistic: Train mean Train stdev    Val mean  Val stdev
# Mean            2.735       0.442       3.091      0.730
# StdDev         0.0074      0.0073      0.0365     0.0346
# StdErr        0.00371     0.00366     0.01823    0.01732
#
# Language=Wichi, form=scas - 10-fold entropy
# Subset selected: See sample and val sizes.
# Sample=1154, k-fold=10, val=116, model=KNI, order=3, smoothing=0.5.
# Statistic: Train mean Train stdev    Val mean  Val stdev
# Mean            2.643       0.432       2.954      0.660
# StdDev         0.0058      0.0033      0.0761     0.0724
# StdErr        0.00194     0.00111     0.02537    0.02414
