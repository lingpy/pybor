# %% [markdown]
# # Loanword analysis using Markov language model
# ### with Kneser Ney smoothing
# ### Files from WOLD  - forms, segmented forms, indicator of loan words
# ## Requires NLTK3.5

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))

# Do this once in the kernel.
import sys
sys.path.append('code')

# Set to automatically reload.
# %load_ext autoreload
# %autoreload 2
# Out:
# <style>.container { width:80% !important; }</style>
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# List of study languages:
languages = ['English', 'Hup', 'ImbaburaQuechua', 'Mapudungun', 'Qeqchi', 'Wichi']
# English for development and the Latin American languages for strong regioinal interest.

# %%
# Compile code for MarkovCharLM...
import py_compile
py_compile.compile('code/utility_functions.py')
py_compile.compile('code/markov_char_lm.py')
py_compile.compile('code/markov_model_analysis.py')
# Out:
# 'code/__pycache__/markov_model_analysis.cpython-38.pyc'

# %%
from utility_functions import *
from markov_char_lm import MarkovCharLM
from markov_model_analysis import analyze_language_word_distributions
from markov_model_analysis import analyze_language_word_distributions_native_basis
from markov_model_analysis import language_word_discrimination_dual_basis
from markov_model_analysis import language_word_discrimination_native_basis
from markov_model_analysis import language_word_discrimination_dual_basis
from markov_model_analysis import language_word_discrimination_native_basis
from markov_model_analysis import k_fold_language_word_discrimination_native_basis
from markov_model_analysis import k_fold_language_word_discrimination_dual_basis
from markov_model_analysis import k_fold_entropy_for_language

# %% [markdown]
# # Randomization test for distribution differences
# ## Markov model entropies calculated from undifferentiated (entire) word table
# 1. Fit Markov model to undifferentiated sample or entire table.
# 2. Examine distributiona of native and loan words.
# 3. Randomization test for native versus loan word distributional differences.
#     1. Calculate decision statistic for 'true' vector of native versus loan.
#     2. Perform n randomizations of vector which arbitrarily designates native versus loan.
#         1. calculate statistic for each randomization.
#     3. Determine empirical probability distribution of statistic and probability of original decision statistic.

# %%
# Test
analyze_language_word_distributions('English', form='formchars', test='ks', n=100)
analyze_language_word_distributions('English', form='segments', test='ks', n=100)
analyze_language_word_distributions('English', form='scas', test='ks', n=100)

# Testing on both original forms, segmented by character, and curated segmentation with IPA symbols.
# Only used 100 replicates in randomization for testing. Practical would be 5000.
# Out:
# Language=English, form=formchars
# prob (ks stat >= 0.16808) = 0.00495
# Language=English, form=segments
# prob (ks stat >= 0.04214) = 0.55941
# Language=English, form=scas
# prob (ks stat >= 0.05185) = 0.18317

# %% [markdown]
# # Randomization tests for distribution differences
# ## Constructs native and loan Markov models for each randomization
# - Repeated estimation of model and with random selector - very compute intensive
#     - Correct approach in that it incoporates the learning bias.
#     - Reduced repetitions to 1000 due to compute time.

# %%
#Test
analyze_language_word_distributions_native_basis('English', test='ks', n=100)
analyze_language_word_distributions_native_basis('English', form='segments', test='ks', n=100)
analyze_language_word_distributions_native_basis('English', form='scas', test='ks', n=100)

# Testing on both original forms, segmented by character, and curated segmentation with IPA symbols.
# Only used 100 replicates in randomization for testing. Practical would be 1000, and still costly in time.
# Out:
# Language=English, form=formchars
# prob (stat >= 0.6870465084378602 ) = 0.004950495049504955
# Language=English, form=segments
# prob (stat >= 0.7809184824143699 ) = 0.004950495049504955
# Language=English, form=scas
# prob (stat >= 0.4050778584776757 ) = 0.004950495049504955

# %% [markdown]
# # Word discrimination - based on native versus loan entropy models

# %%
#Test
language_word_discrimination_dual_basis("English", smoothing=0.5)
language_word_discrimination_dual_basis("English", form='segments', smoothing=0.5)
language_word_discrimination_dual_basis("English", form='scas', smoothing=0.5)
# Out:
# Language=English, form=formchars
# num train= 1213, num test=  303
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9479606188466948, 0.9533239038189534, 0.9506346967559944)
# n = 1213  accuracy = 0.9422918384171476
# confusion matrix: tn, fp, fn, tp [469  37  33 674]
# Predict majority: accuracy= 0.5828524319868096
#
# * TEST RESULTS *
# precision, recall, F1 = (0.75, 0.7409638554216867, 0.7454545454545456)
# n = 303  accuracy = 0.7227722772277227
# confusion matrix: tn, fp, fn, tp [ 96  41  43 123]
# Predict majority: accuracy= 0.5478547854785478
#
# Language=English, form=segments
# num train= 1213, num test=  303
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9757834757834758, 0.9757834757834758, 0.9757834757834758)
# n = 1213  accuracy = 0.9719703215169002
# confusion matrix: tn, fp, fn, tp [494  17  17 685]
# Predict majority: accuracy= 0.5787304204451772
#
# * TEST RESULTS *
# precision, recall, F1 = (0.7111111111111111, 0.7485380116959064, 0.7293447293447293)
# n = 303  accuracy = 0.6864686468646864
# confusion matrix: tn, fp, fn, tp [ 80  52  43 128]
# Predict majority: accuracy= 0.5643564356435643
#
# Language=English, form=scas
# num train= 1213, num test=  303
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8953662182361734, 0.8618705035971223, 0.8782991202346041)
# n = 1213  accuracy = 0.8631492168178071
# confusion matrix: tn, fp, fn, tp [448  70  96 599]
# Predict majority: accuracy= 0.572959604286892
#
# * TEST RESULTS *
# precision, recall, F1 = (0.6987179487179487, 0.6123595505617978, 0.6526946107784432)
# n = 303  accuracy = 0.6171617161716172
# confusion matrix: tn, fp, fn, tp [ 78  47  69 109]
# Predict majority: accuracy= 0.5874587458745875

# %% [markdown]
# # Word discrimination - based on just native known
# - smoothing=0.5
# - z=0.995

# %%
#Test
language_word_discrimination_native_basis('English', smoothing=0.5, p=.995)
language_word_discrimination_native_basis('English', form='segments', smoothing=0.5, p=.995)
language_word_discrimination_native_basis('English', form='scas', smoothing=0.5, p=.995)
# Out:
# Language=English, form=formchars
# num train= 1213, num test=  303
# Native avg=2.618, stdev=0.412
# fraction 0.995, idx 695.50, ref limit=4.090
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.7204968944099379, 0.9942857142857143, 0.8355342136854743)
# n = 1213  accuracy = 0.7741137675185491
# confusion matrix: tn, fp, fn, tp [243 270   4 696]
# Predict majority: accuracy= 0.5770816158285244
#
# * TEST RESULTS *
# precision, recall, F1 = (0.665158371040724, 0.8497109826589595, 0.7461928934010152)
# n = 303  accuracy = 0.66996699669967
# confusion matrix: tn, fp, fn, tp [ 56  74  26 147]
# Predict majority: accuracy= 0.570957095709571
#
# Language=English, form=segments
# num train= 1213, num test=  303
# Native avg=2.646, stdev=0.409
# fraction 0.995, idx 700.48, ref limit=3.883
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8122827346465817, 0.9943262411347518, 0.8941326530612245)
# n = 1213  accuracy = 0.8631492168178071
# confusion matrix: tn, fp, fn, tp [346 162   4 701]
# Predict majority: accuracy= 0.5812036273701566
#
# * TEST RESULTS *
# precision, recall, F1 = (0.7443609022556391, 0.5892857142857143, 0.6578073089700996)
# n = 303  accuracy = 0.6600660066006601
# confusion matrix: tn, fp, fn, tp [101  34  69  99]
# Predict majority: accuracy= 0.5544554455445545
#
# Language=English, form=scas
# num train= 1213, num test=  303
# Native avg=2.519, stdev=0.400
# fraction 0.995, idx 708.44, ref limit=3.697
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.6607642124883504, 0.9943899018232819, 0.7939529675251961)
# n = 1213  accuracy = 0.6966199505358615
# confusion matrix: tn, fp, fn, tp [136 364   4 709]
# Predict majority: accuracy= 0.5877988458367683
#
# * TEST RESULTS *
# precision, recall, F1 = (0.5594713656387665, 0.79375, 0.6563307493540053)
# n = 303  accuracy = 0.5610561056105611
# confusion matrix: tn, fp, fn, tp [ 43 100  33 127]
# Predict majority: accuracy= 0.528052805280528

# %%
# Test k-fold native basis word discrimination. 
# No interest in return table of k-fold trials.
_ = k_fold_language_word_discrimination_native_basis('English', form='formchars', smoothing=0.5, k_fold=10, p=.995)
_ = k_fold_language_word_discrimination_native_basis('English', form='segments', smoothing=0.5, k_fold=10, p=.995)
_ = k_fold_language_word_discrimination_native_basis('English', form='scas', smoothing=0.5, k_fold=10, p=.995)
# Out:
# Language=English, form=formchars
# Native avg=2.622, stdev=0.423
# fraction 0.995, idx 784.06, ref limit=4.098
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.7136363636363636, 0.9949302915082383, 0.8311275807305453)
# n = 1364  accuracy = 0.7661290322580645
# confusion matrix: tn, fp, fn, tp [260 315   4 785]
# Predict majority: accuracy= 0.5784457478005866
#
# * TEST RESULTS *
# precision, recall, F1 = (0.6697247706422018, 0.8690476190476191, 0.7564766839378239)
# n = 152  accuracy = 0.6907894736842105
# confusion matrix: tn, fp, fn, tp [32 36 11 73]
# Predict majority: accuracy= 0.5526315789473685
# Native avg=2.637, stdev=0.426
# fraction 0.995, idx 771.12, ref limit=4.094
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.6954954954954955, 0.9948453608247423, 0.8186638388123012)
# n = 1364  accuracy = 0.749266862170088
# confusion matrix: tn, fp, fn, tp [250 338   4 772]
# Predict majority: accuracy= 0.5689149560117303
#
# * TEST RESULTS *
# precision, recall, F1 = (0.7413793103448276, 0.8865979381443299, 0.8075117370892019)
# n = 152  accuracy = 0.7302631578947368
# confusion matrix: tn, fp, fn, tp [25 30 11 86]
# Predict majority: accuracy= 0.6381578947368421
# Native avg=2.627, stdev=0.435
# fraction 0.995, idx 786.05, ref limit=4.169
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.6983141082519965, 0.9949431099873578, 0.8206465067778936)
# n = 1364  accuracy = 0.7478005865102639
# confusion matrix: tn, fp, fn, tp [233 340   4 787]
# Predict majority: accuracy= 0.5799120234604106
#
# * TEST RESULTS *
# precision, recall, F1 = (0.6601941747572816, 0.8292682926829268, 0.7351351351351352)
# n = 152  accuracy = 0.6776315789473685
# confusion matrix: tn, fp, fn, tp [35 35 14 68]
# Predict majority: accuracy= 0.5394736842105263
# Native avg=2.650, stdev=0.412
# fraction 0.995, idx 782.07, ref limit=4.082
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.704136690647482, 0.9949174078780177, 0.8246445497630331)
# n = 1364  accuracy = 0.7558651026392962
# confusion matrix: tn, fp, fn, tp [248 329   4 783]
# Predict majority: accuracy= 0.5769794721407625
#
# * TEST RESULTS *
# precision, recall, F1 = (0.6842105263157895, 0.9069767441860465, 0.78)
# n = 152  accuracy = 0.7105263157894737
# confusion matrix: tn, fp, fn, tp [30 36  8 78]
# Predict majority: accuracy= 0.5657894736842105
# Native avg=2.634, stdev=0.423
# fraction 0.995, idx 783.06, ref limit=4.080
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.7159817351598173, 0.9949238578680203, 0.83271375464684)
# n = 1364  accuracy = 0.7690615835777126
# confusion matrix: tn, fp, fn, tp [265 311   4 784]
# Predict majority: accuracy= 0.5777126099706745
#
# * TEST RESULTS *
# precision, recall, F1 = (0.6126126126126126, 0.8, 0.6938775510204082)
# n = 152  accuracy = 0.6052631578947368
# confusion matrix: tn, fp, fn, tp [24 43 17 68]
# Predict majority: accuracy= 0.5592105263157895
# Native avg=2.632, stdev=0.421
# fraction 0.995, idx 781.08, ref limit=4.061
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.7089755213055303, 0.9949109414758269, 0.8279512969825303)
# n = 1364  accuracy = 0.7617302052785924
# confusion matrix: tn, fp, fn, tp [257 321   4 782]
# Predict majority: accuracy= 0.5762463343108505
#
# * TEST RESULTS *
# precision, recall, F1 = (0.6909090909090909, 0.8735632183908046, 0.7715736040609137)
# n = 152  accuracy = 0.7039473684210527
# confusion matrix: tn, fp, fn, tp [31 34 11 76]
# Predict majority: accuracy= 0.5723684210526315
# Native avg=2.619, stdev=0.416
# fraction 0.995, idx 783.06, ref limit=4.102
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.7088607594936709, 0.9949238578680203, 0.8278775079197465)
# n = 1365  accuracy = 0.7611721611721611
# confusion matrix: tn, fp, fn, tp [255 322   4 784]
# Predict majority: accuracy= 0.5772893772893772
#
# * TEST RESULTS *
# precision, recall, F1 = (0.6017699115044248, 0.8, 0.6868686868686869)
# n = 151  accuracy = 0.5894039735099338
# confusion matrix: tn, fp, fn, tp [21 45 17 68]
# Predict majority: accuracy= 0.5629139072847682
# Native avg=2.623, stdev=0.428
# fraction 0.995, idx 778.09, ref limit=4.069
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.7094717668488161, 0.9948914431673053, 0.8282828282828283)
# n = 1365  accuracy = 0.7633699633699633
# confusion matrix: tn, fp, fn, tp [263 319   4 779]
# Predict majority: accuracy= 0.5736263736263736
#
# * TEST RESULTS *
# precision, recall, F1 = (0.7247706422018348, 0.8777777777777778, 0.7939698492462312)
# n = 151  accuracy = 0.7284768211920529
# confusion matrix: tn, fp, fn, tp [31 30 11 79]
# Predict majority: accuracy= 0.5960264900662252
# Native avg=2.632, stdev=0.419
# fraction 0.995, idx 788.04, ref limit=4.094
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.7076233183856502, 0.9949558638083228, 0.8270440251572327)
# n = 1365  accuracy = 0.7582417582417582
# confusion matrix: tn, fp, fn, tp [246 326   4 789]
# Predict majority: accuracy= 0.580952380952381
#
# * TEST RESULTS *
# precision, recall, F1 = (0.6330275229357798, 0.8625, 0.7301587301587302)
# n = 151  accuracy = 0.6622516556291391
# confusion matrix: tn, fp, fn, tp [31 40 11 69]
# Predict majority: accuracy= 0.5298013245033113
# Native avg=2.637, stdev=0.422
# fraction 0.995, idx 771.12, ref limit=3.988
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.7228464419475655, 0.9948453608247423, 0.8373101952277657)
# n = 1365  accuracy = 0.7802197802197802
# confusion matrix: tn, fp, fn, tp [293 296   4 772]
# Predict majority: accuracy= 0.5684981684981685
#
# * TEST RESULTS *
# precision, recall, F1 = (0.7166666666666667, 0.8865979381443299, 0.792626728110599)
# n = 151  accuracy = 0.7019867549668874
# confusion matrix: tn, fp, fn, tp [20 34 11 86]
# Predict majority: accuracy= 0.6423841059602649
#
#             Acc   Maj_acc      Prec    Recall        F1
# Mean   0.680054  0.575876  0.673527  0.859233  0.754820
# StDev  0.048414  0.038379  0.047375  0.037041  0.042141
#
# Language=English, form=segments
# Native avg=2.672, stdev=0.407
# fraction 0.995, idx 781.08, ref limit=3.977
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8020512820512821, 0.9949109414758269, 0.8881317433276548)
# n = 1364  accuracy = 0.8555718475073314
# confusion matrix: tn, fp, fn, tp [385 193   4 782]
# Predict majority: accuracy= 0.5762463343108505
#
# * TEST RESULTS *
# precision, recall, F1 = (0.7297297297297297, 0.6206896551724138, 0.6708074534161491)
# n = 152  accuracy = 0.6513157894736842
# confusion matrix: tn, fp, fn, tp [45 20 33 54]
# Predict majority: accuracy= 0.5723684210526315
# Native avg=2.666, stdev=0.430
# fraction 0.995, idx 779.09, ref limit=4.004
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8, 0.9948979591836735, 0.8868675383740763)
# n = 1364  accuracy = 0.8541055718475073
# confusion matrix: tn, fp, fn, tp [385 195   4 780]
# Predict majority: accuracy= 0.5747800586510264
#
# * TEST RESULTS *
# precision, recall, F1 = (0.7464788732394366, 0.5955056179775281, 0.6625)
# n = 152  accuracy = 0.6447368421052632
# confusion matrix: tn, fp, fn, tp [45 18 36 53]
# Predict majority: accuracy= 0.5855263157894737
# Native avg=2.678, stdev=0.413
# fraction 0.995, idx 789.03, ref limit=3.841
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8359788359788359, 0.9949622166246851, 0.9085681426106959)
# n = 1364  accuracy = 0.8834310850439883
# confusion matrix: tn, fp, fn, tp [415 155   4 790]
# Predict majority: accuracy= 0.5821114369501467
#
# * TEST RESULTS *
# precision, recall, F1 = (0.6865671641791045, 0.5822784810126582, 0.6301369863013699)
# n = 152  accuracy = 0.6447368421052632
# confusion matrix: tn, fp, fn, tp [52 21 33 46]
# Predict majority: accuracy= 0.5197368421052632
# Native avg=2.686, stdev=0.422
# fraction 0.995, idx 782.07, ref limit=3.946
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8047276464542652, 0.9949174078780177, 0.8897727272727273)
# n = 1364  accuracy = 0.8577712609970675
# confusion matrix: tn, fp, fn, tp [387 190   4 783]
# Predict majority: accuracy= 0.5769794721407625
#
# * TEST RESULTS *
# precision, recall, F1 = (0.7333333333333333, 0.6395348837209303, 0.6832298136645963)
# n = 152  accuracy = 0.6644736842105263
# confusion matrix: tn, fp, fn, tp [46 20 31 55]
# Predict majority: accuracy= 0.5657894736842105
# Native avg=2.673, stdev=0.420
# fraction 0.995, idx 786.05, ref limit=3.896
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8215031315240083, 0.9949431099873578, 0.8999428244711264)
# n = 1364  accuracy = 0.8717008797653959
# confusion matrix: tn, fp, fn, tp [402 171   4 787]
# Predict majority: accuracy= 0.5799120234604106
#
# * TEST RESULTS *
# precision, recall, F1 = (0.734375, 0.573170731707317, 0.6438356164383561)
# n = 152  accuracy = 0.6578947368421053
# confusion matrix: tn, fp, fn, tp [53 17 35 47]
# Predict majority: accuracy= 0.5394736842105263
# Native avg=2.676, stdev=0.436
# fraction 0.995, idx 785.05, ref limit=3.990
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.81875, 0.9949367088607595, 0.8982857142857142)
# n = 1364  accuracy = 0.8695014662756598
# confusion matrix: tn, fp, fn, tp [400 174   4 786]
# Predict majority: accuracy= 0.5791788856304986
#
# * TEST RESULTS *
# precision, recall, F1 = (0.6153846153846154, 0.5783132530120482, 0.5962732919254657)
# n = 152  accuracy = 0.5723684210526315
# confusion matrix: tn, fp, fn, tp [39 30 35 48]
# Predict majority: accuracy= 0.5460526315789473
# Native avg=2.682, stdev=0.414
# fraction 0.995, idx 776.10, ref limit=3.951
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8060165975103735, 0.9948783610755442, 0.8905444126074498)
# n = 1365  accuracy = 0.8600732600732601
# confusion matrix: tn, fp, fn, tp [397 187   4 777]
# Predict majority: accuracy= 0.5721611721611721
#
# * TEST RESULTS *
# precision, recall, F1 = (0.7222222222222222, 0.5652173913043478, 0.6341463414634146)
# n = 151  accuracy = 0.6026490066225165
# confusion matrix: tn, fp, fn, tp [39 20 40 52]
# Predict majority: accuracy= 0.609271523178808
# Native avg=2.668, stdev=0.431
# fraction 0.995, idx 774.11, ref limit=4.037
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.7924335378323109, 0.9948652118100129, 0.8821855435401252)
# n = 1365  accuracy = 0.8483516483516483
# confusion matrix: tn, fp, fn, tp [383 203   4 775]
# Predict majority: accuracy= 0.5706959706959707
#
# * TEST RESULTS *
# precision, recall, F1 = (0.7746478873239436, 0.5851063829787234, 0.6666666666666667)
# n = 151  accuracy = 0.6357615894039735
# confusion matrix: tn, fp, fn, tp [41 16 39 55]
# Predict majority: accuracy= 0.6225165562913907
# Native avg=2.676, stdev=0.417
# fraction 0.995, idx 777.10, ref limit=3.951
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8078920041536864, 0.9948849104859335, 0.8916905444126075)
# n = 1365  accuracy = 0.8615384615384616
# confusion matrix: tn, fp, fn, tp [398 185   4 778]
# Predict majority: accuracy= 0.5728937728937729
#
# * TEST RESULTS *
# precision, recall, F1 = (0.7142857142857143, 0.6043956043956044, 0.6547619047619048)
# n = 151  accuracy = 0.6158940397350994
# confusion matrix: tn, fp, fn, tp [38 22 36 55]
# Predict majority: accuracy= 0.6026490066225165
# Native avg=2.669, stdev=0.432
# fraction 0.995, idx 778.09, ref limit=3.899
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.82, 0.9948914431673053, 0.8990190421234853)
# n = 1365  accuracy = 0.8717948717948718
# confusion matrix: tn, fp, fn, tp [411 171   4 779]
# Predict majority: accuracy= 0.5736263736263736
#
# * TEST RESULTS *
# precision, recall, F1 = (0.7183098591549296, 0.5666666666666667, 0.6335403726708074)
# n = 151  accuracy = 0.609271523178808
# confusion matrix: tn, fp, fn, tp [41 20 39 51]
# Predict majority: accuracy= 0.5960264900662252
#
#             Acc   Maj_acc      Prec    Recall        F1
# Mean   0.629910  0.575941  0.717533  0.591088  0.647590
# StDev  0.029034  0.033311  0.042437  0.024229  0.025336
#
# Language=English, form=scas
# Native avg=2.540, stdev=0.416
# fraction 0.995, idx 786.05, ref limit=3.996
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.6275917065390749, 0.9949431099873578, 0.769682151589242)
# n = 1364  accuracy = 0.6546920821114369
# confusion matrix: tn, fp, fn, tp [106 467   4 787]
# Predict majority: accuracy= 0.5799120234604106
#
# * TEST RESULTS *
# precision, recall, F1 = (0.5590551181102362, 0.8658536585365854, 0.6794258373205742)
# n = 152  accuracy = 0.5592105263157895
# confusion matrix: tn, fp, fn, tp [14 56 11 71]
# Predict majority: accuracy= 0.5394736842105263
# Native avg=2.542, stdev=0.414
# fraction 0.995, idx 785.05, ref limit=4.030
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.6238095238095238, 0.9949367088607595, 0.7668292682926829)
# n = 1364  accuracy = 0.6495601173020528
# confusion matrix: tn, fp, fn, tp [100 474   4 786]
# Predict majority: accuracy= 0.5791788856304986
#
# * TEST RESULTS *
# precision, recall, F1 = (0.5757575757575758, 0.9156626506024096, 0.7069767441860465)
# n = 152  accuracy = 0.5855263157894737
# confusion matrix: tn, fp, fn, tp [13 56  7 76]
# Predict majority: accuracy= 0.5460526315789473
# Native avg=2.533, stdev=0.418
# fraction 0.995, idx 774.11, ref limit=3.787
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.6342062193126022, 0.9948652118100129, 0.7746126936531734)
# n = 1364  accuracy = 0.6693548387096774
# confusion matrix: tn, fp, fn, tp [138 447   4 775]
# Predict majority: accuracy= 0.5711143695014663
#
# * TEST RESULTS *
# precision, recall, F1 = (0.6178861788617886, 0.8085106382978723, 0.7004608294930876)
# n = 152  accuracy = 0.5723684210526315
# confusion matrix: tn, fp, fn, tp [11 47 18 76]
# Predict majority: accuracy= 0.618421052631579
# Native avg=2.536, stdev=0.423
# fraction 0.995, idx 774.11, ref limit=3.987
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.6190095846645367, 0.9948652118100129, 0.7631708517971444)
# n = 1364  accuracy = 0.6473607038123167
# confusion matrix: tn, fp, fn, tp [108 477   4 775]
# Predict majority: accuracy= 0.5711143695014663
#
# * TEST RESULTS *
# precision, recall, F1 = (0.6456692913385826, 0.8723404255319149, 0.7420814479638009)
# n = 152  accuracy = 0.625
# confusion matrix: tn, fp, fn, tp [13 45 12 82]
# Predict majority: accuracy= 0.618421052631579
# Native avg=2.542, stdev=0.418
# fraction 0.995, idx 773.12, ref limit=3.979
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.6196957566052842, 0.9948586118251928, 0.7636901825357671)
# n = 1364  accuracy = 0.6488269794721407
# confusion matrix: tn, fp, fn, tp [111 475   4 774]
# Predict majority: accuracy= 0.5703812316715543
#
# * TEST RESULTS *
# precision, recall, F1 = (0.6390977443609023, 0.8947368421052632, 0.7456140350877193)
# n = 152  accuracy = 0.618421052631579
# confusion matrix: tn, fp, fn, tp [ 9 48 10 85]
# Predict majority: accuracy= 0.625
# Native avg=2.548, stdev=0.428
# fraction 0.995, idx 780.08, ref limit=3.824
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.6334144363341444, 0.9949044585987261, 0.7740336967294351)
# n = 1364  accuracy = 0.6656891495601173
# confusion matrix: tn, fp, fn, tp [127 452   4 781]
# Predict majority: accuracy= 0.5755131964809385
#
# * TEST RESULTS *
# precision, recall, F1 = (0.6230769230769231, 0.9204545454545454, 0.7431192660550459)
# n = 152  accuracy = 0.631578947368421
# confusion matrix: tn, fp, fn, tp [15 49  7 81]
# Predict majority: accuracy= 0.5789473684210527
# Native avg=2.537, stdev=0.425
# fraction 0.995, idx 780.08, ref limit=4.065
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.617879746835443, 0.9949044585987261, 0.7623230844314298)
# n = 1365  accuracy = 0.6432234432234433
# confusion matrix: tn, fp, fn, tp [ 97 483   4 781]
# Predict majority: accuracy= 0.575091575091575
#
# * TEST RESULTS *
# precision, recall, F1 = (0.6030534351145038, 0.8977272727272727, 0.7214611872146118)
# n = 151  accuracy = 0.5960264900662252
# confusion matrix: tn, fp, fn, tp [11 52  9 79]
# Predict majority: accuracy= 0.5827814569536424
# Native avg=2.532, stdev=0.429
# fraction 0.995, idx 789.03, ref limit=3.825
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.6438467807660961, 0.9949622166246851, 0.7817911924789708)
# n = 1365  accuracy = 0.676923076923077
# confusion matrix: tn, fp, fn, tp [134 437   4 790]
# Predict majority: accuracy= 0.5816849816849817
#
# * TEST RESULTS *
# precision, recall, F1 = (0.5289256198347108, 0.810126582278481, 0.64)
# n = 151  accuracy = 0.5231788079470199
# confusion matrix: tn, fp, fn, tp [15 57 15 64]
# Predict majority: accuracy= 0.5231788079470199
# Native avg=2.536, stdev=0.427
# fraction 0.995, idx 775.11, ref limit=4.098
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.6105428796223447, 0.9948717948717949, 0.756704046806436)
# n = 1365  accuracy = 0.6344322344322344
# confusion matrix: tn, fp, fn, tp [ 90 495   4 776]
# Predict majority: accuracy= 0.5714285714285714
#
# * TEST RESULTS *
# precision, recall, F1 = (0.6111111111111112, 0.8279569892473119, 0.7031963470319634)
# n = 151  accuracy = 0.5695364238410596
# confusion matrix: tn, fp, fn, tp [ 9 49 16 77]
# Predict majority: accuracy= 0.6158940397350994
# Native avg=2.540, stdev=0.424
# fraction 0.995, idx 791.02, ref limit=4.029
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.6275752773375595, 0.9949748743718593, 0.7696793002915453)
# n = 1365  accuracy = 0.6527472527472528
# confusion matrix: tn, fp, fn, tp [ 99 470   4 792]
# Predict majority: accuracy= 0.5831501831501832
#
# * TEST RESULTS *
# precision, recall, F1 = (0.546875, 0.9090909090909091, 0.6829268292682926)
# n = 151  accuracy = 0.5695364238410596
# confusion matrix: tn, fp, fn, tp [16 58  7 70]
# Predict majority: accuracy= 0.5099337748344371
#
#             Acc   Maj_acc      Prec    Recall        F1
# Mean   0.585038  0.575810  0.595051  0.872246  0.706526
# StDev  0.033555  0.043502  0.040128  0.043005  0.033532

# %% [markdown]
# # Word discrimination with native and loan known
# - smoothing=0.5
# - z=0.995
# ## k-fold fit on known native and loan and validation on unknown

# %%
# Test k_fold dual basis word discrimination.
_ = k_fold_language_word_discrimination_dual_basis('English', form='formchars', smoothing=0.5, k_fold=10)
_ = k_fold_language_word_discrimination_dual_basis('English', form='segments', smoothing=0.5, k_fold=10)
_ = k_fold_language_word_discrimination_dual_basis('English', form='scas', smoothing=0.5, k_fold=10)
# Out:
# Language=English, form=formchars
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9428934010152284, 0.9477040816326531, 0.94529262086514)
# n = 1364  accuracy = 0.9369501466275659
# confusion matrix: tn, fp, fn, tp [535  45  41 743]
# Predict majority: accuracy= 0.5747800586510264
#
# * TEST RESULTS *
# precision, recall, F1 = (0.7555555555555555, 0.7640449438202247, 0.7597765363128491)
# n = 152  accuracy = 0.7171052631578947
# confusion matrix: tn, fp, fn, tp [41 22 21 68]
# Predict majority: accuracy= 0.5855263157894737
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9477040816326531, 0.9477040816326531, 0.9477040816326531)
# n = 1364  accuracy = 0.9398826979472141
# confusion matrix: tn, fp, fn, tp [539  41  41 743]
# Predict majority: accuracy= 0.5747800586510264
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8202247191011236, 0.8202247191011236, 0.8202247191011236)
# n = 152  accuracy = 0.7894736842105263
# confusion matrix: tn, fp, fn, tp [47 16 16 73]
# Predict majority: accuracy= 0.5855263157894737
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.948051948051948, 0.9335038363171355, 0.940721649484536)
# n = 1364  accuracy = 0.9325513196480938
# confusion matrix: tn, fp, fn, tp [542  40  52 730]
# Predict majority: accuracy= 0.5733137829912024
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8227848101265823, 0.7142857142857143, 0.7647058823529411)
# n = 152  accuracy = 0.7368421052631579
# confusion matrix: tn, fp, fn, tp [47 14 26 65]
# Predict majority: accuracy= 0.5986842105263158
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9368686868686869, 0.9452229299363057, 0.9410272669625872)
# n = 1364  accuracy = 0.9318181818181818
# confusion matrix: tn, fp, fn, tp [529  50  43 742]
# Predict majority: accuracy= 0.5755131964809385
#
# * TEST RESULTS *
# precision, recall, F1 = (0.7976190476190477, 0.7613636363636364, 0.7790697674418605)
# n = 152  accuracy = 0.75
# confusion matrix: tn, fp, fn, tp [47 17 21 67]
# Predict majority: accuracy= 0.5789473684210527
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9475032010243278, 0.9414758269720102, 0.9444798978940651)
# n = 1364  accuracy = 0.9362170087976539
# confusion matrix: tn, fp, fn, tp [537  41  46 740]
# Predict majority: accuracy= 0.5762463343108505
#
# * TEST RESULTS *
# precision, recall, F1 = (0.7666666666666667, 0.7931034482758621, 0.7796610169491527)
# n = 152  accuracy = 0.743421052631579
# confusion matrix: tn, fp, fn, tp [44 21 18 69]
# Predict majority: accuracy= 0.5723684210526315
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9505208333333334, 0.9358974358974359, 0.9431524547803619)
# n = 1364  accuracy = 0.9354838709677419
# confusion matrix: tn, fp, fn, tp [546  38  50 730]
# Predict majority: accuracy= 0.5718475073313783
#
# * TEST RESULTS *
# precision, recall, F1 = (0.75, 0.7741935483870968, 0.7619047619047619)
# n = 152  accuracy = 0.7039473684210527
# confusion matrix: tn, fp, fn, tp [35 24 21 72]
# Predict majority: accuracy= 0.6118421052631579
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9528061224489796, 0.9455696202531646, 0.9491740787801778)
# n = 1365  accuracy = 0.9413919413919414
# confusion matrix: tn, fp, fn, tp [538  37  43 747]
# Predict majority: accuracy= 0.5787545787545788
#
# * TEST RESULTS *
# precision, recall, F1 = (0.7727272727272727, 0.8192771084337349, 0.7953216374269007)
# n = 151  accuracy = 0.7682119205298014
# confusion matrix: tn, fp, fn, tp [48 20 15 68]
# Predict majority: accuracy= 0.5496688741721855
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9479034307496823, 0.9479034307496823, 0.9479034307496823)
# n = 1365  accuracy = 0.9399267399267399
# confusion matrix: tn, fp, fn, tp [537  41  41 746]
# Predict majority: accuracy= 0.5765567765567765
#
# * TEST RESULTS *
# precision, recall, F1 = (0.75, 0.7674418604651163, 0.7586206896551724)
# n = 151  accuracy = 0.7218543046357616
# confusion matrix: tn, fp, fn, tp [43 22 20 66]
# Predict majority: accuracy= 0.5695364238410596
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9421383647798742, 0.9421383647798742, 0.9421383647798742)
# n = 1365  accuracy = 0.9326007326007326
# confusion matrix: tn, fp, fn, tp [524  46  46 749]
# Predict majority: accuracy= 0.5824175824175825
#
# * TEST RESULTS *
# precision, recall, F1 = (0.7692307692307693, 0.7692307692307693, 0.7692307692307693)
# n = 151  accuracy = 0.7615894039735099
# confusion matrix: tn, fp, fn, tp [55 18 18 60]
# Predict majority: accuracy= 0.5165562913907285
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9429657794676806, 0.9489795918367347, 0.9459631277813096)
# n = 1365  accuracy = 0.9377289377289377
# confusion matrix: tn, fp, fn, tp [536  45  40 744]
# Predict majority: accuracy= 0.5743589743589743
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8292682926829268, 0.7640449438202247, 0.7953216374269005)
# n = 151  accuracy = 0.7682119205298014
# confusion matrix: tn, fp, fn, tp [48 14 21 68]
# Predict majority: accuracy= 0.5894039735099338
#
#             Acc   Maj_acc      Prec    Recall        F1
# Mean   0.746066  0.575806  0.783408  0.774721  0.778384
# StDev  0.026693  0.026772  0.031295  0.030797  0.020016
#
# Language=English, form=segments
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9743260590500642, 0.971830985915493, 0.9730769230769232)
# n = 1364  accuracy = 0.969208211143695
# confusion matrix: tn, fp, fn, tp [563  20  22 759]
# Predict majority: accuracy= 0.5725806451612904
#
# * TEST RESULTS *
# precision, recall, F1 = (0.7710843373493976, 0.6956521739130435, 0.7314285714285714)
# n = 152  accuracy = 0.6907894736842105
# confusion matrix: tn, fp, fn, tp [41 19 28 64]
# Predict majority: accuracy= 0.6052631578947368
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9809885931558935, 0.9699248120300752, 0.9754253308128544)
# n = 1364  accuracy = 0.9714076246334311
# confusion matrix: tn, fp, fn, tp [551  15  24 774]
# Predict majority: accuracy= 0.5850439882697948
#
# * TEST RESULTS *
# precision, recall, F1 = (0.6222222222222222, 0.7466666666666667, 0.6787878787878788)
# n = 152  accuracy = 0.6513157894736842
# confusion matrix: tn, fp, fn, tp [43 34 19 56]
# Predict majority: accuracy= 0.506578947368421
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9733163913595934, 0.9720812182741116, 0.9726984126984125)
# n = 1364  accuracy = 0.968475073313783
# confusion matrix: tn, fp, fn, tp [555  21  22 766]
# Predict majority: accuracy= 0.5777126099706745
#
# * TEST RESULTS *
# precision, recall, F1 = (0.7176470588235294, 0.7176470588235294, 0.7176470588235294)
# n = 152  accuracy = 0.6842105263157895
# confusion matrix: tn, fp, fn, tp [43 24 24 61]
# Predict majority: accuracy= 0.5592105263157895
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9772151898734177, 0.9772151898734177, 0.9772151898734177)
# n = 1364  accuracy = 0.9736070381231672
# confusion matrix: tn, fp, fn, tp [556  18  18 772]
# Predict majority: accuracy= 0.5791788856304986
#
# * TEST RESULTS *
# precision, recall, F1 = (0.6818181818181818, 0.7228915662650602, 0.7017543859649122)
# n = 152  accuracy = 0.6644736842105263
# confusion matrix: tn, fp, fn, tp [41 28 23 60]
# Predict majority: accuracy= 0.5460526315789473
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9770992366412213, 0.9746192893401016, 0.9758576874205844)
# n = 1364  accuracy = 0.9721407624633431
# confusion matrix: tn, fp, fn, tp [558  18  20 768]
# Predict majority: accuracy= 0.5777126099706745
#
# * TEST RESULTS *
# precision, recall, F1 = (0.7311827956989247, 0.8, 0.7640449438202247)
# n = 152  accuracy = 0.7236842105263158
# confusion matrix: tn, fp, fn, tp [42 25 17 68]
# Predict majority: accuracy= 0.5592105263157895
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.977979274611399, 0.9729381443298969, 0.975452196382429)
# n = 1364  accuracy = 0.9721407624633431
# confusion matrix: tn, fp, fn, tp [571  17  21 755]
# Predict majority: accuracy= 0.5689149560117303
#
# * TEST RESULTS *
# precision, recall, F1 = (0.7906976744186046, 0.7010309278350515, 0.7431693989071039)
# n = 152  accuracy = 0.6907894736842105
# confusion matrix: tn, fp, fn, tp [37 18 29 68]
# Predict majority: accuracy= 0.6381578947368421
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9771573604060914, 0.9783989834815756, 0.9777777777777777)
# n = 1365  accuracy = 0.9743589743589743
# confusion matrix: tn, fp, fn, tp [560  18  17 770]
# Predict majority: accuracy= 0.5765567765567765
#
# * TEST RESULTS *
# precision, recall, F1 = (0.7325581395348837, 0.7325581395348837, 0.7325581395348836)
# n = 151  accuracy = 0.695364238410596
# confusion matrix: tn, fp, fn, tp [42 23 23 63]
# Predict majority: accuracy= 0.5695364238410596
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9770408163265306, 0.9733163913595934, 0.9751750477402928)
# n = 1365  accuracy = 0.9714285714285714
# confusion matrix: tn, fp, fn, tp [560  18  21 766]
# Predict majority: accuracy= 0.5765567765567765
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8055555555555556, 0.6744186046511628, 0.7341772151898734)
# n = 151  accuracy = 0.7218543046357616
# confusion matrix: tn, fp, fn, tp [51 14 28 58]
# Predict majority: accuracy= 0.5695364238410596
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9731113956466069, 0.9706257982120051, 0.9718670076726343)
# n = 1365  accuracy = 0.9677655677655678
# confusion matrix: tn, fp, fn, tp [561  21  23 760]
# Predict majority: accuracy= 0.5736263736263736
#
# * TEST RESULTS *
# precision, recall, F1 = (0.7582417582417582, 0.7666666666666667, 0.7624309392265194)
# n = 151  accuracy = 0.7152317880794702
# confusion matrix: tn, fp, fn, tp [39 22 21 69]
# Predict majority: accuracy= 0.5960264900662252
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.9768637532133676, 0.975609756097561, 0.9762363519588954)
# n = 1365  accuracy = 0.9728937728937729
# confusion matrix: tn, fp, fn, tp [568  18  19 760]
# Predict majority: accuracy= 0.5706959706959707
#
# * TEST RESULTS *
# precision, recall, F1 = (0.8024691358024691, 0.6914893617021277, 0.7428571428571429)
# n = 151  accuracy = 0.7019867549668874
# confusion matrix: tn, fp, fn, tp [41 16 29 65]
# Predict majority: accuracy= 0.6225165562913907
#
#             Acc   Maj_acc      Prec    Recall        F1
# Mean   0.693970  0.577209  0.741348  0.724902  0.730886
# StDev  0.023532  0.038921  0.057678  0.038098  0.026121
#
# Language=English, form=scas
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8848728246318608, 0.8377693282636248, 0.8606770833333334)
# n = 1364  accuracy = 0.843108504398827
# confusion matrix: tn, fp, fn, tp [489  86 128 661]
# Predict majority: accuracy= 0.5784457478005866
#
# * TEST RESULTS *
# precision, recall, F1 = (0.6296296296296297, 0.6071428571428571, 0.6181818181818182)
# n = 152  accuracy = 0.5855263157894737
# confusion matrix: tn, fp, fn, tp [38 30 33 51]
# Predict majority: accuracy= 0.5526315789473685
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.893296853625171, 0.8404118404118404, 0.8660477453580901)
# n = 1364  accuracy = 0.8519061583577713
# confusion matrix: tn, fp, fn, tp [509  78 124 653]
# Predict majority: accuracy= 0.5696480938416423
#
# * TEST RESULTS *
# precision, recall, F1 = (0.7974683544303798, 0.65625, 0.7200000000000001)
# n = 152  accuracy = 0.6776315789473685
# confusion matrix: tn, fp, fn, tp [40 16 33 63]
# Predict majority: accuracy= 0.631578947368421
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8938401048492791, 0.8525, 0.872680742162508)
# n = 1364  accuracy = 0.8541055718475073
# confusion matrix: tn, fp, fn, tp [483  81 118 682]
# Predict majority: accuracy= 0.5865102639296188
#
# * TEST RESULTS *
# precision, recall, F1 = (0.5625, 0.6164383561643836, 0.5882352941176471)
# n = 152  accuracy = 0.5855263157894737
# confusion matrix: tn, fp, fn, tp [44 35 28 45]
# Predict majority: accuracy= 0.5197368421052632
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8778523489932886, 0.8427835051546392, 0.8599605522682445)
# n = 1364  accuracy = 0.843841642228739
# confusion matrix: tn, fp, fn, tp [497  91 122 654]
# Predict majority: accuracy= 0.5689149560117303
#
# * TEST RESULTS *
# precision, recall, F1 = (0.7619047619047619, 0.6597938144329897, 0.707182320441989)
# n = 152  accuracy = 0.6513157894736842
# confusion matrix: tn, fp, fn, tp [35 20 33 64]
# Predict majority: accuracy= 0.6381578947368421
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.885752688172043, 0.8481338481338482, 0.8665351742274818)
# n = 1364  accuracy = 0.8511730205278593
# confusion matrix: tn, fp, fn, tp [502  85 118 659]
# Predict majority: accuracy= 0.5696480938416423
#
# * TEST RESULTS *
# precision, recall, F1 = (0.788235294117647, 0.6979166666666666, 0.7403314917127071)
# n = 152  accuracy = 0.6907894736842105
# confusion matrix: tn, fp, fn, tp [38 18 29 67]
# Predict majority: accuracy= 0.631578947368421
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8821954484605087, 0.8437900128040973, 0.8625654450261779)
# n = 1364  accuracy = 0.8460410557184751
# confusion matrix: tn, fp, fn, tp [495  88 122 659]
# Predict majority: accuracy= 0.5725806451612904
#
# * TEST RESULTS *
# precision, recall, F1 = (0.6794871794871795, 0.5760869565217391, 0.623529411764706)
# n = 152  accuracy = 0.5789473684210527
# confusion matrix: tn, fp, fn, tp [35 25 39 53]
# Predict majority: accuracy= 0.6052631578947368
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8908355795148248, 0.8345959595959596, 0.8617992177314211)
# n = 1365  accuracy = 0.8446886446886447
# confusion matrix: tn, fp, fn, tp [492  81 131 661]
# Predict majority: accuracy= 0.5802197802197803
#
# * TEST RESULTS *
# precision, recall, F1 = (0.6835443037974683, 0.6666666666666666, 0.675)
# n = 151  accuracy = 0.6556291390728477
# confusion matrix: tn, fp, fn, tp [45 25 27 54]
# Predict majority: accuracy= 0.5364238410596026
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8902275769745649, 0.8514724711907811, 0.8704188481675392)
# n = 1365  accuracy = 0.8549450549450549
# confusion matrix: tn, fp, fn, tp [502  82 116 665]
# Predict majority: accuracy= 0.5721611721611721
#
# * TEST RESULTS *
# precision, recall, F1 = (0.7297297297297297, 0.5869565217391305, 0.6506024096385542)
# n = 151  accuracy = 0.6158940397350994
# confusion matrix: tn, fp, fn, tp [39 20 38 54]
# Predict majority: accuracy= 0.609271523178808
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8884462151394422, 0.8479087452471483, 0.867704280155642)
# n = 1365  accuracy = 0.8505494505494505
# confusion matrix: tn, fp, fn, tp [492  84 120 669]
# Predict majority: accuracy= 0.578021978021978
#
# * TEST RESULTS *
# precision, recall, F1 = (0.7333333333333333, 0.6547619047619048, 0.6918238993710691)
# n = 151  accuracy = 0.6754966887417219
# confusion matrix: tn, fp, fn, tp [47 20 29 55]
# Predict majority: accuracy= 0.5562913907284768
#
# * TRAIN RESULTS *
# precision, recall, F1 = (0.8908122503328895, 0.8415094339622642, 0.8654592496765847)
# n = 1365  accuracy = 0.8476190476190476
# confusion matrix: tn, fp, fn, tp [488  82 126 669]
# Predict majority: accuracy= 0.5824175824175825
#
# * TEST RESULTS *
# precision, recall, F1 = (0.6024096385542169, 0.6410256410256411, 0.6211180124223603)
# n = 151  accuracy = 0.5960264900662252
# confusion matrix: tn, fp, fn, tp [40 33 28 50]
# Predict majority: accuracy= 0.5165562913907285
#
#             Acc   Maj_acc      Prec    Recall       F1
# Mean   0.631278  0.579749  0.696824  0.636304  0.66360
# StDev  0.043518  0.048378  0.079642  0.038495  0.05079

# %% [markdown]
# # Overfitting of Markov model
# ## k-fold report of entropy mean and standard deviation
# - Table as argument -- allows selection of subset of language table
# - k-fold determines fit and validation fractions
# - Option to specify subset selector for validation study
#     - Can look at only native words with this option.
# - No need for randomization tests of differences
#     - Sufficient evidence in statistical description
#
# ## In all orthographic cases, there is still overfitting even for just native words.

# %%
# Test k_fold train versus val entropy studies.
# Can select subset of table for specialized study - with option to increase k_fold for smaller dataset.
k_fold_entropy_for_language('English', k_fold=5, smoothing=[0.5])
k_fold_entropy_for_language('English', k_fold=10, smoothing=0.5, selector=lambda tbl: tbl.borrowedscore<0.375)
k_fold_entropy_for_language('English', form='segments', k_fold=5, smoothing=[0.5])
k_fold_entropy_for_language('English', form='segments', k_fold=10, smoothing=0.5, selector=lambda tbl: tbl.borrowedscore<0.375)
k_fold_entropy_for_language('English', form='scas', k_fold=5, smoothing=[0.5])
k_fold_entropy_for_language('English', form='scas', k_fold=10, smoothing=0.5, selector=lambda tbl: tbl.borrowedscore<0.375)
# Out:
# Language=English, form=formchars - 5-fold entropy
# Sample=1516, k-fold=5, val=304, model=KNI, order=3, smoothing=0.5.
# Statistic: Train mean Train stdev    Val mean  Val stdev
# Mean            2.837       0.410       3.386      0.774
# StdDev         0.0052      0.0038      0.0323     0.0676
# StdErr        0.00261     0.00190     0.01614    0.03381
#
# Language=English, form=formchars - 10-fold entropy
# Subset selected: See sample and val sizes.
# Sample=873, k-fold=10, val=88, model=KNI, order=3, smoothing=0.5.
# Statistic: Train mean Train stdev    Val mean  Val stdev
# Mean            2.631       0.423       3.266      0.812
# StdDev         0.0055      0.0055      0.0902     0.0961
# StdErr        0.00182     0.00183     0.03008    0.03203
#
# Language=English, form=segments - 5-fold entropy
# Sample=1516, k-fold=5, val=304, model=KNI, order=3, smoothing=0.5.
# Statistic: Train mean Train stdev    Val mean  Val stdev
# Mean            2.865       0.423       3.842      0.923
# StdDev         0.0033      0.0049      0.0567     0.0417
# StdErr        0.00164     0.00247     0.02837    0.02086
#
# Language=English, form=segments - 10-fold entropy
# Subset selected: See sample and val sizes.
# Sample=873, k-fold=10, val=88, model=KNI, order=3, smoothing=0.5.
# Statistic: Train mean Train stdev    Val mean  Val stdev
# Mean            2.674       0.422       3.807      0.979
# StdDev         0.0038      0.0042      0.0738     0.0523
# StdErr        0.00126     0.00141     0.02462    0.01742
#
# Language=English, form=scas - 5-fold entropy
# Sample=1516, k-fold=5, val=304, model=KNI, order=3, smoothing=0.5.
# Statistic: Train mean Train stdev    Val mean  Val stdev
# Mean            2.651       0.429       3.001      0.720
# StdDev         0.0034      0.0095      0.0213     0.0401
# StdErr        0.00171     0.00477     0.01063    0.02005
#
# Language=English, form=scas - 10-fold entropy
# Subset selected: See sample and val sizes.
# Sample=873, k-fold=10, val=88, model=KNI, order=3, smoothing=0.5.
# Statistic: Train mean Train stdev    Val mean  Val stdev
# Mean            2.538       0.423       3.010      0.770
# StdDev         0.0032      0.0020      0.0535     0.0467
# StdErr        0.00107     0.00068     0.01782    0.01556
